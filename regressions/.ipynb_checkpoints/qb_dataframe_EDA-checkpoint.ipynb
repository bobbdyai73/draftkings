# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
qb = pd.read_csv('input/qb/dk_qb_stats.csv')

# %%
qb.drop('Unnamed: 0', axis =1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-aa67a2fdd7bd> in <module>()
# ----> 1 qb.drop('Unnamed: 0', axis =1, inplace=True)
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
#    3626         return self.delete(indexer)
#
# ValueError: labels ['Unnamed: 0'] not contained in axis

# %%
qb.head()
# Out:
#                Player Team  Week  Opp  Comp  Att   Pct  Yds  Yds/Att  TD  Int  \
# 0           Matt Ryan  ATL     1   KC    23   31  74.0  299     10.0   3    0
# 1  Robert Griffin III  WAS     1   NO    19   26  73.0  320     12.0   2    0
# 2           Tony Romo  DAL     1  NYG    22   29  76.0  307     11.0   3    1
# 3       Aaron Rodgers   GB     1   SF    30   44  68.0  303      7.0   2    1
# 4          Drew Brees   NO     1  WAS    24   52  46.0  339      7.0   3    2
#
#    ru_att  ru_yds  yds/ru_att  ru_td  points  year
# 0       3      25         8.0      1   32.46  2012
# 1       9      42         5.0      0   25.00  2012
# 2       5      12         2.0      0   23.48  2012
# 3       5      27         5.0      0   22.82  2012
# 4       0       0         0.0      0   21.56  2012

# %%
for col in qb.columns:
    print(qb[col].describe(), '\n')
# Out:
# count           2729
# unique           108
# top       Drew Brees
# freq             102
# Name: Player, dtype: object
#
# count     2729
# unique      32
# top         NO
# freq       118
# Name: Team, dtype: object
#
# count    2729.000000
# mean        8.898864
# std         4.945676
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        13.000000
# max        17.000000
# Name: Week, dtype: float64
#
# count     2729
# unique      32
# top        ATL
# freq       106
# Name: Opp, dtype: object
#
# count    2729.000000
# mean       21.953096
# std         7.305794
# min         0.000000
# 25%        18.000000
# 50%        22.000000
# 75%        26.000000
# max        44.000000
# Name: Comp, dtype: float64
#
# count    2729.000000
# mean       34.285453
# std        11.020985
# min         0.000000
# 25%        29.000000
# 50%        35.000000
# 75%        41.000000
# max        66.000000
# Name: Att, dtype: float64
#
# count    2729.000000
# mean       63.021070
# std        13.675759
# min         0.000000
# 25%        58.000000
# 50%        64.100000
# 75%        70.600000
# max       100.000000
# Name: Pct, dtype: float64
#
# count    2729.000000
# mean      263.047636
# std        88.329213
# min        -1.000000
# 25%       219.000000
# 50%       268.000000
# 75%       319.000000
# max       527.000000
# Name: Yds, dtype: float64
#
# count    2729.000000
# mean        7.650678
# std         2.229983
# min        -1.000000
# 25%         6.500000
# 50%         7.600000
# 75%         8.900000
# max        23.000000
# Name: Yds/Att, dtype: float64
#
# count    2729.000000
# mean        1.923049
# std         1.161744
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         7.000000
# Name: TD, dtype: float64
#
# count    2729.000000
# mean        0.720044
# std         0.897233
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: Int, dtype: float64
#
# count    2729.000000
# mean        3.111763
# std         2.592349
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        17.000000
# Name: ru_att, dtype: float64
#
# count    2729.000000
# mean       14.198974
# std        19.593158
# min       -17.000000
# 25%         0.000000
# 50%         8.000000
# 75%        21.000000
# max       151.000000
# Name: ru_yds, dtype: float64
#
# count    2729.000000
# mean        3.597728
# std         4.340166
# min        -4.200000
# 25%         0.000000
# 50%         3.000000
# 75%         6.000000
# max        70.000000
# Name: yds/ru_att, dtype: float64
#
# count    2729.000000
# mean        0.151337
# std         0.382200
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: ru_td, dtype: float64
#
# count    2729.000000
# mean       20.468992
# std         8.160655
# min        -6.840000
# 25%        16.420000
# 50%        20.020000
# 75%        24.980000
# max        49.300000
# Name: points, dtype: float64
#
# count    2729.000000
# mean     2013.978747
# std         1.637488
# min      2012.000000
# 25%      2013.000000
# 50%      2014.000000
# 75%      2015.000000
# max      2017.000000
# Name: year, dtype: float64

# %%
def boxplotter(data, column_name):
    fig= plt.figure(figsize=(6,4))

    ax = sns.boxplot(data[column_name], orient='v',
                    fliersize=8, linewidth=1.5, notch=False,
                    saturation=0.5)
    ax.set_title(column_name, fontsize=20)
    plt.show()

# %%
boxplotter(qb,'ru_yds')

# %%
boxplotter(qb, 'Yds/Att')

# %%
boxplotter(qb,'Comp')

# %%
boxplotter(qb,'TD')

# %%
boxplotter(qb,'Int')

# %%
fig = plt.figure(figsize=(12,6))

ax = sns.boxplot(data=qb, orient='v', fliersize=5, linewidth=3, notch=True,
                 saturation=0.5)

ax.set_title('Qb Stats')
# Out:
# Text(0.5,1,'Qb Stats')

# %%
qb.corr()
# Out:
#                 Week      Comp       Att       Pct       Yds   Yds/Att  \
# Week        1.000000 -0.073167 -0.056137 -0.045304 -0.067497 -0.030958
# Comp       -0.073167  1.000000  0.907936  0.493671  0.841669  0.209697
# Att        -0.056137  0.907936  1.000000  0.232028  0.781086  0.047118
# Pct        -0.045304  0.493671  0.232028  1.000000  0.445060  0.682635
# Yds        -0.067497  0.841669  0.781086  0.445060  1.000000  0.542607
# Yds/Att    -0.030958  0.209697  0.047118  0.682635  0.542607  1.000000
# TD         -0.021643  0.346127  0.251715  0.340857  0.467585  0.409962
# Int        -0.011587  0.246737  0.371266 -0.086776  0.206437 -0.101037
# ru_att      0.003627 -0.099053 -0.083553  0.065418 -0.086053  0.068499
# ru_yds      0.026820 -0.122100 -0.068672 -0.020230 -0.130288 -0.028087
# yds/ru_att  0.007510 -0.041320  0.018885 -0.021183 -0.045855 -0.027105
# ru_td       0.013918 -0.072680 -0.073527  0.039975 -0.067329  0.042007
# points     -0.034492  0.571454  0.474329  0.438055  0.740128  0.541291
# year       -0.003525  0.229176  0.180770  0.211135  0.241420  0.182396
#
#                   TD       Int    ru_att    ru_yds  yds/ru_att     ru_td  \
# Week       -0.021643 -0.011587  0.003627  0.026820    0.007510  0.013918
# Comp        0.346127  0.246737 -0.099053 -0.122100   -0.041320 -0.072680
# Att         0.251715  0.371266 -0.083553 -0.068672    0.018885 -0.073527
# Pct         0.340857 -0.086776  0.065418 -0.020230   -0.021183  0.039975
# Yds         0.467585  0.206437 -0.086053 -0.130288   -0.045855 -0.067329
# Yds/Att     0.409962 -0.101037  0.068499 -0.028087   -0.027105  0.042007
# TD          1.000000 -0.040017 -0.081128 -0.106388   -0.034233 -0.197492
# Int        -0.040017  1.000000 -0.087722 -0.032821    0.016592 -0.007887
# ru_att     -0.081128 -0.087722  1.000000  0.742525    0.269860  0.366216
# ru_yds     -0.106388 -0.032821  0.742525  1.000000    0.673834  0.335550
# yds/ru_att -0.034233  0.016592  0.269860  0.673834    1.000000  0.155094
# ru_td      -0.197492 -0.007887  0.366216  0.335550    0.155094  1.000000
# points      0.757600 -0.065047  0.190700  0.207899    0.157456  0.210013
# year        0.202817 -0.051706  0.077674  0.057808    0.046822  0.067813
#
#               points      year
# Week       -0.034492 -0.003525
# Comp        0.571454  0.229176
# Att         0.474329  0.180770
# Pct         0.438055  0.211135
# Yds         0.740128  0.241420
# Yds/Att     0.541291  0.182396
# TD          0.757600  0.202817
# Int        -0.065047 -0.051706
# ru_att      0.190700  0.077674
# ru_yds      0.207899  0.057808
# yds/ru_att  0.157456  0.046822
# ru_td       0.210013  0.067813
# points      1.000000  0.333488
# year        0.333488  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(qb.corr(), annot=True)

# %%
corr = pd.DataFrame(index=qb.columns[4:])

# %%
np.corrcoef(qb.points, qb[col]))
# Out:
#   File "<ipython-input-113-a2a2e6077867>", line 1
#     np.corrcoef(qb.points, qb[col]))
#                                    ^
# SyntaxError: invalid syntax

# %%
corr
# Out:
# Empty DataFrame
# Columns: []
# Index: [Comp, Att, Pct, Yds, Yds/Att, TD, Int, ru_att, ru_yds, yds/ru_att, ru_td, points, year]

# %%
coef =[]
for col in qb.columns[4:]:
    #print(qb[col])
    coef.append(np.corrcoef(qb.points,qb[col])[0][1])

# %%
corr[1] = coef

# %%
corr
# Out:
#                    1
# Comp        0.571454
# Att         0.474329
# Pct         0.438055
# Yds         0.740128
# Yds/Att     0.541291
# TD          0.757600
# Int        -0.065047
# ru_att      0.190700
# ru_yds      0.207899
# yds/ru_att  0.157456
# ru_td       0.210013
# points      1.000000
# year        0.333488

# %%
qb['ru_yds2'] = qb['ru_yds'].apply(lambda x: x**2)

# %%
pd.scatter_matrix(qb[4:], figsize=(20,15))
plt.show()
# Out:
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
qb_temp
# Out:
#       Comp  Att   Pct  Yds  Yds/Att  TD  Int  ru_att  ru_yds  yds/ru_att  \
# 0       23   31  74.0  299     10.0   3    0       3      25         8.0
# 1       19   26  73.0  320     12.0   2    0       9      42         5.0
# 2       22   29  76.0  307     11.0   3    1       5      12         2.0
# 3       30   44  68.0  303      7.0   2    1       5      27         5.0
# 4       24   52  46.0  339      7.0   3    2       0       0         0.0
# 5       19   27  70.0  266     10.0   3    1       0       0         0.0
# 6       19   26  73.0  253     10.0   2    0       4       3         1.0
# 7       21   29  72.0  299     10.0   2    0       2      -1        -1.0
# 8       23   39  59.0  260      7.0   2    0       5       6         1.0
# 9       21   35  60.0  333     10.0   2    1       4      -4        -1.0
# 10      32   46  70.0  297      7.0   1    0       0       0         0.0
# 11      20   26  77.0  211      8.0   2    0       5      13         3.0
# 12      23   31  74.0  236      8.0   2    0       2       1         1.0
# 13      21   33  64.0  258      8.0   1    2       4      20         5.0
# 14      22   40  55.0  245      6.0   2    1       2       4         2.0
# 15      29   56  52.0  317      6.0   2    4       7      32         5.0
# 16      18   32  56.0  195      6.0   3    3       2       8         4.0
# 17      20   31  65.0  266      9.0   1    0       4      -2        -1.0
# 18      24   33  73.0  231      7.0   1    0       1      -2        -2.0
# 19      21   32  66.0  213      7.0   1    0       0       0         0.0
# 20      23   33  70.0  303      9.0   1    2       5       4         1.0
# 21      32   48  67.0  355      7.0   1    3       0       0         0.0
# 22      17   25  68.0  198      8.0   1    0       2       2         1.0
# 23      16   24  67.0  138      6.0   1    0       7      13         2.0
# 24      23   32  72.0  229      7.0   1    1       2      11         6.0
# 25      23   45  51.0  309      7.0   1    3       2       9         5.0
# 26      20   27  74.0  270     10.0   0    0       1       1         1.0
# 27      18   34  53.0  153      5.0   1    1       8      20         3.0
# 28       6    8  75.0   66      8.0   1    0       1      -1        -1.0
# 29      22   37  60.0  221      6.0   0    1       3      11         4.0
# ...    ...  ...   ...  ...      ...  ..  ...     ...     ...         ...
# 2699    20   31  64.5  242      7.8   4    0      14      58         4.1
# 2700    22   30  73.3  281      9.4   2    1       3      10         3.3
# 2701    37   57  64.9  434      7.6   3    1       0       0         0.0
# 2702    32   50  64.0  382      7.6   2    3       5      31         6.2
# 2703    22   36  61.1  288      8.0   1    1       2       7         3.5
# 2704    14   23  60.9  193      8.4   0    0       7      44         6.3
# 2705    19   38  50.0  286      7.5   1    0       2      -1        -0.5
# 2706    22   40  55.0  290      7.2   1    0       1       0         0.0
# 2707    25   39  64.1  304      7.8   1    0       4      13         3.2
# 2708    22   38  57.9  301      7.9   4    0       3      -6        -2.0
# 2709    20   29  69.0  226      7.8   2    0       1      -1        -1.0
# 2710    21   30  70.0  242      8.1   2    1       3       3         1.0
# 2711    21   28  75.0  224      8.0   2    1       2       6         3.0
# 2712    19   37  51.4  299      8.1   3    1       5       8         1.6
# 2713    29   38  76.3  237      6.2   2    0       4      -2        -0.5
# 2714    16   25  64.0  160      6.4   0    1      14      52         3.7
# 2715    21   27  77.8  367     13.6   1    0       3       6         2.0
# 2716    25   47  53.2  203      4.3   2    1       0       0         0.0
# 2717    28   51  54.9  363      7.1   1    3       5      32         6.4
# 2718    23   44  52.3  222      5.0   3    0       2      -2        -1.0
# 2719    20   33  60.6  292      8.8   2    2       2      -1        -0.5
# 2720    18   29  62.1  221      7.6   2    0       5      36         7.2
# 2721    29   42  69.0  265      6.3   1    1       4       8         2.0
# 2722    20   29  69.0  323     11.1   3    0       2       2         1.0
# 2723    21   31  67.7  254      8.2   2    2       3      13         4.3
# 2724    28   37  75.7  387     10.5   3    0       1       5         5.0
# 2725    18   37  48.6  190      5.1   2    0       0       0         0.0
# 2726    19   27  70.4  204      7.6   1    0       6      35         5.8
# 2727    28   45  62.2  317      7.0   1    0       3      14         4.7
# 2728    16   30  53.3  314     10.5   2    1       6      61        10.2
#
#       ru_td  points  year  ru_att2  ru_yds2
# 0         1   32.46  2012        1      625
# 1         0   25.00  2012        0     1764
# 2         0   23.48  2012        0      144
# 3         0   22.82  2012        0      729
# 4         0   21.56  2012        0        0
# 5         0   20.64  2012        0        0
# 6         0   20.42  2012        0        9
# 7         0   19.86  2012        0        1
# 8         0   19.00  2012        0       36
# 9         0   18.92  2012        0       16
# 10        0   17.88  2012        0        0
# 11        0   17.74  2012        0      169
# 12        0   17.54  2012        0        1
# 13        1   16.32  2012        1      400
# 14        0   16.20  2012        0       16
# 15        0   15.88  2012        0     1024
# 16        0   14.60  2012        0       64
# 17        0   14.44  2012        0        4
# 18        0   13.04  2012        0        4
# 19        0   12.52  2012        0        0
# 20        0   12.52  2012        0       16
# 21        0   12.50  2012        0        0
# 22        0   12.12  2012        0        4
# 23        0   10.82  2012        0      169
# 24        0   10.26  2012        0      121
# 25        0    9.26  2012        0       81
# 26        0    8.90  2012        0        1
# 27        0    8.12  2012        0      400
# 28        0    6.54  2012        0        1
# 29        0    5.94  2012        0      121
# ...     ...     ...   ...      ...      ...
# 2699      0   31.48  2017        0     3364
# 2700      0   19.24  2017        0      100
# 2701      0   31.36  2017        0        0
# 2702      0   28.38  2017        0      961
# 2703      0   15.22  2017        0       49
# 2704      1   18.12  2017        1     1936
# 2705      0   15.34  2017        0        1
# 2706      0   15.60  2017        0        0
# 2707      0   20.46  2017        0      169
# 2708      0   29.44  2017        0       36
# 2709      0   16.94  2017        0        1
# 2710      1   22.98  2017        1        9
# 2711      0   16.56  2017        0       36
# 2712      0   23.76  2017        0       64
# 2713      0   17.28  2017        0        4
# 2714      1   16.60  2017        1     2704
# 2715      0   19.28  2017        0       36
# 2716      0   15.12  2017        0        0
# 2717      1   29.72  2017        1     1024
# 2718      0   20.68  2017        0        4
# 2719      0   17.58  2017        0        1
# 2720      0   20.44  2017        0     1296
# 2721      1   20.40  2017        1       64
# 2722      0   30.12  2017        0        4
# 2723      0   16.46  2017        0      169
# 2724      0   30.98  2017        0       25
# 2725      0   15.60  2017        0        0
# 2726      0   15.66  2017        0     1225
# 2727      0   21.08  2017        0      196
# 2728      0   28.66  2017        0     3721
#
# [2729 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
qb_temp = qb[qb.columns[4:]]

# %%
#A function that will covert a time series database into a supervised learning database

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
reframed = series_to_supervised(qb_temp,1,1)
reframed.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1       23.0       31.0       74.0      299.0       10.0        3.0
# 2       19.0       26.0       73.0      320.0       12.0        2.0
# 3       22.0       29.0       76.0      307.0       11.0        3.0
# 4       30.0       44.0       68.0      303.0        7.0        2.0
# 5       24.0       52.0       46.0      339.0        7.0        3.0
#
#    var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)    ...     var6(t)  var7(t)  \
# 1        0.0        3.0       25.0         8.0    ...           2        0
# 2        0.0        9.0       42.0         5.0    ...           3        1
# 3        1.0        5.0       12.0         2.0    ...           2        1
# 4        1.0        5.0       27.0         5.0    ...           3        2
# 5        2.0        0.0        0.0         0.0    ...           3        1
#
#    var8(t)  var9(t)  var10(t)  var11(t)  var12(t)  var13(t)  var14(t)  \
# 1        9       42       5.0         0     25.00      2012         0
# 2        5       12       2.0         0     23.48      2012         0
# 3        5       27       5.0         0     22.82      2012         0
# 4        0        0       0.0         0     21.56      2012         0
# 5        0        0       0.0         0     20.64      2012         0
#
#    var15(t)
# 1      1764
# 2       144
# 3       729
# 4         0
# 5         0
#
# [5 rows x 30 columns]

# %%
train  = qb[qb['year']!=2017]
test = qb[qb['year']==2017]

# %%
y_test = train['points']
X_test = test['points']

# %%
train = train.drop('points', axis=1)
test = test.drop('points', axis=1)

# %%
X_train = train[train.columns[4:]]
X_test = test[test.columns[4:]]

# %%
X_train = X_train.drop('ru_yds2')

# %%
X_train.head()
# Out:
#    Comp  Att   Pct  Yds  Yds/Att  TD  Int  ru_att  ru_yds  yds/ru_att  ru_td  \
# 0    23   31  74.0  299     10.0   3    0       3      25         8.0      1
# 1    19   26  73.0  320     12.0   2    0       9      42         5.0      0
# 2    22   29  76.0  307     11.0   3    1       5      12         2.0      0
# 3    30   44  68.0  303      7.0   2    1       5      27         5.0      0
# 4    24   52  46.0  339      7.0   3    2       0       0         0.0      0
#
#    year  ru_att2  ru_yds2
# 0  2012        1      625
# 1  2012        0     1764
# 2  2012        0      144
# 3  2012        0      729
# 4  2012        0        0

# %%
df = X_train.values.astype('float32')

# %%
reframed = series_to_supervised(X_test.values.astype('float32'),1,1)

# %%
test = qb_temp[qb_t['year']==2017]

# %%
test.columns
# Out:
# Index(['Comp', 'Att', 'Pct', 'Yds', 'Yds/Att', 'TD', 'Int', 'ru_att', 'ru_yds',
#        'yds/ru_att', 'ru_td', 'points', 'year', 'ru_att2', 'ru_yds2'],
#       dtype='object')

# %%
y_train = train['points']
y_test = test['points']
X_train = train.drop('points',axis=1)
X_test = test.drop('points', axis=1)

# %%
y_test.shape
# Out:
# (2429,)

# %%
y_test.head()
# Out:
# 2429    17.12
# 2430    19.58
# 2431    28.54
# 2432    20.54
# 2433    15.64
# Name: points, dtype: float64

# %%
X_train.head()
# Out:
#    Comp  Att   Pct  Yds  Yds/Att  TD  Int  ru_att  ru_yds  yds/ru_att  ru_td  \
# 0    23   31  74.0  299     10.0   3    0       3      25         8.0      1
# 1    19   26  73.0  320     12.0   2    0       9      42         5.0      0
# 2    22   29  76.0  307     11.0   3    1       5      12         2.0      0
# 3    30   44  68.0  303      7.0   2    1       5      27         5.0      0
# 4    24   52  46.0  339      7.0   3    2       0       0         0.0      0
#
#    year  ru_att2  ru_yds2
# 0  2012        1      625
# 1  2012        0     1764
# 2  2012        0      144
# 3  2012        0      729
# 4  2012        0        0

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yhat = lr.predict(X_test)
yhat.shape
# Out:
# (300,)

# %%
y_test.shape
# Out:
# (300,)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y)
print("RMSE error is: " + str(rmse_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-219-a0497114bdf0> in <module>()
#       2     return np.sqrt(((predictions - targets) ** 2).mean())
#       3
# ----> 4 rmse_val = rmse(yhat, y)
#       5 print("RMSE error is: " + str(rmse_val))
#
# NameError: name 'y' is not defined

# %%
qb[qb['year']==2017]['Player']
# Out:
# 2429          Dak Prescott
# 2430         Deshone Kizer
# 2431          Sam Bradford
# 2432         Aaron Rodgers
# 2433            Drew Brees
# 2434          Tyrod Taylor
# 2435            Jared Goff
# 2436             Matt Ryan
# 2437          Carson Wentz
# 2438            Alex Smith
# 2439      Matthew Stafford
# 2440         Philip Rivers
# 2441            Derek Carr
# 2442    Ben Roethlisberger
# 2443        Marcus Mariota
# 2444        Trevor Siemian
# 2445         Philip Rivers
# 2446         Carson Palmer
# 2447    Ben Roethlisberger
# 2448        Deshaun Watson
# 2449          Carson Wentz
# 2450           Josh McCown
# 2451            Drew Brees
# 2452        Trevor Siemian
# 2453          Mike Glennon
# 2454            Alex Smith
# 2455            Derek Carr
# 2456          Dak Prescott
# 2457            Joe Flacco
# 2458        Russell Wilson
#                ...
# 2699            Cam Newton
# 2700    Ben Roethlisberger
# 2701           Eli Manning
# 2702         Blake Bortles
# 2703             Matt Ryan
# 2704        Mitch Trubisky
# 2705            Jay Cutler
# 2706         Philip Rivers
# 2707            Alex Smith
# 2708            Jared Goff
# 2709    Ben Roethlisberger
# 2710       Jimmy Garoppolo
# 2711             Tom Brady
# 2712          Kirk Cousins
# 2713            Joe Flacco
# 2714            Cam Newton
# 2715        Jameis Winston
# 2716            Joe Flacco
# 2717        Jameis Winston
# 2718           Andy Dalton
# 2719       Jimmy Garoppolo
# 2720        Russell Wilson
# 2721           David Fales
# 2722      Matthew Stafford
# 2723          Paxton Lynch
# 2724         Philip Rivers
# 2725             Tom Brady
# 2726          Tyrod Taylor
# 2727             Matt Ryan
# 2728         Deshone Kizer
# Name: Player, Length: 300, dtype: object

# %%
results = pd.DataFrame()
results['Player'] = qb[qb['year']==2017]['Player']
results['score'] = y_test
results['Predicted'] = yhat
results.groupby('Player').mean()[['score','Predicted']]
# Out:
#                         score  Predicted
# Player
# Aaron Rodgers       24.146667  24.697428
# Alex Smith          24.120000  25.196656
# Andy Dalton         19.657778  21.516429
# Ben Roethlisberger  21.794545  23.016664
# Blaine Gabbert      20.460000  21.372105
# Blake Bortles       23.237778  23.396685
# Brett Hundley       22.033333  23.847635
# Brian Hoyer         27.650000  27.671779
# Brock Osweiler      20.510000  20.840111
# CJ Beathard         20.260000  22.697145
# Cam Newton          24.714000  25.424445
# Carson Palmer       20.504000  21.254254
# Carson Wentz        24.208333  24.691966
# Case Keenum         22.780000  24.021963
# Dak Prescott        22.207273  23.580420
# David Fales         20.400000  22.024247
# Derek Carr          19.877500  21.306177
# Deshaun Watson      29.363333  29.601788
# Deshone Kizer       20.917500  22.098968
# Drew Brees          20.593333  22.064709
# Drew Stanton        15.130000  16.856196
# Eli Manning         22.406667  24.308359
# Jacoby Brissett     21.348000  22.211978
# Jameis Winston      23.620000  24.654429
# Jared Goff          22.622000  23.735243
# Jay Cutler          19.324000  20.778160
# Jimmy Garoppolo     20.565000  21.548240
# Joe Flacco          17.622857  19.364701
# Josh McCown         22.565000  23.517490
# Kevin Hogan         17.760000  18.589174
# Kirk Cousins        24.300000  25.039329
# Marcus Mariota      18.620000  19.336863
# Matt Moore          15.280000  17.917269
# Matt Ryan           17.820000  19.135471
# Matthew Stafford    21.308333  22.786979
# Mike Glennon        16.040000  16.105972
# Mitch Trubisky      17.532000  19.026980
# Nick Foles          25.480000  27.340966
# Paxton Lynch        16.460000  18.942123
# Philip Rivers       21.420000  22.657632
# Russell Wilson      26.823333  27.883829
# Ryan Fitzpatrick    21.350000  23.475450
# Sam Bradford        28.540000  28.779954
# TJ Yates            18.100000  19.407776
# Tom Brady           22.581538  23.620024
# Tom Savage          18.000000  19.375831
# Trevor Siemian      21.025000  22.168720
# Tyrod Taylor        20.017500  21.752477
