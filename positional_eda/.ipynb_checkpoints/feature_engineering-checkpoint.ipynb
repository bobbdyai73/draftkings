# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
rb = pd.read_csv('../input/rb/rb_loc_cleaned.csv')

# %%
rb.dtypes
# Out:
# year           int64
# Name          object
# Team          object
# Week           int64
# Opponent      object
# att            int64
# yds            int64
# td             int64
# tar            int64
# rec_yds        int64
# def_rk         int64
# h/a_1        float64
# surface_0    float64
# salary         int64
# points       float64
# dtype: object

# %%
rb['salary'] = rb['salary'].replace('null', 0)

# %%
def create_sorted_dict (df):
    df_sorted = df.sort_values(['year','Name','Week','Opponent'])
    sorted_dict = {}
    for player in df_sorted['Name']:
        sorted_dict['{}'.format(player)] = {'year':df_sorted[df_sorted['Name']==player]['year'],
                                            'points':df_sorted[df_sorted['Name']==player]['points'],
                                            'def_rk':df_sorted[df_sorted['Name']==player]['def_rk'],
                                            'surface_0':df_sorted[df_sorted['Name']==player]['surface_0'],
                                            'h/a_1':df_sorted[df_sorted['Name']== player]['h/a_1'],
                                            'salary':df_sorted[df_sorted['Name']==player]['salary']
                                           }
       
    return sorted_dict

# %%
rb_sorted_dict = create_sorted_dict(rb)

# %%
rb_sorted_dict.keys()
# Out:
# dict_keys(['Adrian Peterson', 'Ahmad Bradshaw', 'Akeem Hunt', 'Alfred Blue', 'Alfred Morris', 'Alonzo Harris', 'Ameer Abdullah', 'Andre Ellington', 'Andre Williams', 'Anthony Dixon', 'Anthony Sherman', 'Antone Smith', 'Antonio Andrews', 'Arian Foster', 'Austin Johnson', 'Benjamin Cunningham', 'Bernard Pierce', 'Bilal Powell', 'Bishop Sankey', 'Bobby Rainey', 'Branden Oliver', 'Brandon Bolden', 'Bruce Miller', 'Bryce Brown', 'CJ Anderson', 'CJ Spiller', 'Cameron Artis-Payne', 'Carlos Hyde', 'Charcandrick West', 'Charles Sims', 'Chris Ivory', 'Chris Johnson', 'Chris Polk', 'Chris Thompson', 'Christine Michael', 'Cierre Wood', 'Corey Grant', 'Damien Williams', 'Dan Herron', 'Danny Woodhead', 'Darrel Young', 'Darren McFadden', 'Darren Sproles', 'David Cobb', 'David Johnson', 'DeAngelo Williams', 'DeMarco Murray', 'Denard Robinson', 'Derrick Coleman', 'Devonta Freeman', 'Dexter McCluster', 'Dion Lewis', 'Donald Brown', 'Doug Martin', 'DuJuan Harris', 'Duke Johnson', 'Eddie Lacy', 'Fitzgerald Toussaint', 'Fozzy Whittaker', 'Frank Gore', 'Fred Jackson', 'George Winn', 'Giovani Bernard', 'Glenn Winston', 'Isaiah Crowell', 'Isaiah Pead', 'Jacquizz Rodgers', 'Jalston Fowler', 'Jamaal Charles', 'James Starks', 'James White', 'Jamize Olawale', 'Jarryd Hayne', 'Javorius Allen', 'Jay Ajayi', 'Jay Prosch', 'Jeremy Hill', 'Jeremy Langford', 'Jerick McKinnon', 'Jerome Felton', 'Joey Iosefa', 'John Crockett', 'John Kuhn', 'Joique Bell', 'Jonas Gray', 'Jonathan Grimes', 'Jonathan Stewart', 'Jordan Todman', 'Jorvorskie Lane', 'Joseph Randle', 'Josh Robinson', 'Justin Forsett', 'Juwan Thompson', "Ka'Deem Carey", 'Karlos Williams', 'Kendall Gaskins', 'Kendall Hunter', 'Kenjon Barner', 'Kerwynn Williams', 'Khiry Robinson', 'Knile Davis', 'Kyle Juszczyk', 'Lamar Miller', 'Lance Dunbar', 'Latavius Murray', "Le'Veon Bell", 'LeGarrette Blount', 'LeSean McCoy', 'Lorenzo Taliaferro', 'Malcolm Brown', 'Marcel Reece', 'Marcus Murphy', 'Marcus Thigpen', 'Mark Ingram', 'Marshawn Lynch', 'Matt Asiata', 'Matt Forte', 'Matt Jones', 'Melvin Gordon', 'Michael Burton', 'Mike Davis', 'Mike Gillislee', 'Mike Tolbert', 'Orleans Darkwa', 'Patrick DiMarco', 'Pierre Thomas', 'Rashad Jennings', 'Reggie Bush', 'Rex Burkhead', 'Robert Turbin', 'Rod Smith', 'Ronnie Hillman', 'Roy Helu', 'Ryan Mathews', 'Shane Vereen', 'Shaun Draughn', 'Spencer Ware', 'Stepfan Taylor', 'Stevan Ridley', 'Steven Jackson', 'TJ Yeldon', 'Taiwan Jones', 'Terrance West', 'Terrence Magee', 'Terron Ward', 'Tevin Coleman', 'Theo Riddick', 'Thomas Rawls', 'Tim Hightower', 'Toby Gerhart', 'Todd Gurley', 'Tommy Bohanon', 'Travaris Cadet', 'Tre Mason', 'Trey Williams', 'Ty Montgomery', 'Tyler Varga', 'Will Johnson', 'Will Tukuafu', 'Zac Stacy', 'Zach Line', 'Zach Zenner', 'Zurlon Tipton', 'Aaron Ripkowski', 'Alex Collins', 'Andy Janovich', 'Brandon Burks', 'Brandon Wilds', 'Bronson Hill', 'Byron Marshall', 'CJ Prosise', 'Cedric Peerman', 'DJ Foster', 'Daniel Lasco', 'Daryl Richardson', 'Deandre Washington', 'Derek Watt', 'Derrick Henry', 'Devontae Booker', 'Don Jackson', 'Dwayne Washington', 'Ezekiel Elliott', 'George Atkinson', 'JD McKissic', 'Jalen Richard', 'Joe Banyard', 'Joe Kerridge', 'Jonathan Williams', 'Jordan Howard', 'Josh Ferguson', 'Kapri Bibbs', 'Keith Smith', 'Kenneth Dixon', 'Kenneth Farrow', 'Kenyan Drake', 'Mack Brown', 'Malcolm Johnson', 'Mike James', 'Paul Lasike', 'Paul Perkins', 'Peyton Barber', 'Raheem Mostert', 'Rob Kelley', 'Terrell Watson', 'Troymaine Pope', 'Tyler Ervin', 'Wendell Smallwood', 'Aaron Jones', 'Alvin Kamara', 'Austin Ekeler', 'Brian Hill', 'CJ Ham', 'Chris Carson', 'Christian McCaffrey', 'Corey Clement', "D'Onta Foreman", 'Dalvin Cook', 'David Fluellen', "De'Angelo Henderson", 'Devante Mays', 'Elijah McGuire', 'Elijhaa Penny', 'Jamaal Williams', 'James Conner', 'Joe Mixon', 'Justin Davis', 'Kareem Hunt', 'Lawrence Thomas', 'Leonard Fournette', 'Leshun Daniels Jr.', 'Marlon Mack', 'Matt Breida', 'Matt Dayes', 'Roosevelt Nix', 'Samaje Perine', 'Senorise Perry', 'Tari ...

# %%
rb_sorted_dict['Jordan Howard']['points']
# Out:
# 1374     5.1
# 1445    13.2
# 1506    19.2
# 1564    28.3
# 3903    12.0
# 1690     2.2
# 1742    33.2
# 1849    12.0
# 1905    10.9
# 1970    15.7
# 2031    32.7
# 4011    13.0
# 2161    21.3
# 4033    16.8
# 2296    16.5
# 2361    15.6
# 2433     0.7
# 2509    35.6
# 4078    14.3
# 2656     7.6
# 2721    21.6
# 2787     6.5
# 2842    18.1
# 2969     5.4
# 3029    21.5
# 3093     3.9
# 3159     4.3
# 3225    31.5
# 3295    10.3
# 3362    16.4
# 3427     2.4
# 3498    15.7
# 3573     9.8
# 3638    16.1
# 3704     2.5
# Name: points, dtype: float64

# %%
# Create a data frame to investigate the points attribute of the dataset. 


def get_points_df(df):
    total_points = df['points'].sum()
    total_games = df['points'].count()

    val_lst = []
    sal_lst = []
    games_lst = []
    wght_avg=[]
    players = []
    avg_lst=[]

    for name in list(df['Name'].unique()):
        players.append(name)
        player_games = df[df['Name'] ==name].describe().loc['count'][0]
        games_lst.append(player_games)
        avg_points = round(df[df['Name'] ==name].describe()['points'].mean(),2)
        avg_lst.append(avg_points)
        wght_avg.append((round(avg_points + (avg_points* (player_games/total_games)),2)))
        sal_avg= round(df[df['Name'] ==name].describe()['salary'].mean(),2)
        sal_lst.append(sal_avg)
        val = round(sal_avg/avg_points,2)
        val_lst.append(val)
     
    df_eng = pd.DataFrame()
    df_eng['player'] = (df['Name'].unique())
    df_eng['games'] = games_lst
    df_eng['avg_points']= avg_lst
    df_eng['wght_avg'] = wght_avg
    df_eng['sal_avg'] = sal_lst
    df_eng['val'] = val_lst
    df_eng.head()
    
    return df_eng

# %%
rb_points = get_points_df(rb)

# %%
rb_points.to_csv('../input/rb/rb_points.csv', index=False)

# %% [markdown]
# ## Group Dataframes

# %%
# A function to create a dictonary of grouped data frames

def grouped_dict(csv):
    
    df= pd.read_csv(csv)
    

    yearly_dict = {}
    for year in list(df['year'].unique()):
        yearly_dict['player_{}'.format(year)] = (df[df['year']==year]).drop('year',axis=1).groupby(['Name','Week','Opponent']).sum()
        yearly_dict['player_{}'.format(year)]


    return yearly_dict

# %%
def conv_atts(df):
    df['salary'] = df['salary'].apply(lambda x: int(x))
    df['h/a_1'] = df['h/a_1'].astype('category')
    df['surface_0'] = df['surface_0'].astype('category')
    df['def_rk'] = df['def_rk'].astype('category')

    return df

# %%
rb_group = grouped_dict('../input/rb/rb_loc_cleaned.csv')
rb = conv_atts(rb)
rb.dtypes
# Out:
# year            int64
# Name           object
# Team           object
# Week            int64
# Opponent       object
# att             int64
# yds             int64
# td              int64
# tar             int64
# rec_yds         int64
# def_rk       category
# h/a_1        category
# surface_0    category
# salary          int64
# points        float64
# dtype: object

# %%
rb_group['player_2015'].columns
# Out:
# Index(['att', 'yds', 'td', 'tar', 'rec_yds', 'def_rk', 'h/a_1', 'surface_0',
#        'salary', 'points'],
#       dtype='object')

# %%
def drop_col (grouped_df):
    for group in grouped_df:
        grouped_df[group].drop('def_rk', axis=1,inplace=True)
        grouped_df[group].drop('h/a_1', axis=1, inplace=True)
        grouped_df[group].drop('surface_0',axis=1, inplace=True)
        grouped_df[group].drop('salary',axis=1, inplace=True)
        grouped_df[group].drop('points',axis=1, inplace=True)
    return grouped_df

# %%
rb = drop_col(rb_group)
rb['player_2015'].columns
# Out:
# Index(['att', 'yds', 'td', 'tar', 'rec_yds'], dtype='object')

# %% [markdown]
# ## Career Average

# %%
# Week 1 stats are player's career average through 2014 season
# Populate current dataframe with current year averages of players

def career_average (grouped_df1, grouped_df2=None):
    new_grouped_df1 = pd.DataFrame(index= grouped_df1.index)
    for col in grouped_df1: # Iterate through every attribute in the team_stats dataframe
        points=[]  # Create an empty list to hold the season average of the current attribute

        try:
            for player in grouped_df1.index.levels[0]:  # Iterate through every player in the team_stats df
                if player in list(grouped_df2.index.levels[0].unique()):
                    total =[grouped_df2.loc[player][col][-1]] # If player not a rookie, use final average from 2015
                else:
                    total =[]  # create an empty list to hold the weekly attributes value
                
                for week in grouped_df1.loc[player].index: # Iterate throough every week for the current player
                    total.append(grouped_df1.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                    points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list
                    
            new_grouped_df1['{}_car'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe


                                
        except:
            for player in grouped_df1.index.levels[0]:  # Iterate through every player in the team_stats df
                total = []

                for week in grouped_df1.loc[player].index: # Iterate throough every week for the current player
                    total.append(grouped_df1.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                    points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list

            new_grouped_df1['{}_car'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe
    return new_grouped_df1

# %%
df_career_2015 = career_average(rb_group['player_2015'])
df_career_2016 = career_average(rb_group['player_2016'], rb_group['player_2015'])
df_career_2017 = career_average(rb_group['player_2017'], rb_group['player_2016'])
df_career_2018 = career_average(rb_group['player_2018'], rb_group['player_2017'])

# %%
player_career = pd.concat([df_career_2015, df_career_2016])
player_career = pd.concat([player_career, df_career_2017])
player_career = pd.concat([player_career, df_career_2018])

# %%
player_stats = pd.concat([rb_group['player_2015'],rb_group['player_2016']])
player_stats = pd.concat([player_stats,rb_group['player_2017']])
player_stats = pd.concat([player_stats,rb_group['player_2018']])
player_stats.tail()
# Out:
#                                  att  yds  td  tar  rec_yds
# Name              Week Opponent
# Wayne Gallman     3    HOU         6   25   0    1        0
#                   4    NO          2    6   0    3       17
# Wendell Smallwood 2    TB          7   28   0    1        2
#                   3    IND        10   56   1    5       35
#                   4    TEN         5   39   0    5       15

# %%
rb_stats =  player_career

# %%
rb_stats.head()
# Out:
#                                att_car  yds_car  td_car  tar_car  rec_yds_car
# Name            Week Opponent
# Adrian Peterson 1    SF          10.00     31.0    0.00     3.00        21.00
#                 2    DET         19.50     82.5    0.00     2.50        39.50
#                 3    LAC         19.67     97.0    0.67     1.67        26.33
#                 4    DEN         18.75     93.0    0.75     2.75        23.00
#                 6    KC          20.20     86.4    0.60     2.40        17.80

# %% [markdown]
# ## Recent Player Stats
# Calculate the 4 game moving average of all attributes for each player and insert resluts into positional dataframe

# %%
# A function designed to calcuate a player's 4 game moving average in seasons 2015,2016,2017,2018

def moving_average(grouped_df, games):
    new_grouped_df = pd.DataFrame(index = grouped_df.index)
    for col in grouped_df:  # Iterate through every attribute in the team_stats dataframe
        ma4 = []  # Create an empty list to hold the season average of the current attribute
        for player in grouped_df.index.levels[0]:  # Iterate through every player in the team_stats df
            total = [] # INstantiate a deque container with a max length of 3 to hold the three most current games for player
            count = 0 # Counter to track week number 
            for week in grouped_df.loc[player].index: # Iterate through every week for relevant player d
                if count < games: # check count value to start 3 game moving average
                    ma4.append(0)  # week 1 through 3 have 3 game movong average of 0
                    total.append(grouped_df.loc[player].loc[week][col])  # Add the value current player's attribute total from the left
                    count += 1  # Increase count
                else:  # Once 3 game moving average is avaliable
                    ma4.append(np.mean(total))  # Add the average of the 3 games held in totals 3 game moivng average list
                    total.append(grouped_df.loc[player].loc[week][col]) # Replace 3 set block with a first in first out process
        new_grouped_df['{}_ma'.format(col.lower())] = ma4  # Populate databse with 3 game moving average list
       

    return new_grouped_df

# %%
player_ma_2015 = moving_average(rb_group['player_2015'],4)
player_ma_2016 = moving_average(rb_group['player_2016'],4)
player_ma_2017 = moving_average(rb_group['player_2017'],4)
player_ma_2018 = moving_average(rb_group['player_2018'],4)

# %%
player_yearly_ma = pd.concat([player_ma_2015, player_ma_2016])
player_yearly_ma = pd.concat([player_yearly_ma,player_ma_2017])
player_yearly_ma = pd.concat([player_yearly_ma,player_ma_2018])

# %%
rb_stats = pd.concat([player_yearly_ma,player_career], axis=1)
rb_stats.head()
# Out:
#                                att_ma  yds_ma  td_ma  tar_ma  rec_yds_ma  \
# Name            Week Opponent
# Adrian Peterson 1    SF          0.00     0.0   0.00    0.00         0.0
#                 2    DET         0.00     0.0   0.00    0.00         0.0
#                 3    LAC         0.00     0.0   0.00    0.00         0.0
#                 4    DEN         0.00     0.0   0.00    0.00         0.0
#                 6    KC         18.75    93.0   0.75    2.75        23.0
#
#                                att_car  yds_car  td_car  tar_car  rec_yds_car
# Name            Week Opponent
# Adrian Peterson 1    SF          10.00     31.0    0.00     3.00        21.00
#                 2    DET         19.50     82.5    0.00     2.50        39.50
#                 3    LAC         19.67     97.0    0.67     1.67        26.33
#                 4    DEN         18.75     93.0    0.75     2.75        23.00
#                 6    KC          20.20     86.4    0.60     2.40        17.80

# %% [markdown]
# ## Current Stats
# Weekly moving average for every year from 2015 through 2018

# %%
# Week 1 stats are player's career average through 2014 season
# Populate current dataframe with current year averages of players

def insert_data (grouped_df):
    new_df = pd.DataFrame(index=grouped_df.index)
    for col in grouped_df: # Iterate through every attribute in the team_stats dataframe
        points=[]  # Create an empty list to hold the season average of the current attribute

        for player in grouped_df.index.levels[0]:  # Iterate through every player in the team_stats df
            total =[]# create an empty list to hold the weekly attributes valu3

            for week in grouped_df.loc[player].index: # Iterate throough every week for the current player
                total.append(grouped_df.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list

        new_df['{}_avg'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe
    return new_df

# %%
rb_week_2015 = insert_data(rb_group['player_2015'])
rb_week_2016 = insert_data(rb_group['player_2016'])
rb_week_2017 = insert_data(rb_group['player_2017'])
rb_week_2018 = insert_data(rb_group['player_2018'])

# %%
rb_week_2015.head()
# Out:
#                                att_avg  yds_avg  td_avg  tar_avg  rec_yds_avg
# Name            Week Opponent
# Adrian Peterson 1    SF          10.00     31.0    0.00     3.00        21.00
#                 2    DET         19.50     82.5    0.00     2.50        39.50
#                 3    LAC         19.67     97.0    0.67     1.67        26.33
#                 4    DEN         18.75     93.0    0.75     2.75        23.00
#                 6    KC          20.20     86.4    0.60     2.40        17.80

# %%
rb_week_2015['year']=2015
rb_week_2016['year']=2016
rb_week_2017['year']=2017
rb_week_2018['year']=2018

# %%
rb_week = pd.concat([rb_week_2015,rb_week_2016])
rb_week = pd.concat([rb_week, rb_week_2017])
rb_week = pd.concat([rb_week, rb_week_2018])

# %%
year = rb_week['year']
year
# Out:
# Name               Week  Opponent
# Adrian Peterson    1     SF          2015
#                    2     DET         2015
#                    3     LAC         2015
#                    4     DEN         2015
#                    6     KC          2015
#                    7     DET         2015
#                    8     CHI         2015
#                    9     LAR         2015
#                    10    OAK         2015
#                    11    GB          2015
#                    12    ATL         2015
#                    13    SEA         2015
#                    14    ARI         2015
#                    15    CHI         2015
#                    16    NYG         2015
#                    17    GB          2015
# Ahmad Bradshaw     6     NE          2015
#                    7     NO          2015
#                    8     CAR         2015
#                    9     DEN         2015
#                    11    ATL         2015
#                    12    TB          2015
# Akeem Hunt         11    NYJ         2015
#                    12    NO          2015
#                    13    BUF         2015
#                    14    NE          2015
#                    15    IND         2015
#                    16    TEN         2015
#                    17    JAX         2015
# Alfred Blue        1     KC          2015
#                                      ...
# TJ Yeldon          2     NE          2018
#                    3     TEN         2018
#                    4     NYJ         2018
# Tarik Cohen        1     GB          2018
#                    2     SEA         2018
#                    3     ARI         2018
#                    4     TB          2018
# Tevin Coleman      1     PHI         2018
#                    2     CAR         2018
#                    3     NO          2018
#                    4     CIN         2018
# Theo Riddick       1     NYJ         2018
#                    4     DAL         2018
# Todd Gurley        1     OAK         2018
#                    2     ARI         2018
#                    3     LAC         2018
#                    4     MIN         2018
# Tre Madden         3     DAL         2018
# Trenton Cannon     1     DET         2018
# Ty Montgomery      1     CHI         2018
#                    2     MIN         2018
#                    3     WAS         2018
#                    4     BUF         2018
# Wayne Gallman      1     JAX         2018
#                    2     DAL         2018
#                    3     HOU         2018
#                    4     NO          2018
# Wendell Smallwood  2     TB          2018
#                    3     IND         2018
#                    4     TEN         2018
# Name: year, Length: 4224, dtype: int64

# %%
cols = rb_week.columns.tolist()
cols = cols[-1:] +cols[:-1]
rb_week = rb_week[cols]
rb_week.head()
# Out:
#                                year  att_avg  yds_avg  td_avg  tar_avg  \
# Name            Week Opponent
# Adrian Peterson 1    SF        2015    10.00     31.0    0.00     3.00
#                 2    DET       2015    19.50     82.5    0.00     2.50
#                 3    LAC       2015    19.67     97.0    0.67     1.67
#                 4    DEN       2015    18.75     93.0    0.75     2.75
#                 6    KC        2015    20.20     86.4    0.60     2.40
#
#                                rec_yds_avg
# Name            Week Opponent
# Adrian Peterson 1    SF              21.00
#                 2    DET             39.50
#                 3    LAC             26.33
#                 4    DEN             23.00
#                 6    KC              17.80

# %%
rb_stats = pd.concat([rb_week, rb_stats],axis=1)
rb_stats.head()
# Out:
#                                year  att_avg  yds_avg  td_avg  tar_avg  \
# Name            Week Opponent
# Adrian Peterson 1    SF        2015    10.00     31.0    0.00     3.00
#                 2    DET       2015    19.50     82.5    0.00     2.50
#                 3    LAC       2015    19.67     97.0    0.67     1.67
#                 4    DEN       2015    18.75     93.0    0.75     2.75
#                 6    KC        2015    20.20     86.4    0.60     2.40
#
#                                rec_yds_avg  att_ma  yds_ma  td_ma  tar_ma  \
# Name            Week Opponent
# Adrian Peterson 1    SF              21.00    0.00     0.0   0.00    0.00
#                 2    DET             39.50    0.00     0.0   0.00    0.00
#                 3    LAC             26.33    0.00     0.0   0.00    0.00
#                 4    DEN             23.00    0.00     0.0   0.00    0.00
#                 6    KC              17.80   18.75    93.0   0.75    2.75
#
#                                rec_yds_ma  att_car  yds_car  td_car  tar_car  \
# Name            Week Opponent
# Adrian Peterson 1    SF               0.0    10.00     31.0    0.00     3.00
#                 2    DET              0.0    19.50     82.5    0.00     2.50
#                 3    LAC              0.0    19.67     97.0    0.67     1.67
#                 4    DEN              0.0    18.75     93.0    0.75     2.75
#                 6    KC              23.0    20.20     86.4    0.60     2.40
#
#                                rec_yds_car
# Name            Week Opponent
# Adrian Peterson 1    SF              21.00
#                 2    DET             39.50
#                 3    LAC             26.33
#                 4    DEN             23.00
#                 6    KC              17.80

# %%
rb_stats.drop('year', axis=1, inplace=True)

# %%
rb_stats.columns
# Out:
# Index(['att_avg', 'yds_avg', 'td_avg', 'tar_avg', 'rec_yds_avg', 'att_ma',
#        'yds_ma', 'td_ma', 'tar_ma', 'rec_yds_ma', 'att_car', 'yds_car',
#        'td_car', 'tar_car', 'rec_yds_car'],
#       dtype='object')

# %%
#A function that will covert a time series database into a supervised learning database

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
rb_stats.loc['Jordan Howard'].head()
# Out:
#                att_avg  yds_avg  td_avg  tar_avg  rec_yds_avg  att_ma  yds_ma  \
# Week Opponent
# 2    PHI          3.00    22.00     0.0     2.00         9.00    0.00     0.0
# 3    DAL          6.00    33.50     0.0     4.00        28.00    0.00     0.0
# 4    DET         11.67    59.33     0.0     4.00        25.67    0.00     0.0
# 5    IND         12.75    74.00     0.0     3.75        30.50    0.00     0.0
# 6    JAX         13.20    66.00     0.2     3.80        25.60   12.75    74.0
#
#                td_ma  tar_ma  rec_yds_ma  att_car  yds_car  td_car  tar_car  \
# Week Opponent
# 2    PHI         0.0    0.00         0.0     3.00    22.00     0.0     2.00
# 3    DAL         0.0    0.00         0.0     6.00    33.50     0.0     4.00
# 4    DET         0.0    0.00         0.0    11.67    59.33     0.0     4.00
# 5    IND         0.0    0.00         0.0    12.75    74.00     0.0     3.75
# 6    JAX         0.0    3.75        30.5    13.20    66.00     0.2     3.80
#
#                rec_yds_car
# Week Opponent
# 2    PHI              9.00
# 3    DAL             28.00
# 4    DET             25.67
# 5    IND             30.50
# 6    JAX             25.60

# %%
points_dict = {}
reframed_dict = {}
for player in rb_stats.index.levels[0]:
    #points_dict['{}'.format(player)]['points'] = qb_stats.loc[player]['points'][0]
    #points_dict['{}'.format(player)]['def_rk'] = qb_stats.loc[player]['def_rk']
    #points_dict['{}'.format(player)]['h/a_1'] = qb_stats.loc[player]['h/a_1']
    #points_dict['{}'.format(player)]['surface_0']= qb_stats.loc[player]['surface_0']
    #points_dict['{}'.format(player)]['salary']=qb_stats.loc[player]['salary']
    #rop_list = ['points','def_rk','h/a_1','surface_0','salary']
    #qb_stats.drop(drop_list, axis=1, inplace=True)
    reframed_dict['{}_reframed'.format(player)]= series_to_supervised(rb_stats.loc[player])

# %%
reframed_dict.keys()
# Out:
# dict_keys(['Aaron Jones_reframed', 'Aaron Ripkowski_reframed', 'Adrian Peterson_reframed', 'Ahmad Bradshaw_reframed', 'Akeem Hunt_reframed', 'Alex Armah_reframed', 'Alex Collins_reframed', 'Alfred Blue_reframed', 'Alfred Morris_reframed', 'Alonzo Harris_reframed', 'Alvin Kamara_reframed', 'Ameer Abdullah_reframed', 'Andre Ellington_reframed', 'Andre Williams_reframed', 'Andy Janovich_reframed', 'Anthony Dixon_reframed', 'Anthony Sherman_reframed', 'Antone Smith_reframed', 'Antonio Andrews_reframed', 'Arian Foster_reframed', 'Austin Ekeler_reframed', 'Austin Johnson_reframed', 'Benjamin Cunningham_reframed', 'Bernard Pierce_reframed', 'Bilal Powell_reframed', 'Bishop Sankey_reframed', 'Bobby Rainey_reframed', 'Branden Oliver_reframed', 'Brandon Bolden_reframed', 'Brandon Burks_reframed', 'Brandon Wilds_reframed', 'Brian Hill_reframed', 'Bronson Hill_reframed', 'Bruce Miller_reframed', 'Bryce Brown_reframed', 'Byron Marshall_reframed', 'CJ Anderson_reframed', 'CJ Ham_reframed', 'CJ Prosise_reframed', 'CJ Spiller_reframed', 'Cameron Artis-Payne_reframed', 'Carlos Hyde_reframed', 'Cedric Peerman_reframed', 'Charcandrick West_reframed', 'Charles Sims_reframed', 'Chase Edmonds_reframed', 'Chris Carson_reframed', 'Chris Ivory_reframed', 'Chris Johnson_reframed', 'Chris Polk_reframed', 'Chris Thompson_reframed', 'Christian McCaffrey_reframed', 'Christine Michael_reframed', 'Cierre Wood_reframed', 'Corey Clement_reframed', 'Corey Grant_reframed', "D'Onta Foreman_reframed", 'DJ Foster_reframed', 'Dalvin Cook_reframed', 'Damien Williams_reframed', 'Dan Herron_reframed', 'Daniel Lasco_reframed', 'Danny Woodhead_reframed', 'Darrel Young_reframed', 'Darren McFadden_reframed', 'Darren Sproles_reframed', 'Daryl Richardson_reframed', 'David Cobb_reframed', 'David Fluellen_reframed', 'David Johnson_reframed', "De'Angelo Henderson_reframed", "De'Lance Turner_reframed", 'DeAngelo Williams_reframed', 'DeMarco Murray_reframed', 'Deandre Washington_reframed', 'Denard Robinson_reframed', 'Derek Watt_reframed', 'Derrick Coleman_reframed', 'Derrick Henry_reframed', 'Detrez Newsome_reframed', 'Devante Mays_reframed', 'Devonta Freeman_reframed', 'Devontae Booker_reframed', 'Dexter McCluster_reframed', 'Dion Lewis_reframed', 'Don Jackson_reframed', 'Donald Brown_reframed', 'Doug Martin_reframed', 'DuJuan Harris_reframed', 'Duke Johnson_reframed', 'Dwayne Washington_reframed', 'Eddie Lacy_reframed', 'Elijah McGuire_reframed', 'Elijhaa Penny_reframed', 'Ezekiel Elliott_reframed', 'Fitzgerald Toussaint_reframed', 'Fozzy Whittaker_reframed', 'Frank Gore_reframed', 'Fred Jackson_reframed', 'George Atkinson_reframed', 'George Winn_reframed', 'Giovani Bernard_reframed', 'Glenn Winston_reframed', 'Isaiah Crowell_reframed', 'Isaiah Pead_reframed', 'Ito Smith_reframed', 'JD McKissic_reframed', 'Jacquizz Rodgers_reframed', 'Jalen Richard_reframed', 'Jalston Fowler_reframed', 'Jamaal Charles_reframed', 'Jamaal Williams_reframed', 'James Conner_reframed', 'James Starks_reframed', 'James White_reframed', 'Jamize Olawale_reframed', 'Jarryd Hayne_reframed', 'Javorius Allen_reframed', 'Jay Ajayi_reframed', 'Jay Prosch_reframed', 'Jeremy Hill_reframed', 'Jeremy Langford_reframed', 'Jeremy McNichols_reframed', 'Jerick McKinnon_reframed', 'Jerome Felton_reframed', 'Joe Banyard_reframed', 'Joe Kerridge_reframed', 'Joe Mixon_reframed', 'Joey Iosefa_reframed', 'John Crockett_reframed', 'John Kuhn_reframed', 'Joique Bell_reframed', 'Jonas Gray_reframed', 'Jonathan Grimes_reframed', 'Jonathan Stewart_reframed', 'Jonathan Williams_reframed', 'Jordan Howard_reframed', 'Jordan Todman_reframed', 'Jordan Wilkins_reframed', 'Jorvorskie Lane_reframed', 'Joseph Randle_reframed', 'Josh Adams_reframed', 'Josh Ferguson_reframed', 'Josh Robinson_reframed', 'Justin Davis_reframed', 'Justin Forsett_reframed', 'Juwan Thompson_reframed', "Ka'Deem Carey_reframed", 'Kalen Ballage_reframed', 'Kapri Bibbs_reframed', 'Kareem Hunt_reframed', 'Karlos Williams_reframed', 'Keith Smith_reframed', 'Kendall ...

# %%
# A function to insert the non reframed columns back into the stats dataframe 

def insert_non_reframed(df, col_dict):
    non_reframed = ['year','def_rk','h/a_1','surface_0','salary','points']
    for player in df.index.levels[0]:
        for col in non_reframed:
            reframed_dict['{}_reframed'.format(player)][col] = col_dict['{}'.format(player)][col][1:].val

# %%
non_reframed = ['year','def_rk','h/a_1','surface_0','salary','points']
for player in rb_stats.index.levels[0]:
    for col in non_reframed:
        reframed_dict['{}_reframed'.format(player)][col] = rb_sorted_dict['{}'.format(player)][col][1:].value

# %%
reframed_dict['Aaron Jones_reframed']
# Out:
#                var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  \
# Week Opponent
# 5    DAL           13.00      49.00       1.00       0.00       0.00
# 6    MIN           16.00      87.00       1.00       0.50       4.50
# 7    NO            15.00      71.67       0.67       1.67       3.33
# 9    DET           15.50      86.50       0.75       2.50       4.25
# 10   CHI           13.40      71.60       0.60       3.00       3.20
# 13   TB            11.67      61.67       0.50       2.67       2.67
# 14   CLE           10.14      55.71       0.57       2.29       2.29
# 15   CAR            9.38      48.50       0.50       2.00       2.00
# 16   MIN            8.67      48.33       0.44       2.00       2.44
# 3    WAS            8.10      44.80       0.40       1.80       2.20
# 4    BUF            6.00      42.00       0.00       1.00       5.00
#
#                var6(t-1)  var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)  \
# Week Opponent
# 5    DAL        0.000000   0.000000   0.000000   0.000000    0.000000
# 6    MIN        0.000000   0.000000   0.000000   0.000000    0.000000
# 7    NO         0.000000   0.000000   0.000000   0.000000    0.000000
# 9    DET        0.000000   0.000000   0.000000   0.000000    0.000000
# 10   CHI       15.500000  86.500000   0.750000   2.500000    4.250000
# 13   TB        13.400000  71.600000   0.600000   3.000000    3.200000
# 14   CLE       11.666667  61.666667   0.500000   2.666667    2.666667
# 15   CAR       10.142857  55.714286   0.571429   2.285714    2.285714
# 16   MIN        9.375000  48.500000   0.500000   2.000000    2.000000
# 3    WAS        8.666667  48.333333   0.444444   2.000000    2.444444
# 4    BUF        0.000000   0.000000   0.000000   0.000000    0.000000
#
#                  ...       var6(t)    var7(t)   var8(t)   var9(t)  var10(t)  \
# Week Opponent    ...
# 5    DAL         ...      0.000000   0.000000  0.000000  0.000000  0.000000
# 6    MIN         ...      0.000000   0.000000  0.000000  0.000000  0.000000
# 7    NO          ...      0.000000   0.000000  0.000000  0.000000  0.000000
# 9    DET         ...     15.500000  86.500000  0.750000  2.500000  4.250000
# 10   CHI         ...     13.400000  71.600000  0.600000  3.000000  3.200000
# 13   TB          ...     11.666667  61.666667  0.500000  2.666667  2.666667
# 14   CLE         ...     10.142857  55.714286  0.571429  2.285714  2.285714
# 15   CAR         ...      9.375000  48.500000  0.500000  2.000000  2.000000
# 16   MIN         ...      8.666667  48.333333  0.444444  2.000000  2.444444
# 3    WAS         ...      0.000000   0.000000  0.000000  0.000000  0.000000
# 4    BUF         ...      0.000000   0.000000  0.000000  0.000000  0.000000
#
#                var11(t)  var12(t)  var13(t)  var14(t)  var15(t)
# Week Opponent
# 5    DAL          16.00     87.00      1.00      0.50      4.50
# 6    MIN          15.00     71.67      0.67      1.67      3.33
# 7    NO           15.50     86.50      0.75      2.50      4.25
# 9    DET          13.40     71.60      0.60      3.00      3.20
# 10   CHI          11.67     61.67      0.50      2.67      2.67
# 13   TB           10.14     55.71      0.57      2.29      2.29
# 14   CLE           9.38     48.50      0.50      2.00      2.00
# 15   CAR           8.67     48.33      0.44      2.00      2.44
# 16   MIN           8.10     44.80      0.40      1.80      2.20
# 3    WAS           4.50     27.50      0.00      0.50      2.50
# 4    BUF           6.67     40.00      0.33      0.67      7.33
#
# [11 rows x 30 columns]

# %%
for player in rb_stats.index.levels[0]:
    print('{}_reframed'.format(player))
# Out:
# Aaron Jones_reframed
# Aaron Ripkowski_reframed
# Adrian Peterson_reframed
# Ahmad Bradshaw_reframed
# Akeem Hunt_reframed
# Alex Armah_reframed
# Alex Collins_reframed
# Alfred Blue_reframed
# Alfred Morris_reframed
# Alonzo Harris_reframed
# Alvin Kamara_reframed
# Ameer Abdullah_reframed
# Andre Ellington_reframed
# Andre Williams_reframed
# Andy Janovich_reframed
# Anthony Dixon_reframed
# Anthony Sherman_reframed
# Antone Smith_reframed
# Antonio Andrews_reframed
# Arian Foster_reframed
# Austin Ekeler_reframed
# Austin Johnson_reframed
# Benjamin Cunningham_reframed
# Bernard Pierce_reframed
# Bilal Powell_reframed
# Bishop Sankey_reframed
# Bobby Rainey_reframed
# Branden Oliver_reframed
# Brandon Bolden_reframed
# Brandon Burks_reframed
# Brandon Wilds_reframed
# Brian Hill_reframed
# Bronson Hill_reframed
# Bruce Miller_reframed
# Bryce Brown_reframed
# Byron Marshall_reframed
# CJ Anderson_reframed
# CJ Ham_reframed
# CJ Prosise_reframed
# CJ Spiller_reframed
# Cameron Artis-Payne_reframed
# Carlos Hyde_reframed
# Cedric Peerman_reframed
# Charcandrick West_reframed
# Charles Sims_reframed
# Chase Edmonds_reframed
# Chris Carson_reframed
# Chris Ivory_reframed
# Chris Johnson_reframed
# Chris Polk_reframed
# Chris Thompson_reframed
# Christian McCaffrey_reframed
# Christine Michael_reframed
# Cierre Wood_reframed
# Corey Clement_reframed
# Corey Grant_reframed
# D'Onta Foreman_reframed
# DJ Foster_reframed
# Dalvin Cook_reframed
# Damien Williams_reframed
# Dan Herron_reframed
# Daniel Lasco_reframed
# Danny Woodhead_reframed
# Darrel Young_reframed
# Darren McFadden_reframed
# Darren Sproles_reframed
# Daryl Richardson_reframed
# David Cobb_reframed
# David Fluellen_reframed
# David Johnson_reframed
# De'Angelo Henderson_reframed
# De'Lance Turner_reframed
# DeAngelo Williams_reframed
# DeMarco Murray_reframed
# Deandre Washington_reframed
# Denard Robinson_reframed
# Derek Watt_reframed
# Derrick Coleman_reframed
# Derrick Henry_reframed
# Detrez Newsome_reframed
# Devante Mays_reframed
# Devonta Freeman_reframed
# Devontae Booker_reframed
# Dexter McCluster_reframed
# Dion Lewis_reframed
# Don Jackson_reframed
# Donald Brown_reframed
# Doug Martin_reframed
# DuJuan Harris_reframed
# Duke Johnson_reframed
# Dwayne Washington_reframed
# Eddie Lacy_reframed
# Elijah McGuire_reframed
# Elijhaa Penny_reframed
# Ezekiel Elliott_reframed
# Fitzgerald Toussaint_reframed
# Fozzy Whittaker_reframed
# Frank Gore_reframed
# Fred Jackson_reframed
# George Atkinson_reframed
# George Winn_reframed
# Giovani Bernard_reframed
# Glenn Winston_reframed
# Isaiah Crowell_reframed
# Isaiah Pead_reframed
# Ito Smith_reframed
# JD McKissic_reframed
# Jacquizz Rodgers_reframed
# Jalen Richard_reframed
# Jalston Fowler_reframed
# Jamaal Charles_reframed
# Jamaal Williams_reframed
# James Conner_reframed
# James Starks_reframed
# James White_reframed
# Jamize Olawale_reframed
# Jarryd Hayne_reframed
# Javorius Allen_reframed
# Jay Ajayi_reframed
# Jay Prosch_reframed
# Jeremy Hill_reframed
# Jeremy Langford_reframed
# Jeremy McNichols_reframed
# Jerick McKinnon_reframed
# Jerome Felton_reframed
# Joe Banyard_reframed
# Joe Kerridge_reframed
# Joe Mixon_reframed
# Joey Iosefa_reframed
# John Crockett_reframed
# John Kuhn_reframed
# Joique Bell_reframed
# Jonas Gray_reframed
# Jonathan Grimes_reframed
# Jonathan Stewart_reframed
# Jonathan Williams_reframed
# Jordan Howard_reframed
# Jordan Todman_reframed
# Jordan Wilkins_reframed
# Jorvorskie Lane_reframed
# Joseph Randle_reframed
# Josh Adams_reframed
# Josh Ferguson_reframed
# Josh Robinson_reframed
# Justin Davis_reframed
# Justin Forsett_reframed
# Juwan Thompson_reframed
# Ka'Deem Carey_reframed
# Kalen Ballage_reframed
# Kapri Bibbs_reframed
# Kareem Hunt_reframed
# Karlos Williams_reframed
# Keith Smith_reframed
# Kendall Gaskins_reframed
# Kendall Hunter_reframed
# Kenjon Barner_reframed
# Kenneth Dixon_reframed
# Kenneth Farrow_reframed
# Kenyan Drake_reframed
# Kerryon Johnson_reframed
# Kerwynn Williams_reframed
# Khiry Robinson_reframed
# Knile Davis_reframed
# Kyle Juszczyk_reframed
# Lamar Miller_reframed
# Lance Dunbar_reframed
# Latavius Murray_reframed
# Lawrence Thomas_reframed
# Le'Veon Bell_reframed
# LeGarrette Blount_reframed
# LeSean McCoy_reframed
# Leonard Fournette_reframed
# Leshun Daniels Jr._reframed
# Lorenzo Taliaferro_reframed
# Mack Brown_reframed
# Malcolm Brown_reframed
# Malcolm Johnson_reframed
# Marcel Reece_reframed
# Marcus Murphy_reframed
# Marcus Thigpen_reframed
# Mark Ingram_reframed
# Mark Walton_reframed
# Marlon Mack_reframed
# Marshawn Lynch_reframed
# Matt Asiata_reframed
# Matt Breida_reframed
# Matt Dayes_reframed
# Matt Forte_reframed
# Matt Jones_reframed
# Melvin Gordon_reframed
# Michael Burton_reframed
# Mike Boone_reframed
# Mike Davis_reframed
# Mike Gillislee_reframed
# Mike James_reframed
# Mike Tolbert_reframed
# Nick Chubb_reframed
# Nyheim Hines_reframed
# Orleans Darkwa_reframed
# Patrick DiMarco_reframed
# Paul Lasike_reframed
# Paul Perkins_reframed
# Peyton Barber_reframed
# Phillip Lindsay_reframed
# Pierre Thomas_reframed
# Raheem Mostert_reframed
# Rashaad Penny_reframed
# Rashad Jennings_reframed
# Reggie Bush_reframed
# Rex Burkhead_reframed
# Rob Kelley_reframed
# Robert Turbin_reframed
# Roc Thomas_reframed
# Rod Smith_reframed
# Ronald Jones II_reframed
# Ronnie Hillman_reframed
# Roosevelt Nix_reframed
# Roy Helu_reframed
# Royce Freeman_reframed
# Ryan Mathews_reframed
# Samaje Perine_reframed
# Saquon Barkley_reframed
# Senorise Perry_reframed
# Shane Vereen_reframed
# Shaun Draughn_reframed
# Shaun Wilson_reframed
# Sony Michel_reframed
# Spencer Ware_reframed
# Stepfan Taylor_reframed
# Stevan Ridley_reframed
# Steven Jackson_reframed
# TJ Yeldon_reframed
# Taiwan Jones_reframed
# Tarik Cohen_reframed
# Terrance West_reframed
# Terrell Watson_reframed
# Terrence Magee_reframed
# Terron Ward_reframed
# Tevin Coleman_reframed
# Theo Riddick_reframed
# Thomas Rawls_reframed
# Tim Hightower_reframed
# Tion Green_reframed
# Toby Gerhart_reframed
# Todd Gurley_reframed
# Tommy Bohanon_reframed
# Travaris Cadet_reframed
# Tre Madden_reframed
# Tre Mason_reframed
# Trenton Cannon_reframed
# Trey Edmunds_reframed
# Trey Williams_reframed
# Troymaine Pope_reframed
# Ty Montgomery_reframed
# Tyler Ervin_reframed
# Tyler Varga_reframed
# Wayne Gallman_reframed
# Wendell Smallwood_reframed
# Will Johnson_reframed
# Will Tukuafu_reframed
# Zac Stacy_reframed
# Zach Line_reframed
# Zach Zenner_reframed
# Zurlon Tipton_reframed

# %%
rb_stats = pd.concat(reframed_dict)

# %%
rb_stats.columns
# Out:
# Index(['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)',
#        'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var9(t-1)', 'var10(t-1)',
#        'var11(t-1)', 'var12(t-1)', 'var13(t-1)', 'var14(t-1)', 'var15(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)',
#        'var7(t)', 'var8(t)', 'var9(t)', 'var10(t)', 'var11(t)', 'var12(t)',
#        'var13(t)', 'var14(t)', 'var15(t)'],
#       dtype='object')

# %%
qb_stats.to_csv('../input/qb/qb_stats.csv', index=True)

# %%
train  = qb
test = week1

# %%
qb_stats.columns
# Out:
# Index(['year', 'att_avg', 'comp%_avg', 'yds_avg', 'td_avg', 'rat_avg',
#        'log_att_avg', 'log_comp_avg', 'att_ma', 'comp%_ma', 'yds_ma', 'td_ma',
#        'rat_ma', 'log_att_ma', 'log_comp_ma', 'log_yds_ma', 'att_car',
#        'comp%_car', 'yds_car', 'td_car', 'rat_car', 'log_att_car',
#        'log_comp_car', 'log_yds_car'],
#       dtype='object')

# %%
week1.columns
# Out:
# Index(['Player', 'Team', 'Week', 'Opp', 'Comp', 'Att', 'Pct', 'Yds', 'Yds/Att',
#        'TD', 'Int', 'ru_att', 'ru_yds', 'yds/ru_att', 'ru_td', 'points',
#        'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
y_train = train['points']
y_test = test['points']
X_train = train.drop('points',axis=1)
X_test = test.drop('points', axis=1)

# %%
X_train = X_train[X_train.columns[4:]]
X_test = X_test[X_test.columns[4:]]

# %%
X_train = X_train[X_train.columns[4:11]]
X_test = X_test[X_test.columns[4:11]]

# %%
X_train.shape
# Out:
# (2729, 14)

# %%
X_test.shape
# Out:
# (57, 14)

# %%
X_train.columns
# Out:
# Index(['Comp', 'Att', 'Pct', 'Yds', 'Yds/Att', 'TD', 'Int', 'ru_att', 'ru_yds',
#        'yds/ru_att', 'ru_td', 'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
reframed = series_to_supervised(X_train.values.astype('float32'),1,1)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff = pd.DataFrame(X_train.columns)
coeff['coefficients'] = lr.coef_
coeff
# Out:
#               0  coefficients
# 0          Comp      0.029938
# 1           Att     -0.076581
# 2           Pct     -0.013013
# 3           Yds      0.058688
# 4       Yds/Att     -0.179413
# 5            TD      4.002376
# 6           Int     -1.242807
# 7        ru_att     -0.086593
# 8        ru_yds      0.114284
# 9    yds/ru_att     -0.025317
# 10        ru_td      5.934202
# 11         year      0.257254
# 12    def_ru_rk      0.001679
# 13  def_pass_rk      0.001679

# %%
yhat = lr.predict(X_test)
yhat.shape
# Out:
# (57,)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y_test)
print("RMSE error is: " + str(rmse_val))
# Out:
# RMSE error is: 1.68578446369

# %%
results = pd.DataFrame()
results['Player'] = week1['Player']
#results['score'] = y_test
results['Predicted'] = yhat
#results['Week'] = qb[qb['year']==2017]['Week']
#results.groupby('Player').mean()[['score','Predicted']]
results
# Out:
#                 Player  Predicted
# 0        Aaron Rodgers  22.622505
# 1           Drew Brees  22.935390
# 2            Tom Brady  22.578469
# 3       Deshaun Watson  21.599166
# 4           Cam Newton  20.770403
# 5     Matthew Stafford  21.079952
# 6   Ben Roethlisberger  20.937474
# 7          Andrew Luck  20.630576
# 8        Philip Rivers  20.697301
# 9         Kirk Cousins  20.450940
# 10      Russell Wilson  19.891470
# 11          Jared Goff  20.281654
# 12         Andy Dalton  19.393590
# 13        Tyrod Taylor  18.422072
# 14      Marcus Mariota  18.840468
# 15          Alex Smith  18.706081
# 16        Dak Prescott  18.531013
# 17       Blake Bortles  17.825208
# 18      Mitch Trubisky  17.685679
# 19           Matt Ryan  17.719255
# 20          Nick Foles  17.689892
# 21         Case Keenum  17.309548
# 22    Ryan Fitzpatrick  17.335215
# 23      Ryan Tannehill  17.145849
# 24     Jimmy Garoppolo  16.642067
# 25        Sam Bradford  16.345740
# 26          Derek Carr  16.040414
# 27          Joe Flacco  15.378570
# 28         Eli Manning  14.808699
# 29     Jacoby Brissett   0.463902
# 30         Josh McCown   0.337107
# 31      Brock Osweiler  -0.620867
# 32      Trevor Siemian  -1.230982
# 33        Mike Glennon  -0.683016
# 34       Deshone Kizer  -1.466677
# 35      Blaine Gabbert  -0.858647
# 36         David Fales  -0.911532
# 37         CJ Beathard  -1.370145
# 38         Brian Hoyer   0.331182
# 39      Brandon Weeden   0.652488
# 40          Colt McCoy   0.662689
# 41        Chase Daniel   0.641186
# 42       Brett Hundley  -1.142635
# 43         AJ McCarron   0.579074
# 44        Cody Kessler   0.779729
# 45          Chad Henne   1.410097
# 46   Teddy Bridgewater   1.478111
# 47         Matt Schaub   1.389056
# 48          Geno Smith   1.400105
# 49         Matt Cassel   1.454686
# 50  Robert Griffin III   1.378767
# 51        Carson Wentz   1.250565
# 52        Drew Stanton   1.227057
# 53        Matt Barkley   1.314373
# 54        Austin Davis   1.232926
# 55         Kevin Hogan   1.267357
# 56            Joe Webb   1.257282

# %%
results.shape
# Out:
# (300, 3)

# %%
results.to_csv('2018_week1_qb.csv', index= False)
