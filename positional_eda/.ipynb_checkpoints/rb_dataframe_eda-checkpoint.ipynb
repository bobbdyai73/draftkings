# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# %matplotlib inline

# %%
rb= pd.read_csv('../input/rb/dk_stats_loc.csv')

# %%
# Convert salary attribute from object to integer

rb['salary'].replace('null',0, inplace=True)
rb['salary'] = rb1['salary'].apply(lambda x: int(x))

# %%
rb[rb['year']==2018].shape
# Out:
# (355, 20)

# %%
rb= rb.sort_values('year').reset_index(drop=True)

# %%
rb.head()
# Out:
#    year  PlayerID             Name Team  Week Opponent  att  yds  yds/att  td  \
# 0  2015      2699       Matt Forte  CHI     1       GB   24  141      5.9   1
# 1  2015     10949       CJ Spiller   NO    15      DET    2    2      1.0   0
# 2  2015      8649  Rashad Jennings  NYG    15      CAR   16  107      6.7   1
# 3  2015      8604     Donald Brown  LAC    15      MIA   12   90      7.5   0
# 4  2015      8066  Darren McFadden  DAL    15      NYJ   16  100      6.2   0
#
#    tar  rec  rec_yds  rec_td  fum  def_rk  h/a_1  surface_0  salary  points
# 0    8    5       25       0    0      13    1.0        1.0    3000    30.6
# 1    5    2       16       0    0      17    1.0        0.0    3000     3.8
# 2    3    1        0       0    1      19    1.0        0.0    3000    19.7
# 3    3    2       14       0    0      31    0.0        1.0    3000    12.4
# 4    3    2       13       0    0       5    1.0        0.0    3000    16.3

# %%
def add_salary(df,df2):
    df = df.sort_values(['Week','PlayerID'])
    df.reset_index(inplace=True, drop=True)
    df2 = df2.sort_values(['Week','PlayerID'])
    df2 = df2.drop(['Rank','Position'], axis=1)
    df2.reset_index(inplace=True, drop=True)
    df['salary'] = df2['DraftKingsSalary']
    
    return df

# %%
rb.dtypes
# Out:
# year            int64
# PlayerID        int64
# Name           object
# Team           object
# Week            int64
# Opponent       object
# att             int64
# yds             int64
# yds/att       float64
# td              int64
# tar             int64
# rec             int64
# rec_yds         int64
# rec_td          int64
# fum             int64
# def_rk       category
# h/a_1        category
# surface_0    category
# salary          int64
# points        float64
# dtype: object

# %%
# The home or away, surafce, and defensive rank variables are categorical attributes and should not be treated as numeric

for col in ['h/a_1','surface_0','def_rk']:
    rb[col] = rb[col].astype('category')

# %%
# A broad overview of the dataset


rb.describe()
# Out:
#               year      PlayerID         Week          att          yds  \
# count  4737.000000   4737.000000  4737.000000  4737.000000  4737.000000
# mean   2016.141018  14785.294701     8.527127     7.913236    32.397509
# std       0.951284   3854.490207     5.136950     7.164827    35.455341
# min    2015.000000    733.000000     1.000000     0.000000   -11.000000
# 25%    2015.000000  13418.000000     4.000000     2.000000     4.000000
# 50%    2016.000000  15645.000000     8.000000     6.000000    21.000000
# 75%    2017.000000  16934.000000    13.000000    13.000000    49.000000
# max    2018.000000  20562.000000    17.000000    38.000000   236.000000
#
#            yds/att          td          tar          rec      rec_yds  \
# count  4737.000000  4737.00000  4737.000000  4737.000000  4737.000000
# mean      3.456618     0.21997     2.478784     1.842094    15.059531
# std       3.056805     0.50937     2.449840     1.976845    19.917234
# min     -10.000000     0.00000     0.000000     0.000000    -8.000000
# 25%       1.800000     0.00000     1.000000     0.000000     0.000000
# 50%       3.300000     0.00000     2.000000     1.000000     8.000000
# 75%       4.700000     0.00000     4.000000     3.000000    22.000000
# max      56.000000     3.00000    20.000000    15.000000   158.000000
#
#             rec_td          fum        salary       points
# count  4737.000000  4737.000000   4737.000000  4737.000000
# mean      0.073042     0.056998   3913.510661     8.524931
# std       0.274449     0.239038   1356.781587     8.236432
# min       0.000000     0.000000      0.000000    -1.800000
# 25%       0.000000     0.000000   3000.000000     2.200000
# 50%       0.000000     0.000000   3300.000000     6.100000
# 75%       0.000000     0.000000   4500.000000    12.500000
# max       3.000000     2.000000  10000.000000    55.600000

# %% [markdown]
# There were 6290 running backs that were on active rosters for 8.5 games per player from 2015 through 2018. They

# %% [markdown]
# ## DNP

# %% [markdown]
# Running Backs that do not have any rushing attempts and no receiving targets are considered as Did Not Participate (DNP)

# %%
no_rush=[]
for idx,att in enumerate(rb['att']):
    if att == 0:
        no_rush.append(idx)

rb.drop(no_rush, inplace=True)

no_rushes = rb[rb['att']==0]
no_rushes.reset_index(inplace=True, drop=True)

dnp_idx = []
for idx, tar in enumerate(no_rushes['tar']):
    if tar==0:
        dnp_idx.append(idx)

receiving_backs = no_rushes.drop(dnp_idx)

rb = pd.concat([rb,receiving_backs])

# %%
rb.tail()
# Out:
#       year  PlayerID                 Name Team  Week Opponent  att  yds  \
# 2043  2017     15207  Benjamin Cunningham  CHI    17      MIN    0    0
# 2045  2017     18690        Jalen Richard  OAK    17      LAC    0    0
# 2051  2018     18093        Andy Janovich  DEN     2      OAK    0    0
# 2055  2018     13063         Taiwan Jones  BUF     4       GB    0    0
# 2057  2018     15631      Derrick Coleman  ARI     4      SEA    0    0
#
#       yds/att  td  tar  rec  rec_yds  rec_td  fum  def_rk  h/a_1  surface_0  \
# 2043      0.0   0    1    1        6       0    0       1    0.0        0.0
# 2045      0.0   0    1    1        6       0    0      23    0.0        1.0
# 2051      0.0   0    1    1       11       0    0      24    1.0        1.0
# 2055      0.0   0    1    0        0       0    0       9    0.0        1.0
# 2057      0.0   0    1    1        5       0    0      10    1.0        1.0
#
#       salary  points
# 2043    5200     1.6
# 2045    3300     1.6
# 2051       0     2.1
# 2055       0     0.0
# 2057       0     1.5

# %% [markdown]
# After removing the 1553 DNP players the numbers look more reasonable. There were 4737 running backs that played in games from 2015 through 2018. The players, on average, played in 8.5 games, had 8 rushing attempts for 32 yards for a rate of 3.4 yards/attempt. They averaged a measly .22 touchdowns per player. They were targeted 2.5 times per player and had 1.85 receptions for 15 yards/reception, pretty good. On average they do not catch alot of touchdown passes at a rate of .07 per player and are extremely reliable with the football only losing a fumble .06 times per player. The competing players have cost an average of $3913.52 and have only averaged 8.52 fantasy points per player

# %% [markdown]
# ## Data Visualization

# %%
cat_cols = ['h/a_1','surface_0','def_rk']

# %%
rec_cols =[]
rushing_cols = []
for col in rb.columns:
    if 'rec' in col:
        rec_cols.append(col)
    else:
        rushing_cols.append(col)

# %%
rec_cols.append('tar')
rec_cols.append('Name')
rec_cols.append('year')
rec_cols.append('points')

# %%
rec_cols
# Out:
# ['rec', 'rec_yds', 'rec_td', 'tar', 'Name', 'year', 'points']

# %%
not_rushing = ['tar','PlayerID','salary','h/a_1','surface_0','def_rk']
for val in not_rushing:
    rushing_cols.remove(val)

# %%
rb[rushing_cols].head()
# Out:
#    year             Name Team  Week Opponent  att  yds  yds/att  td  fum  \
# 0  2015       Matt Forte  CHI     1       GB   24  141      5.9   1    0
# 1  2015       CJ Spiller   NO    15      DET    2    2      1.0   0    0
# 2  2015  Rashad Jennings  NYG    15      CAR   16  107      6.7   1    1
# 3  2015     Donald Brown  LAC    15      MIA   12   90      7.5   0    0
# 4  2015  Darren McFadden  DAL    15      NYJ   16  100      6.2   0    0
#
#    points
# 0    30.6
# 1     3.8
# 2    19.7
# 3    12.4
# 4    16.3

# %%
rb[rec_cols].head()
# Out:
#    rec  rec_yds  tar             Name  points
# 0    5       25    8       Matt Forte    30.6
# 1    2       16    5       CJ Spiller     3.8
# 2    1        0    3  Rashad Jennings    19.7
# 3    2       14    3     Donald Brown    12.4
# 4    2       13    3  Darren McFadden    16.3

# %% [markdown]
# ### Pair Plots#

# %%
# Remove categroical variables for Pairs Plot
discrete = ['td','fum','year','rec_td','Week']
for val in discrete:
    if val in rushing_cols:
        rushing_cols.remove(val)
    elif val in rec_cols:
        rec_cols.remove(val)

# %%
sns.pairplot(rb[rushing_cols])

# %%
sns.pairplot(rb[rec_cols])

# %% [markdown]
# A Pair Plot shows scatter plots of all numeric variables. Since we have other methods of investigating discrete variabes we remove the discrete variables from the rushing and receiving data frames before plotting. At first glance, the pairs plot shows what we would expect. Running backs fantasy points are directly related to rushing attempts, yards, receiving targets, receptions, yards, yards per catch.

# %% [markdown]
# # Boxplots

# %% [markdown]
# Boxplots are a good way to visualize outliers wihtin a dataset.

# %%
def boxplotter(data, column_name):
    fig= plt.figure(figsize=(6,4))

    ax = sns.boxplot(data[column_name], orient='v',
                    fliersize=8, linewidth=1.5, notch=False,
                    saturation=0.5)
    ax.set_title(column_name, fontsize=20)
    plt.show()

# %%
rushing_cols
# Out:
# ['Name', 'Team', 'Opponent', 'att', 'yds', 'yds/att', 'points']

# %%
fig,ax = plt.subplots(2,2)
ax[0,0] = sns.boxplot(rb['att'], orient='v')

# %%
ax[0,1] = sns.boxplot(rb['yds'], orient='v')

# %%
for col in rushing_cols[3:]:
    boxplotter(rb,col)

# %%
rec_cols
# Out:
# ['rec', 'rec_yds', 'tar', 'Name', 'points']

# %%
for col in rec_cols[:3]:
    boxplotter(rb,col)

# %% [markdown]
# # Histograms

# %%
poisson = np.random.poisson(0.5, 1000)
plt.hist(poisson)
# Out:
# (array([610.,   0., 311.,   0.,   0.,  69.,   0.,   9.,   0.,   1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# This is the histogram of a standard poisson distribution

# %%
plt.hist(rb['td'], bins=10)
# Out:
# (array([3878.,    0.,    0.,  701.,    0.,    0.,  133.,    0.,    0.,
#           25.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
# Investigating the relationship of a players' opponent's defensive ranking as a function of the fantasy points scored

fig = plt.figure(figsize=(10,10))
sns.boxplot(x=rb['def_rk'], y=rb['points'])

# %%
# Investigating the relationship betwwen type of surface, grass or turf, as a function of a player's fantasy points scored

sns.boxplot(rb['h/a_1'], rb['points'])

# %%
rb[rb['td']==0].count()
# Out:
# year         3878
# PlayerID     3878
# Name         3878
# Team         3878
# Week         3878
# Opponent     3878
# att          3878
# yds          3878
# yds/att      3878
# td           3878
# tar          3878
# rec          3878
# rec_yds      3878
# rec_td       3878
# fum          3878
# def_rk       3878
# h/a_1        3878
# surface_0    3878
# salary       3878
# points       3878
# dtype: int64

# %%
receiving_backs.sort_values('tar', ascending=False, inplace=True)

# %%
receiving_backs.reset_index(inplace=True, drop=True)
receiving_backs
# Out:
#      year  PlayerID              Name Team  Week Opponent  att  yds  yds/att  \
# 0    2015     15126      Theo Riddick  DET     5      ARI    0    0      0.0
# 1    2018     15126      Theo Riddick  DET     2       SF    0    0      0.0
# 2    2017     12780      Shane Vereen  NYG     1      DAL    0    0      0.0
# 3    2015     15126      Theo Riddick  DET     3      DEN    0    0      0.0
# 4    2016     16056       James White   NE    12      NYJ    0    0      0.0
# 5    2017     18253         DJ Foster  ARI    15      WAS    0    0      0.0
# 6    2017     15126      Theo Riddick  DET     3      ATL    0    0      0.0
# 7    2015     14731      Lance Dunbar  DAL     1      NYG    0    0      0.0
# 8    2016     14901     Kyle Juszczyk  BAL     4      OAK    0    0      0.0
# 9    2015     14901     Kyle Juszczyk  BAL    16      PIT    0    0      0.0
# 10   2018     18690     Jalen Richard  OAK     3      MIA    0    0      0.0
# 11   2015     14901     Kyle Juszczyk  BAL     5      CLE    0    0      0.0
# 12   2016     14901     Kyle Juszczyk  BAL     6      NYG    0    0      0.0
# 13   2016     13158     Shaun Draughn   SF    12      MIA    0    0      0.0
# 14   2016     16056       James White   NE    11       SF    0    0      0.0
# 15   2016     14352    Travaris Cadet   NO     3      ATL    0    0      0.0
# 16   2018     18652            CJ Ham  MIN     3      BUF    0    0      0.0
# 17   2017     17965        CJ Prosise  SEA     2       SF    0    0      0.0
# 18   2015     14901     Kyle Juszczyk  BAL    15       KC    0    0      0.0
# 19   2016     14352    Travaris Cadet   NO    13      DET    0    0      0.0
# 20   2016     14731      Lance Dunbar  DAL    14      NYG    0    0      0.0
# 21   2015     14901     Kyle Juszczyk  BAL    10      JAX    0    0      0.0
# 22   2015     16855     Ty Montgomery   GB     5      LAR    0    0      0.0
# 23   2016     14352    Travaris Cadet   NO    17      ATL    0    0      0.0
# 24   2017     14901     Kyle Juszczyk   SF    16      JAX    0    0      0.0
# 25   2015     14901     Kyle Juszczyk  BAL     7      ARI    0    0      0.0
# 26   2017     16838      Duke Johnson  CLE     1      PIT    0    0      0.0
# 27   2017     18041       Tyler Ervin  HOU     2      CIN    0    0      0.0
# 28   2016     14901     Kyle Juszczyk  BAL     5      WAS    0    0      0.0
# 29   2017     16609      Charles Sims   TB     6      ARI    0    0      0.0
# ..    ...       ...               ...  ...   ...      ...  ...  ...      ...
# 479  2016     16378       Keith Smith  DAL     2      WAS    0    0      0.0
# 480  2016     14872    Mike Gillislee  BUF     2      NYJ    0    0      0.0
# 481  2016     12649      Will Tukuafu  SEA     2      LAR    0    0      0.0
# 482  2016     16273       Kapri Bibbs  DEN     1      CAR    0    0      0.0
# 483  2016     14872    Mike Gillislee  BUF     1      BAL    0    0      0.0
# 484  2016     14786   Patrick DiMarco  ATL     1       TB    0    0      0.0
# 485  2016     18376        Alan Cross   TB     5      CAR    0    0      0.0
# 486  2016       733     Jerome Felton  BUF     6       SF    0    0      0.0
# 487  2016     13418   Anthony Sherman   KC     6      OAK    0    0      0.0
# 488  2016     14786   Patrick DiMarco  ATL     6      SEA    0    0      0.0
# 489  2016     17303       Paul Lasike  CHI    10       TB    0    0      0.0
# 490  2016     14731      Lance Dunbar  DAL    10      PIT    0    0      0.0
# 491  2016     18217     Josh Ferguson  IND     9       GB    0    0      0.0
# 492  2016     18003      Kenyan Drake  MIA     9      NYJ    0    0      0.0
# 493  2016     16928    Michael Burton  DET     9      MIN    0    0      0.0
# 494  2016     14786   Patrick DiMarco  ATL     9       TB    0    0      0.0
# 495  2016     14352    Travaris Cadet   NO     9       SF    0    0      0.0
# 496  2016     13418   Anthony Sherman   KC     9      JAX    0    0      0.0
# 497  2016     18115        Derek Watt  LAC     8      DEN    0    0      0.0
# 498  2016     16867   Jeremy Langford  CHI     8      MIN    0    0      0.0
# 499  2016     16378       Keith Smith  DAL     8      PHI    0    0      0.0
# 500  2016     15224   Andre Ellington  ARI     8      CAR    0    0      0.0
# 501  2016     11220  Dexter McCluster  LAC     8      DEN    0    0      0.0
# 502  2016     18041       Tyler Ervin  HOU     7      DEN    0    0      0.0
# 503  2016     14901     Kyle Juszczyk  BAL     7      NYJ    0    0      0.0
# 504  2016     14786   Patrick DiMarco  ATL     7      LAC    0    0      0.0
# 505  2016     13741    Brandon Bolden   NE     7      PIT    0    0      0.0
# 506  2016     13418   Anthony Sherman   KC     7       NO    0    0      0.0
# 507  2016     18115        Derek Watt  LAC     6      DEN    0    0      0.0
# 508  2018     20159        Mike Boone  MIN     4      LAR    0    0      0.0
#
#      td  tar  rec  rec_yds  rec_td  fum  def_rk  h/a_1  surface_0 salary  \
# 0     0   13   10       53       1    0       8    1.0        0.0   3000
# 1     0   12    9       47       0    0      26    0.0        1.0   5000
# 2     0   10    9       51       0    0       8    0.0        0.0   5200
# 3     0   10    8       66       0    0      14    1.0        0.0   5900
# 4     0    9    4       22       0    0      19    0.0        0.0   3000
# 5     0    9    4       22       0    0      28    0.0        1.0   4700
# 6     0    9    4       38       0    0      14    1.0        0.0   4500
# 7     0    8    8       70       0    0      24    1.0        0.0   3000
# 8     0    7    6       56       0    0      23    1.0        1.0   3500
# 9     0    7    5       55       0    0       2    1.0        1.0   5000
# 10    0    7    6       59       0    0      28    0.0        1.0   3000
# 11    0    6    3       31       1    0      16    1.0        1.0   3000
# 12    0    6    4       25       0    0       6    0.0        0.0   null
# 13    0    6    6       49       0    0      20    0.0        1.0   4600
# 14    0    6    6       63       1    0      32    0.0        1.0   3000
# 15    0    6    6       32       0    0      29    1.0        0.0   3000
# 16    0    6    5       47       0    0      25    1.0        0.0   3900
# 17    0    6    3       22       0    0      26    1.0        0.0   3100
# 18    0    6    5       26       1    0       3    1.0        1.0   null
# 19    0    6    5       53       0    0       9    1.0        0.0   3800
# 20    0    5    3       12       0    0       6    0.0        0.0   3000
# 21    0    5    5       47       0    0      27    1.0        1.0   3000
# 22    0    5    4       59       1    0      23    1.0        1.0   4200
# 23    0    5    3       18       1    0      29    0.0        0.0   5600
# 24    0    5    5       76       0    0      10    1.0        1.0   3900
# 25    0    5    4       15       1    0       8    0.0        1.0   3000
# 26    0    5    2       20       0    0      18    1.0        1.0   3000
# 27    0    5    3       16       0    0      30    0.0        0.0   3400
# 28    0    5    3       20       0    0      26    1.0        1.0   3000
# 29    0    5    4       45       0    0       5    0.0        1.0   null
# ..   ..  ...  ...      ...     ...  ...     ...    ...        ...    ...
# 479   0    1    1        5       0    0      26    0.0        1.0   4000
# 480   0    1    1       18       1    0      19    1.0        0.0   3000
# 481   0    1    0        0       0    0      16    0.0        1.0   6000
# 482   0    1    1        6       0    0      15    1.0        1.0   3100
# 483   0    1    1       -4       0    0      13    0.0        1.0   3000
# 484   0    1    1        8       0    0      22    1.0        0.0   6600
# 485   0    1    1        5       0    0      15    0.0        1.0   3000
# 486   0    1    0        0       0    0      32    1.0        0.0   null
# 487   0    1    0        0       0    0      23    0.0        1.0   6200
# 488   0    1    1        3       0    0       4    0.0        0.0   4300
# 489   0    1    1        3       0    0      22    0.0        1.0   7100
# 490   0    1    0        0       0    0      27    0.0        1.0   3000
# 491   0    1    1        9       0    0      10    0.0        1.0   3000
# 492   0    1    1        6       0    0      19    1.0        1.0   3000
# 493   0    1    0        0       0    0       8    0.0        0.0   null
# 494   0    1    1        1       1    0      22    0.0        1.0   null
# 495   0    1    1        4       0    0      32    0.0        1.0   3000
# 496   0    1    1        6       0    0      14    1.0        1.0   7600
# 497   0    1    1       53       0    0      18    0.0        1.0   4200
# 498   0    1    1       11       0    0       8    1.0        1.0   null
# 499   0    1    1        1       0    0      12    1.0        0.0   null
# 500   0    1    1       16       0    0      15    0.0        1.0   5100
# 501   0    1    1        3       0    0      18    0.0        1.0   4400
# 502   0    1    1        9       0    0      18    0.0        1.0   3000
# 503   0    1    1        2       0    0      19    0.0        0.0   3600
# 504   0    1    1        3       0    0      28    1.0        0.0   3000
# 505   0    1    0        0       0    0      27    0.0        1.0   null
# 506   0    1    1        0       0    0      30    1.0        1.0   3000
# 507   0    1    1        8       0    0      18    0.0        1.0   null
# 508   0    1    1        1       0    0      11    0.0        1.0   4400
#
#      points
# 0      21.3
# 1      13.7
# 2      14.1
# 3      14.6
# 4       6.2
# 5       6.2
# 6       7.8
# 7      15.0
# 8      11.6
# 9      10.5
# 10     11.9
# 11     12.1
# 12      6.5
# 13     10.9
# 14     18.3
# 15      9.2
# 16      9.7
# 17      5.2
# 18     13.6
# 19     10.3
# 20      4.2
# 21      9.7
# 22     15.9
# 23     10.8
# 24     12.6
# 25     11.5
# 26      4.0
# 27      4.6
# 28      5.0
# 29      8.5
# ..      ...
# 479     1.5
# 480     8.8
# 481     0.0
# 482     1.6
# 483     0.6
# 484     1.8
# 485     1.5
# 486     0.0
# 487     0.0
# 488     1.3
# 489     1.3
# 490     0.0
# 491     1.9
# 492     7.6
# 493     0.0
# 494     7.1
# 495     1.4
# 496     1.6
# 497     6.3
# 498     2.1
# 499     1.1
# 500     2.6
# 501     1.3
# 502     1.9
# 503     1.2
# 504     1.3
# 505     0.0
# 506     1.0
# 507     1.8
# 508     1.1
#
# [509 rows x 20 columns]

# %%
rb.drop(dnp, inplace=True)

# %%
rb.describe()
# Out:
#              year      PlayerID         Week          att          yds  \
# count  6289.00000   6289.000000  6289.000000  6289.000000  6289.000000
# mean   2016.13627  15006.989346     8.497217     5.960407    24.402449
# std       0.94793   3682.868882     5.109087     7.092661    33.792593
# min    2015.00000    733.000000     1.000000     0.000000   -11.000000
# 25%    2015.00000  13791.000000     4.000000     0.000000     0.000000
# 50%    2016.00000  16056.000000     8.000000     3.000000     9.000000
# 75%    2017.00000  17023.000000    13.000000    10.000000    39.000000
# max    2018.00000  20562.000000    17.000000    38.000000   236.000000
#
#            yds/att           td          tar          rec      rec_yds  \
# count  6289.000000  6289.000000  6289.000000  6289.000000  6289.000000
# mean      2.603594     0.165686     1.867069     1.387502    11.343139
# std       3.042868     0.452122     2.379637     1.890559    18.464728
# min     -10.000000     0.000000     0.000000     0.000000    -8.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       2.400000     0.000000     1.000000     1.000000     1.000000
# 75%       4.100000     0.000000     3.000000     2.000000    16.000000
# max      56.000000     3.000000    20.000000    15.000000   158.000000
#
#             rec_td          fum       def_rk        h/a_1    surface_0  \
# count  6289.000000  6289.000000  6289.000000  6289.000000  6289.000000
# mean      0.055017     0.044522    16.577675     0.486882     0.590555
# std       0.240257     0.212347     9.218288     0.499868     0.491771
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     0.000000     9.000000     0.000000     0.000000
# 50%       0.000000     0.000000    17.000000     0.000000     1.000000
# 75%       0.000000     0.000000    25.000000     1.000000     1.000000
# max       3.000000     2.000000    32.000000     1.000000     1.000000
#
#             points
# count  6289.000000
# mean      6.422102
# std       8.037897
# min      -1.800000
# 25%       0.000000
# 50%       3.300000
# 75%       9.800000
# max      55.600000

# %%
rec_col = [col for col in rb.columns if 'ru' not in col ]
rush_col = [col for col in rb.columns if 'ru' in col]

# %%
rush_col.append('fum')

# %%
for col in rb.columns:
    print(rb[col].describe(), '\n')
# Out:
# count    4930.000000
# mean     2016.255781
# std         1.010842
# min      2015.000000
# 25%      2015.000000
# 50%      2016.000000
# 75%      2017.000000
# max      2018.000000
# Name: year, dtype: float64
#
# count     4930.000000
# mean     14893.428803
# std       3845.044397
# min        733.000000
# 25%      13735.000000
# 50%      16031.000000
# 75%      17023.000000
# max      20562.000000
# Name: PlayerID, dtype: float64
#
# count             4930
# unique             270
# top       Duke Johnson
# freq                55
# Name: Name, dtype: object
#
# count     4930
# unique      32
# top        OAK
# freq       188
# Name: Team, dtype: object
#
# count    4930.000000
# mean        8.108114
# std         5.212727
# min         1.000000
# 25%         3.000000
# 50%         8.000000
# 75%        13.000000
# max        17.000000
# Name: Week, dtype: float64
#
# count     4930
# unique      32
# top        LAC
# freq       166
# Name: Opponent, dtype: object
#
# count    4930.000000
# mean        7.971805
# std         7.150203
# min         0.000000
# 25%         2.000000
# 50%         6.000000
# 75%        13.000000
# max        38.000000
# Name: ru_att, dtype: float64
#
# count    4930.000000
# mean       32.693915
# std        35.380570
# min       -11.000000
# 25%         4.000000
# 50%        21.000000
# 75%        50.000000
# max       236.000000
# Name: ru_yds, dtype: float64
#
# count    4930.000000
# mean        3.469067
# std         3.024639
# min       -10.000000
# 25%         1.800000
# 50%         3.300000
# 75%         4.800000
# max        56.000000
# Name: ru_yds/att, dtype: float64
#
# count    4930.000000
# mean        0.223124
# std         0.512090
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: ru_td, dtype: float64
#
# count    4930.000000
# mean        2.520081
# std         2.496112
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        20.000000
# Name: tar, dtype: float64
#
# count    4930.000000
# mean        1.875659
# std         2.013889
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: rec, dtype: float64
#
# count    4930.000000
# mean       15.299391
# std        20.108350
# min        -8.000000
# 25%         0.000000
# 50%         8.000000
# 75%        22.000000
# max       158.000000
# Name: yds, dtype: float64
#
# count    4930.000000
# mean        0.074037
# std         0.276186
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: td, dtype: float64
#
# count    4930.000000
# mean        0.056998
# std         0.238760
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: fum, dtype: float64
#
# count    4930.000000
# mean       16.700609
# std         9.237276
# min         1.000000
# 25%         9.000000
# 50%        17.000000
# 75%        25.000000
# max        32.000000
# Name: def_rk, dtype: float64
#
# count    4930.000000
# mean        0.513185
# std         0.499877
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: h/a_1, dtype: float64
#
# count    4930.000000
# mean        0.593103
# std         0.491305
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: surface_0, dtype: float64
#
# count     4930.000000
# mean      3533.590264
# std       1764.132711
# min          0.000000
# 25%       3000.000000
# 50%       3200.000000
# 75%       4300.000000
# max      10000.000000
# Name: salary, dtype: float64
#
# count    4930.000000
# mean        8.640613
# std         8.249049
# min        -1.600000
# 25%         2.200000
# 50%         6.300000
# 75%        12.700000
# max        55.600000
# Name: points, dtype: float64

# %%
players = []
avg_points =[]
for name in list(rb['Name'].unique()):
    avg_points.append(rb[rb['Name'] ==name].describe()['points'].mean())

# %%
rb_avg = pd.DataFrame()
rb_avg['player'] = (rb['Name'].unique())
rb_avg['avg_points']= avg_points
#rb.sort_values(rb_avg['avg_points'], ascending=False)

# %%
rb_avg.sort_values('avg_points',ascending=False)
# Out:
#                   player  avg_points
# 115         Le'Veon Bell   25.656949
# 123          Todd Gurley   24.944231
# 216         Alvin Kamara   23.548177
# 167      Ezekiel Elliott   22.027668
# 85         David Johnson   21.795297
# 77       Devonta Freeman   21.236008
# 80         Melvin Gordon   20.685576
# 18          LeSean McCoy   20.315075
# 38          Lamar Miller   19.506927
# 217          Kareem Hunt   19.363201
# 34           Mark Ingram   19.083512
# 250       Saquon Barkley   18.650153
# 79           Carlos Hyde   18.282951
# 30        DeMarco Murray   17.819920
# 57       Latavius Murray   17.529867
# 181        Jordan Howard   17.349195
# 5        Adrian Peterson   17.251222
# 28          Bilal Powell   17.211677
# 70        Isaiah Crowell   17.075537
# 1             Matt Forte   16.828371
# 215  Christian McCaffrey   16.717959
# 52       Giovani Bernard   16.398979
# 8             Frank Gore   16.354073
# 119          James White   16.350305
# 11     DeAngelo Williams   16.322842
# 59        Chris Thompson   16.290846
# 212    Leonard Fournette   16.213811
# 42           Doug Martin   16.112869
# 144            Jay Ajayi   16.033527
# 26            Dion Lewis   16.014328
# ..                   ...         ...
# 46        Bernard Pierce    1.513652
# 117       Stepfan Taylor    1.473723
# 202       Cedric Peerman    1.428571
# 241         Devante Mays    1.417570
# 158       Terrence Magee    1.381694
# 43           Isaiah Pead    1.380964
# 44       Jorvorskie Lane    1.345546
# 128         Tyler Clutts    1.342857
# 204       Chase Reynolds    1.342857
# 193          Don Jackson    1.233749
# 164        Trey Williams    1.171429
# 228       David Fluellen    0.995546
# 179          Paul Lasike    0.961738
# 125        Alonzo Harris    0.939061
# 246   Leshun Daniels Jr.    0.863388
# 209         Joe Kerridge    0.852405
# 203          Joe Banyard    0.742857
# 207         Bronson Hill    0.702405
# 178     Daryl Richardson    0.556694
# 130          Cierre Wood    0.521339
# 266     Jeremy McNichols    0.485714
# 267        Kalen Ballage    0.400000
# 154       Kendall Hunter    0.314286
# 137          George Winn    0.296339
# 263       Detrez Newsome    0.250000
# 226         Justin Davis    0.228571
# 247     Marquez Williams    0.142857
# 156       Marcus Thigpen    0.057143
# 162        John Crockett    0.057143
# 211        Brandon Burks   -0.200000
#
# [270 rows x 2 columns]

# %%
rb[rb['Name']=='Saquon Barkley']
# Out:
# Empty DataFrame
# Columns: [Name, Opponent, PlayerID, Team, Week, att, def_rk, fum, h/a_1, points, rec, rec_td, rec_yds, ru_att, ru_td, ru_yds, ru_yds/att, salary, surface_0, tar, td, yds, yds/att, year]
# Index: []
#
# [0 rows x 24 columns]

# %%
rb_refined = [] 
for player in rb_2018['Name'].unique():
    print(rb_2018[rb_2018['Name'] == player].reset_index(inplace=True, drop=True)
    #df.drop([:3],inplace =True)
    #rb_refined.append(df[:3])

# %%
def boxplotter(data, column_name):
    fig= plt.figure(figsize=(6,4))

    ax = sns.boxplot(data[column_name], orient='v',
                    fliersize=8, linewidth=1.5, notch=False,
                    saturation=0.5)
    ax.set_title(column_name, fontsize=20)
    plt.show()

# %%
cols = ['ru_yds','ru_att','yds/att','td','targets','Receptions','rec_yds','rec_td','points']

# %%
for col in cols:
    boxplotter(rb,col)

# %%
rb['ru_yds'].describe()
# Out:
# count    11748.000000
# mean        24.306435
# std         34.737340
# min        -14.000000
# 25%          0.000000
# 50%          8.000000
# 75%         37.000000
# max        251.000000
# Name: ru_yds, dtype: float64

# %%
boxplotter(rb, np.l('ru_yds'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9d31c6e676c7> in <module>()
# ----> 1 boxplotter(rb, ln('ru_yds'))
#
# NameError: name 'ln' is not defined

# %%
boxplotter(qb,'Comp')

# %%
boxplotter(qb,'TD')

# %%
boxplotter(qb,'Int')

# %%
fig = plt.figure(figsize=(20,20))

ax = sns.boxplot(data=rb, orient='v', fliersize=5, linewidth=3, notch=True,
                 saturation=0.5)

ax.set_title('RB Stats')
# Out:
# Text(0.5,1,'RB Stats')

# %%
rb.corr()
# Out:
#                      Week    ru_att    ru_yds   yds/att        td  \
# Week         1.000000e+00  0.003010  0.007359 -0.004875 -0.002318
# ru_att       3.009886e-03  1.000000  0.899538  0.401823  0.467409
# ru_yds       7.359134e-03  0.899538  1.000000  0.567452  0.499462
# yds/att     -4.874831e-03  0.401823  0.567452  1.000000  0.264593
# td          -2.318229e-03  0.467409  0.499462  0.264593  1.000000
# targets     -8.431204e-07  0.407778  0.342059  0.239379  0.149631
# Receptions  -1.029887e-02  0.381668  0.320810  0.229259  0.149917
# rec_yds     -1.603193e-02  0.298583  0.253933  0.191213  0.135855
# rec_td       1.543040e-04  0.086384  0.085008  0.054334  0.027802
# Fumbles     -3.897673e-03  0.218665  0.200009  0.102549  0.092620
# FumblesLost -1.188719e-02  0.178190  0.163147  0.080932  0.059614
# points       5.654426e-05  0.779881  0.837260  0.478092  0.722055
# year         1.485271e-02  0.007314  0.002319  0.018411  0.001156
# def_ru_rk   -1.802705e-03  0.034677  0.045174  0.031125  0.054807
# def_pass_rk -1.802705e-03  0.034677  0.045174  0.031125  0.054807
#
#                   targets  Receptions   rec_yds    rec_td   Fumbles  \
# Week        -8.431204e-07   -0.010299 -0.016032  0.000154 -0.003898
# ru_att       4.077776e-01    0.381668  0.298583  0.086384  0.218665
# ru_yds       3.420590e-01    0.320810  0.253933  0.085008  0.200009
# yds/att      2.393790e-01    0.229259  0.191213  0.054334  0.102549
# td           1.496312e-01    0.149917  0.135855  0.027802  0.092620
# targets      1.000000e+00    0.941870  0.794247  0.274669  0.137527
# Receptions   9.418700e-01    1.000000  0.838840  0.293824  0.144010
# rec_yds      7.942466e-01    0.838840  1.000000  0.343222  0.111920
# rec_td       2.746689e-01    0.293824  0.343222  1.000000  0.020783
# Fumbles      1.375269e-01    0.144010  0.111920  0.020783  1.000000
# FumblesLost  1.142906e-01    0.122290  0.102770  0.013162  0.768605
# points       5.369358e-01    0.542549  0.546928  0.353509  0.140720
# year         2.959688e-02    0.028119  0.029390  0.031603 -0.007175
# def_ru_rk   -9.594877e-03   -0.010416  0.007477  0.017967 -0.005018
# def_pass_rk -9.594877e-03   -0.010416  0.007477  0.017967 -0.005018
#
#              FumblesLost    points      year  def_ru_rk  def_pass_rk
# Week           -0.011887  0.000057  0.014853  -0.001803    -0.001803
# ru_att          0.178190  0.779881  0.007314   0.034677     0.034677
# ru_yds          0.163147  0.837260  0.002319   0.045174     0.045174
# yds/att         0.080932  0.478092  0.018411   0.031125     0.031125
# td              0.059614  0.722055  0.001156   0.054807     0.054807
# targets         0.114291  0.536936  0.029597  -0.009595    -0.009595
# Receptions      0.122290  0.542549  0.028119  -0.010416    -0.010416
# rec_yds         0.102770  0.546928  0.029390   0.007477     0.007477
# rec_td          0.013162  0.353509  0.031603   0.017967     0.017967
# Fumbles         0.768605  0.140720 -0.007175  -0.005018    -0.005018
# FumblesLost     1.000000  0.088526 -0.006260  -0.010037    -0.010037
# points          0.088526  1.000000 -0.037305   0.053160     0.053160
# year           -0.006260 -0.037305  1.000000   0.004223     0.004223
# def_ru_rk      -0.010037  0.053160  0.004223   1.000000     1.000000
# def_pass_rk    -0.010037  0.053160  0.004223   1.000000     1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(rb.corr(), annot=True)

# %%
corr = pd.DataFrame(index=rb.columns[4:])

# %%
rb.head()
# Out:
#           Player Team  Week  Opp  ru_att  ru_yds  yds/att  td  targets  \
# 0     CJ Spiller  BUF     1  NYJ      14     169     12.1   1        3
# 1  Alfred Morris  WAS     1   NO      28      96      3.4   2        0
# 2       Ray Rice  BAL     1  CIN      10      68      6.8   2        4
# 3  Stevan Ridley   NE     1  TEN      21     125      6.0   1        3
# 4    Kevin Smith  DET     1  LAR      13      62      4.8   1        6
#
#    Receptions  rec_yds  rec_td  Fumbles  FumblesLost  points  year  def_ru_rk  \
# 0           2       25       0        1            1    29.4  2012         20
# 1           0        0       0        0            0    21.6  2012         31
# 2           3       25       0        0            0    24.3  2012          8
# 3           2       27       0        0            0    26.2  2012         32
# 4           4       29       1        0            0    25.1  2012         14
#
#    def_pass_rk
# 0           20
# 1           31
# 2            8
# 3           32
# 4           14

# %%
np.corrcoef(rb.points,)
# Out:
# 1.0

# %%
corr
# Out:
# Empty DataFrame
# Columns: []
# Index: [Comp, Att, Pct, Yds, Yds/Att, TD, Int, ru_att, ru_yds, yds/ru_att, ru_td, points, year]

# %%
coef =[]
for col in rb.columns[4:]:
    #print(qb[col])
    coef.append(np.corrcoef(rb.points,rb[col])[0][1])

# %%
corr[1] = coef

# %%
corr
# Out:
#                     1
# ru_att       0.779881
# ru_yds       0.837260
# yds/att      0.478092
# td           0.722055
# targets      0.536936
# Receptions   0.542549
# rec_yds      0.546928
# rec_td       0.353509
# Fumbles      0.140720
# FumblesLost  0.088526
# points       1.000000
# year        -0.037305
# def_ru_rk    0.053160
# def_pass_rk  0.053160

# %%
pd.scatter_matrix(rb[4:], figsize=(20,15))
plt.show()
# Out:
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
#A function that will covert a time series database into a supervised learning database

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
train  = rb
test = week1_2018

# %%
train.shape
# Out:
# (11748, 18)

# %%
test.shape
# Out:
# (70, 18)

# %%
passing = ['Comp','Att','Pct','Yds','Yds/Att','TD','Int']

# %%
y_train = train['points']
y_test = test['points']
X_train = train.drop('points',axis=1)
X_test = test.drop('points', axis=1)

# %%
X_train = X_train[X_train.columns[4:]]
X_test = X_test[X_test.columns[4:]]

# %%
X_train = X_train[X_train.columns[4:11]]
X_test = X_test[X_test.columns[4:11]]

# %%
X_train.columns
# Out:
# Index(['ru_att', 'ru_yds', 'yds/att', 'td', 'targets', 'Receptions', 'rec_yds',
#        'rec_td', 'Fumbles', 'FumblesLost', 'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
reframed = series_to_supervised(X_train.values.astype('float32'),1,1)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff = pd.DataFrame(X_train.columns)
coeff['coefficients'] = lr.coef_
coeff
# Out:
#               0  coefficients
# 0        ru_att     -0.016761
# 1        ru_yds      0.107790
# 2       yds/att     -0.020275
# 3            td      5.971200
# 4       targets      0.007460
# 5    Receptions      0.141891
# 6       rec_yds      0.100108
# 7        rec_td      5.822190
# 8       Fumbles      0.010859
# 9   FumblesLost     -1.777669
# 10         year     -0.206622
# 11    def_ru_rk      0.000245
# 12  def_pass_rk      0.000245

# %%
yhat = lr.predict(X_test)
yhat.shape
# Out:
# (70,)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y_test)
print("RMSE error is: " + str(rmse_val))
# Out:
# RMSE error is: 0.712465875151

# %%
results = pd.DataFrame()
results['Player'] = week1_2018['Player']
#results['score'] = y_test
results['Predicted'] = yhat
#results['Week'] = rb[rb['year']==2017]['Week']
#results.groupby('Player').mean()[['score','Predicted']]
results
# Out:
#                  Player  Predicted
# 0           Todd Gurley  18.561469
# 1         David Johnson  17.240292
# 2         Melvin Gordon  14.514580
# 3       Devonta Freeman  11.331842
# 4          LeSean McCoy  10.591942
# 5          Lamar Miller  10.344359
# 6          Le'Veon Bell   9.925670
# 7             Jay Ajayi   9.253915
# 8          Rex Burkhead   9.192221
# 9        Marshawn Lynch   8.668046
# 10          Carlos Hyde   8.328319
# 11           Dion Lewis   7.869186
# 12         Bilal Powell   7.154256
# 13       Isaiah Crowell   7.064721
# 14        Tevin Coleman   6.917477
# 15        Alfred Morris   6.120175
# 16      Adrian Peterson   6.078089
# 17         Duke Johnson   6.139119
# 18        Ty Montgomery   5.973629
# 19       Chris Thompson   6.010961
# 20      Giovani Bernard   5.801194
# 21          James White   5.866649
# 22      Latavius Murray   5.263004
# 23       Javorius Allen   5.098503
# 24       Mike Gillislee   4.701093
# 25         Theo Riddick   4.859084
# 26          CJ Anderson   4.488499
# 27    LeGarrette Blount   4.277004
# 28       Darren Sproles   4.145270
# 29           Frank Gore   4.003119
# ..                  ...        ...
# 40        Kyle Juszczyk   2.106373
# 41        Malcolm Brown   1.354275
# 42       Ameer Abdullah   1.178090
# 43        Marcus Murphy   1.122274
# 44       Raheem Mostert   1.023913
# 45     Jacquizz Rodgers   0.958200
# 46  Cameron Artis-Payne   0.678922
# 47           Mike Davis   0.199104
# 48  Benjamin Cunningham   0.186323
# 49        Stevan Ridley   0.057218
# 50      Damien Williams  -0.038640
# 51       Jamize Olawale  -0.284085
# 52      Anthony Sherman  -0.329027
# 53      Patrick DiMarco  -0.344949
# 54            Zach Line  -0.367831
# 55        Roosevelt Nix  -0.451050
# 56       Senorise Perry  -0.426596
# 57          Keith Smith  -0.438665
# 58        Tommy Bohanon  -0.452947
# 59       Michael Burton  -0.488060
# 60       Brandon Bolden  -0.488132
# 61        James Develin  -0.499484
# 62         Taiwan Jones  -0.576815
# 63      Derrick Coleman  -0.581716
# 64        Robert Turbin  -0.692301
# 65      Jerick McKinnon  -0.702582
# 66      Malcolm Johnson  -0.702582
# 67      Fozzy Whittaker  -0.692791
# 68          Zach Zenner  -0.690343
# 69        Trey Williams  -0.700624
#
# [70 rows x 2 columns]

# %%
results.shape
# Out:
# (70, 2)

# %%
results.to_csv('2018_week1_rb.csv', index= False)
