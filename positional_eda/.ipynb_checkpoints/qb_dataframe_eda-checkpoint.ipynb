# %%
import pandas as pd
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, LabelEncoder


# %matplotlib inline

# %%
qb_eda =pd.read_csv('../input/qb/qb_loc_cleaned.csv')
qb_eda.head()
# Out:
#    year  PlayerID                Name Team  Week Opponent  att  comp%  yds  \
# 0  2015       611          Joe Flacco  BAL     1      DEN   32   56.2  117
# 1  2015       732           Matt Ryan  ATL     1      PHI   34   67.6  298
# 2  2015      2428       Carson Palmer  ARI     1       NO   32   59.4  307
# 3  2015      2593       Aaron Rodgers   GB     1      CHI   23   78.3  189
# 4  2015      3807  Ben Roethlisberger  PIT     1       NE   38   68.4  351
#
#    td     rat  def_rk  h/a_1  surface_0   log_att  log_comp   log_yds  salary  \
# 0   0   38.15       1    0.0        1.0  1.505150  1.255273  2.068186    6700
# 1   2   90.07      30    1.0        0.0  1.531479  1.361728  2.474216    7500
# 2   3  122.79      32    1.0        1.0  1.505150  1.278754  2.487138    6500
# 3   3  140.49      25    0.0        1.0  1.361728  1.255273  2.276462    8600
# 4   1   95.39      15    0.0        0.0  1.579784  1.414973  2.545307    7300
#
#    points
# 0    2.68
# 1   18.62
# 2   28.68
# ...

# %%
# Read in current weeks players and salaries from draftkings
#week4 = pd.read_csv('../input/DKSalaries (1).csv')

qb = pd.read_csv('../input/qb/dk_stats_loc.csv')

# %% [markdown]
# home: h/a_1 == 1
#
#
# grass: surface_0 ==1

# %% [markdown]
# ## Matt Stafford

# %%
staff_vs_GB = ((qb.groupby(['Name','h/a_1','Opponent']).mean()).loc['Matthew Stafford']).loc[1.0].loc['GB']

staff = (qb.groupby('Name').mean()).loc['Matthew Stafford']

staff_home = (qb.groupby(['Name','h/a_1']).mean()).loc['Matthew Stafford'].loc[1.0]

# %%
staff_vs_GB
# Out:
# year          2016.000000
# PlayerID      9038.000000
# Week            15.666667
# comp            23.000000
# att             35.000000
# comp%           66.033333
# yds            296.666667
# yds/att          8.633333
# td               2.333333
# int              0.333333
# rat            112.940000
# ru_att           1.333333
# ru_yds           8.000000
# ru_yds/att       4.000000
# ru_td            0.000000
# def_rk          20.666667
# surface_0        0.000000
# salary        5433.333333
# points          24.000000
# Name: GB, dtype: float64

# %%
#plt.figure(figsize=(15,15))
for idx in staff_home.index[3:]:
    n_groups =1
    fig, ax = plt.subplots(figsize=(10,5))
    index = np.arange(n_groups)
    bar_width = 0.10
    opacity = 0.8

    rects1 = plt.bar(index, staff_home[idx], bar_width,
                     alpha=opacity,
                     color='b',
                     label='Satfford @ Home')

    rects2 = plt.bar(index + bar_width, staff_vs_GB[idx], bar_width,
                     alpha=opacity,
                     color='g',
                     label='Satfford vs GB @ Home')

    plt.xlabel('Home v GB')
    plt.ylabel(idx)
    plt.title('Stafford A Home vs Stafford @ Home vs GB')
    plt.xticks(index + bar_width, ('A', 'B'))
    plt.legend()

    plt.tight_layout()

# %% [markdown]
# ## Golden Tate

# %%
tate_vs_GB = ((qb.groupby(['Name','h/a_1','Opponent']).mean()).loc['Golden Tate']).loc[1.0].loc['GB']

tate = (qb.groupby('Name').mean()).loc['Golden Tate']

tate_home = (qb.groupby(['Name','h/a_1']).mean()).loc['Golden Tate'].loc[1.0]

# %%
# Convert attributes from to correct data type
def conv_atts(df):
    df['salary'] = df['salary'].apply(lambda x: int(x))
    df['h/a_1'] = df['h/a_1'].astype('category')
    df['surface_0'] = df['surface_0'].astype('category')
    df['def_rk'] = df['def_rk'].astype('category')
    df['PlayerID'] = df['PlayerID'].astype('category')

    return df

# %%
qb = conv_atts(qb)
qb.dtypes
# Out:
# year             int64
# PlayerID      category
# Name            object
# Team            object
# Week             int64
# Opponent        object
# comp             int64
# att              int64
# comp%          float64
# yds              int64
# yds/att        float64
# td               int64
# int              int64
# rat            float64
# ru_att           int64
# ru_yds           int64
# ru_yds/att     float64
# ru_td            int64
# def_rk        category
# h/a_1         category
# surface_0     category
# salary           int64
# points         float64
# dtype: object

# %% [markdown]
# ## EDA

# %%
qb.tail()
# Out:
#       year PlayerID            Name Team  Week Opponent  comp  att  comp%  \
# 1910  2018    19763      Josh Rosen  ARI     4      SEA    15   27   55.6
# 1911  2018    19781   Lamar Jackson  BAL     4      PIT     0    0    0.0
# 1912  2018    19790  Baker Mayfield  CLE     4      OAK    21   41   51.2
# 1913  2018    19801      Josh Allen  BUF     4       GB    16   33   48.5
# 1914  2018    19812     Sam Darnold  NYJ     4      JAX    17   34   50.0
#
#       yds  ...      rat  ru_att  ru_yds  ru_yds/att  ru_td  def_rk  h/a_1  \
# 1910  180  ...    88.50       2      13         6.5      0       6    1.0
# 1911    0  ...     0.00       4      17         4.2      0      31    0.0
# 1912  295  ...    70.68       4      10         2.5      0      14    0.0
# 1913  151  ...    36.30       5      19         3.8      0      13    0.0
# 1914  167  ...    74.02       2       8         4.0      0       1    0.0
#
#       surface_0 salary points
# 1910        1.0   4300  12.50
# ...

# %%
qb.describe()
# Out:
#               year         Week         comp          att        comp%  \
# count  1915.000000  1915.000000  1915.000000  1915.000000  1915.000000
# mean   2016.159791     8.643342    18.875718    29.959269    58.702402
# std       0.959772     5.170318     9.001986    13.582728    19.478462
# min    2015.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2015.000000     4.000000    15.000000    25.000000    54.500000
# 50%    2016.000000     8.000000    20.000000    32.000000    62.200000
# 75%    2017.000000    13.000000    25.000000    39.000000    69.200000
# max    2018.000000    17.000000    44.000000    66.000000   100.000000
#
#                yds      yds/att           td          int          rat  \
# count  1915.000000  1915.000000  1915.000000  1915.000000  1915.000000
# mean    215.143081     6.721775     1.327937     0.691906    83.377650
# std     106.696889     2.840606     1.199977     0.888868    34.124152
# ...

# %% [markdown]
# Some facts about NFL quaterbacks performance. First the attributes can be broken up into two categories: passing and rushing. There were 1762 quarterbacks that were on active NFL Rosters from 2015 to 2017. There were 107 observations of qbs that did not attempt a pass and most likely did not take a snap in live games. Qbs on average played 9 games a year attempted nearly 30 passes a game with an average completion percentage of  59%. They threw for 214 yds/ga and 1.3 td/game per game. The maximum number of passing attempts was 66 and the maximum number of passing completions was 44. One qb threw for 35 yds/att and someone had a perfect passer rating of 158.3

# %%
qb.columns
# Out:
# Index(['year', 'PlayerID', 'Name', 'Team', 'Week', 'Opponent', 'comp', 'att',
#        'comp%', 'yds', 'yds/att', 'td', 'int', 'rat', 'ru_att', 'ru_yds',
#        'ru_yds/att', 'ru_td', 'def_rk', 'h/a_1', 'surface_0', 'salary',
#        'points'],
#       dtype='object')

# %%
qb['Name'].nunique()
# Out:
# 111

# %%
# Define a QB's weekly participation as attempting a pass. Therefore, QB's with 0 PassesAttemtpted should be discarded

dnp =[]
for idx, val in enumerate(qb['att']):
    if val ==0:
        dnp.append(idx)

# %%
len(dnp)
# Out:
# 122

# %%
# Drop the 107 observations in which the qb did not participate

qb = qb.drop(dnp)
qb.shape
# Out:
# (1793, 23)

# %%
qb[qb['att']==0].count()
# Out:
# year          0
# PlayerID      0
# Name          0
# Team          0
# Week          0
# Opponent      0
# comp          0
# att           0
# comp%         0
# yds           0
# yds/att       0
# td            0
# int           0
# rat           0
# ru_att        0
# ru_yds        0
# ru_yds/att    0
# ru_td         0
# def_rk        0
# h/a_1         0
# surface_0     0
# salary        0
# points        0
# dtype: int64

# %%
qb[qb['Name'] =='Baker Mayfield'].describe()
# Out:
#          year      Week       comp        att      comp%         yds  yds/att  \
# count     2.0  2.000000   2.000000   2.000000   2.000000    2.000000  2.00000
# mean   2018.0  3.500000  19.000000  32.000000  62.550000  248.000000  7.95000
# std       0.0  0.707107   2.828427  12.727922  16.051324   66.468037  1.06066
# min    2018.0  3.000000  17.000000  23.000000  51.200000  201.000000  7.20000
# 25%    2018.0  3.250000  18.000000  27.500000  56.875000  224.500000  7.57500
# 50%    2018.0  3.500000  19.000000  32.000000  62.550000  248.000000  7.95000
# 75%    2018.0  3.750000  20.000000  36.500000  68.225000  271.500000  8.32500
# max    2018.0  4.000000  21.000000  41.000000  73.900000  295.000000  8.70000
#
#              td       int        rat    ru_att     ru_yds  ru_yds/att  ru_td  \
# count  2.000000  2.000000    2.00000  2.000000   2.000000    2.000000    2.0
# mean   1.000000  1.000000   85.38500  3.000000   4.000000    0.750000    0.0
# ...

# %%
total_points = qb['points'].sum()
total_points
# Out:
# 29814.56000000002

# %%
total_games = qb["points"].count()
total_games
# Out:
# 1793

# %%
passing_cols=[]
rushing_cols = []
for col in qb.columns:
    if 'ru' in col:
        rushing_cols.append(col)
    else:
        passing_cols.append(col)
        

rushing_cols.append('points')

# %%
rem_lst = ['Name','PlayerID','Opponent','Team','year','Week','def_rk','h/a_1','surface_0']
for val in rem_lst:
    passing_cols.remove(val)

# %%
passing_cols
# Out:
# ['comp',
#  'att',
#  'comp%',
#  'yds',
#  'yds/att',
#  'td',
#  'int',
#  'rat',
#  'salary',
#  'points']

# %%
rushing_cols
# Out:
# ['ru_att', 'ru_yds', 'ru_yds/att', 'ru_td', 'points']

# %%
cat_cols=['Name','td','ru_td', 'int', 'salary', 'def_rk', 'h/a_1', 'surface_0']
cat_cols.append('points')

# %%
qb[cat_cols].head()
# Out:
#                  Name  td  ru_td  int  salary def_rk h/a_1 surface_0  points
# 0          Joe Flacco   0      0    2    6700      1   0.0       1.0    2.68
# 1           Matt Ryan   2      0    2    7500     30   1.0       0.0   18.62
# 2       Carson Palmer   3      0    0    6500     32   1.0       1.0   28.68
# 3       Aaron Rodgers   3      0    0    8600     25   0.0       1.0   23.06
# 4  Ben Roethlisberger   1      0    1    7300     15   0.0       0.0   22.04

# %%
passing_cols
# Out:
# ['Name', 'points']

# %%
sns.pairplot(qb[passing_cols])

# %%
def boxplotter(data, column_name):
    fig= plt.figure(figsize=(6,4))

    ax = sns.boxplot(data[column_name], orient='v',
                    fliersize=8, linewidth=1.5, notch=False,
                    saturation=0.5)
    ax.set_title(column_name, fontsize=20)
    plt.show()

# %%
boxplotter(qb,'yds')

# %%
plt.scatter(qb.index,np.log(qb['att']))

# %% [markdown]
# ## MATTY ICE
# A breakdown of how Matt Ryan, a quarterback for the Atlanta Falcons, has performed from 2015-2018.

# %%
matty_ice = qb_df[qb_df['Name'] =='Matt Ryan']
matty_ice.reset_index(inplace=True, drop=True)
matty_ice.describe()['FantasyPointsDraftKings'].mean()
# Out:
# 22.617064224631353

# %%
matty_ice[passing_cols]
# Out:
#          Name  PassingCompletions  PassingAttempts  \
# 0   Matt Ryan                  23               34
# 1   Matt Ryan                  30               46
# 2   Matt Ryan                  24               36
# 3   Matt Ryan                  19               27
# 4   Matt Ryan                  24               42
# 5   Matt Ryan                  30               44
# 6   Matt Ryan                  22               38
# 7   Matt Ryan                  37               45
# 8   Matt Ryan                  30               45
# 9   Matt Ryan                  25               46
# 10  Matt Ryan                  22               31
# 11  Matt Ryan                  30               45
# 12  Matt Ryan                  22               34
# 13  Matt Ryan                  22               35
# 14  Matt Ryan                  23               30
# 15  Matt Ryan                  24               36
# 16  Matt Ryan                  27               39
# ...

# %%
home_ice = (matty_ice[matty_ice['h/a1']==1]).reset_index(drop=True)
away_ice = (matty_ice[matty_ice['h/a1']==0]).reset_index(drop=True)


home_ice['games'] = home_ice.index+1
away_ice['games'] = away_ice.index+1

avg_home_pts = home_ice['FantasyPointsDraftKings'].mean()
avg_away_pts = away_ice['FantasyPointsDraftKings'].mean()
print(avg_home_pts,avg_away_pts)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(matty_ice[passing_cols].corr(), annot=True)

# %%
matty_ice['games'] = matty_ice.index +1
matty_ice
# Out:
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     PlayerID       Name Team  Week Opponent  PassingCompletions  \
# 0        732  Matt Ryan  ATL     1      PHI                  23
# 1        732  Matt Ryan  ATL     2      NYG                  30
# 2        732  Matt Ryan  ATL     3      DAL                  24
# 3        732  Matt Ryan  ATL     4      HOU                  19
# 4        732  Matt Ryan  ATL     5      WAS                  24
# 5        732  Matt Ryan  ATL     6       NO                  30
# 6        732  Matt Ryan  ATL     7      TEN                  22
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(matty_ice[rushing_cols].corr(), annot=True)

# %% [markdown]
# ## BIG BEN

# %%
big_ben = qb_df[qb_df['Name'] =='Ben Roethlisberger']
big_ben.reset_index(inplace=True, drop=True)
big_ben.describe()['FantasyPointsDraftKings'].mean()
# Out:
# 23.354522809562884

# %%
qb_df.to_csv('../input/qb/dk_qb_loc.csv', index=False)

# %%
qb_df['surface_encoded'] = qb_df['surface_encoded'].values.reshape(-1,1)

# %%
plt.bar()

# %%
def boxplotter(data, column_name):
    fig= plt.figure(figsize=(6,4))

    ax = sns.boxplot(data[column_name], orient='v',
                    fliersize=8, linewidth=1.5, notch=False,
                    saturation=0.5)
    ax.set_title(column_name, fontsize=20)
    plt.show()

# %%
boxplotter(home_ice, 'FantasyPointsDraftKings')
boxplotter(away_ice, 'FantasyPointsDraftKings')

# %%
qb[passing_cols][:10]
# Out:
#     comp  att  comp%  yds  yds/att  td  int     rat  salary  points
# 0     18   32   56.2  117      3.7   0    2   38.15    6700    2.68
# 1     23   34   67.6  298      8.8   2    2   90.07    7500   18.62
# 2     19   32   59.4  307      9.6   3    0  122.79    6500   28.68
# 3     18   23   78.3  189      8.2   3    0  140.49    8600   23.06
# 4     26   38   68.4  351      9.2   1    1   95.39    7300   22.04
# 5     36   45   80.0  356      7.9   3    2  103.33    7300   27.14
# 6     25   32   78.1  288      9.0   4    0  143.75    7700   27.62
# 7     20   36   55.6  189      5.2   0    0   70.25    7400    8.36
# 8      5    8   62.5   49      6.1   0    0   79.69    5200    3.26
# 10    22   33   66.7  243      7.4   3    0  118.62    8000   23.22

# %% [markdown]
# ## Outliers

# %%
qb.dtypes
# Out:
# year             int64
# PlayerID      category
# Name            object
# Team            object
# Week             int64
# Opponent        object
# comp             int64
# att              int64
# comp%          float64
# yds              int64
# yds/att        float64
# td               int64
# int              int64
# rat            float64
# ru_att           int64
# ru_yds           int64
# ru_yds/att     float64
# ru_td            int64
# def_rk        category
# h/a_1         category
# surface_0     category
# salary           int64
# points         float64
# dtype: object

# %%
def get_outliers(df):
    #rem_cols = ['Week','Year','Name','Opponent','Team']
    col_dict ={}
    for col in df.columns:
        if df[col].dtype.name == ('int64' or 'float64'):
            col_dict.update({col:df[col].describe()})

    col_name = []
    outliers_lst = []
    for col in df.columns:
        if df[col].dtype.name == ('int64' or 'float64'):
            col_name.append(col)
            outliers_lst.append(len(abs(df[col]-col_dict[col]['mean'])[df[col] > (col_dict[col]['std'])*3]))
            
    outliers= pd.DataFrame()
    outliers['col_name'] = col_name
    outliers['# of outliers'] = outliers_lst
    


    

    percent_lst = [ ]
    for idx, val in enumerate(outliers['# of outliers']):
        percent_lst.append(val/int(df.shape[0])*100)

    outliers['pecent'] = percent_lst
    outliers = outliers.drop(outliers.index[:2])



    return outliers

# %%
get_outliers(qb)
# Out:
#    col_name  # of outliers     pecent
# 2      comp            594  33.128834
# 3       att            791  44.116007
# 4       yds            525  29.280535
# 5        td            100   5.577245
# 6       int             82   4.573341
# 7    ru_att             96   5.354155
# 8    ru_yds             70   3.904071
# 9     ru_td             12   0.669269
# 10   salary           1789  99.776910

# %%
qb['log_att'] = qb['att'].apply(lambda x: np.log10(x))
qb['log_comp'] = qb['comp'].apply(lambda x: np.log10(x))
qb['log_yds'] = qb['yds'].apply(lambda x: np.log10(x))

# %%
qb.head()
# Out:
#    year PlayerID                Name Team  Week Opponent  comp  att  comp%  \
# 0  2015      611          Joe Flacco  BAL     1      DEN    18   32   56.2
# 1  2015      732           Matt Ryan  ATL     1      PHI    23   34   67.6
# 2  2015     2428       Carson Palmer  ARI     1       NO    19   32   59.4
# 3  2015     2593       Aaron Rodgers   GB     1      CHI    18   23   78.3
# 4  2015     3807  Ben Roethlisberger  PIT     1       NE    26   38   68.4
#
#    yds    ...     ru_yds/att  ru_td  def_rk  h/a_1  surface_0  salary  points  \
# 0  117    ...            0.0      0       1    0.0        1.0    6700    2.68
# 1  298    ...            1.4      0      30    1.0        0.0    7500   18.62
# 2  307    ...            4.7      0      32    1.0        1.0    6500   28.68
# 3  189    ...            4.4      0      25    0.0        1.0    8600   23.06
# 4  351    ...            0.0      0      15    0.0        0.0    7300   22.04
#
#     log_att  log_comp   log_yds
# ...

# %%
pass_corr = qb[passing_cols].corr()
rush_corr = qb[rushing_cols].corr()

# %%
plt.figure(figsize = (20,20))
sns.heatmap(pass_corr, annot=True)

# %%
qb = pd.concat([yearly_dict['player_2015'], yearly_dict['player_2016']])
qb = pd.concat([qb, yearly_dict['player_2017']])
qb = pd.concat([qb, yearly_dict['player_2018']])

# %%
qb.drop('Unnamed: 0', axis=1, inplace=True)

# %%
qb.head()
# Out:
#                            PlayerID  att  comp  comp%  def_rk  int  points  \
# Name        Week Opponent
# AJ McCarron 12   LAR          16116    1     1  100.0      10    0    0.12
#             13   CLE          16116    3     2   66.7      28    0    0.76
#             14   PIT          16116   32    22   68.8      24    2   18.00
#             15   SF           16116   21    15   71.4      16    0   11.88
#             16   DEN          16116   35    22   62.9       1    0   13.10
#
#                               rat  ru_att  ru_td  ru_yds  ru_yds/att  salary  \
# Name        Week Opponent
# AJ McCarron 12   LAR        79.17       0      0       0         0.0    6000
#             13   CLE        84.03       0      0       0         0.0    5000
#             14   PIT        90.62       3      0       8         2.7    5000
#             15   SF        115.58       2      0       2         1.0    3000
#             16   DEN        87.80       4      0      21         5.2    5100
# ...

# %%
boxplotter(week1,'ru_yds')

boxplotter(qb, 'Yds/Att')

boxplotter(qb,'Comp')

boxplotter(qb,'TD')

boxplotter(qb,'Int')

# %%
fig = plt.figure(figsize=(12,6))

ax = sns.boxplot(data=qb, orient='v', fliersize=5, linewidth=3, notch=True,
                 saturation=0.5)

ax.set_title('Qb Stats')
# Out:
# Text(0.5,1,'Qb Stats')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(qb.corr(), annot=True)

# %%
rushing_cols =[]
for col in qb.columns:
    if 'ru' in col:
        rushing_cols.append(col)

# %%
rushing_cols.append('comp')
rushing_cols.append('yds/att')
rushing_cols.append('int')
qb_eda = qb.drop(rushing_cols, axis=1)

# %%
cols = qb_eda.columns.tolist()
cols = cols[:-5] + cols[-3:] + cols[-5:-3]
qb_eda = qb_eda[cols]

# %%
qb_eda.head()
# Out:
#    year PlayerID                Name Team  Week Opponent  att  comp%  yds  td  \
# 0  2015      611          Joe Flacco  BAL     1      DEN   32   56.2  117   0
# 1  2015      732           Matt Ryan  ATL     1      PHI   34   67.6  298   2
# 2  2015     2428       Carson Palmer  ARI     1       NO   32   59.4  307   3
# 3  2015     2593       Aaron Rodgers   GB     1      CHI   23   78.3  189   3
# 4  2015     3807  Ben Roethlisberger  PIT     1       NE   38   68.4  351   1
#
#       rat def_rk h/a_1 surface_0   log_att  log_comp   log_yds  salary  points
# 0   38.15      1   0.0       1.0  1.505150  1.255273  2.068186    6700    2.68
# 1   90.07     30   1.0       0.0  1.531479  1.361728  2.474216    7500   18.62
# 2  122.79     32   1.0       1.0  1.505150  1.278754  2.487138    6500   28.68
# 3  140.49     25   0.0       1.0  1.361728  1.255273  2.276462    8600   23.06
# 4   95.39     15   0.0       0.0  1.579784  1.414973  2.545307    7300   22.04

# %%
qb_eda.drop('PlayerID', axis=1, inplace=True)

# %%
qb_eda.to_csv('../input/qb/qb_loc_cleaned.csv', index=False)

# %% [markdown]
# # Quarterback Feature Engineering

# %% [markdown]
# ## Career Average

# %%
# Week 1 stats are player's career average through 2014 season
# Populate current dataframe with current year averages of players

def career_average (grouped_df1, grouped_df2=None):
    for col in grouped_df1: # Iterate through every attribute in the team_stats dataframe
        points=[]  # Create an empty list to hold the season average of the current attribute

        try:
            for player in grouped_df1.index.levels[0]:  # Iterate through every player in the team_stats df
                if player in list(grouped_df2.index.levels[0].unique()):
                    total =[grouped_df2.loc[player][col][-1]] # If player not a rookie, use final average from 2015
                else:
                    total =[]  # create an empty list to hold the weekly attributes value
                
                for week in grouped_df1.loc[player].index: # Iterate throough every week for the current player
                    total.append(grouped_df1.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                    points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list
                    
            grouped_df1['{}_car'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe


                                
        except:
            for player in grouped_df1.index.levels[0]:  # Iterate through every player in the team_stats df
                total = []

                for week in grouped_df1.loc[player].index: # Iterate throough every week for the current player
                    total.append(grouped_df1.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                    points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list

            grouped_df1['{}_car'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe
    return grouped_df1

# %%
qb_career_2015 = career_average(yearly_dict['player_2015'])
qb_career_2016 = career_average(yearly_dict['player_2016'],yearly_dict['player_2015'])
qb_career_2017 = career_average(yearly_dict['player_2017'], yearly_dict['player_2016'])
qb_career_2018 = career_average(yearly_dict['player_2018'],yearly_dict['player_2017'])

# %%
player_career = pd.concat([qb_career_2015, qb_career_2016])
player_career = pd.concat([player_career, qb_career_2017])
player_career = pd.concat([player_career, qb_career_2018])

# %%
player_career.shape
# Out:
# (1838, 36)

# %% [markdown]
# ## Recent Player Stats
# Calculate the 4 game moving average of all attributes for each player and insert resluts into positional dataframe

# %%
# A function designed to calcuate a player's 4 game moving average in seasons 2015,2016,2017,2018

def moving_average(grouped_df, games):
    for col in grouped_df:  # Iterate through every attribute in the team_stats dataframe
        ma4 = []  # Create an empty list to hold the season average of the current attribute
        for player in grouped_df.index.levels[0]:  # Iterate through every player in the team_stats df
            total = [] # INstantiate a deque container with a max length of 3 to hold the three most current games for player
            count = 0 # Counter to track week number 
            for week in grouped_df.loc[player].index: # Iterate through every week for relevant player d
                if count < games: # check count value to start 3 game moving average
                    ma4.append(0)  # week 1 through 3 have 3 game movong average of 0
                    total.append(grouped_df.loc[player].loc[week][col])  # Add the value current player's attribute total from the left
                    count += 1  # Increase count
                else:  # Once 3 game moving average is avaliable
                    ma4.append(np.mean(total))  # Add the average of the 3 games held in totals 3 game moivng average list
                    total.append(grouped_df.loc[player].loc[week][col]) # Replace 3 set block with a first in first out process
        grouped_df['{}_ma'.format(col.lower())] = ma4  # Populate databse with 3 game moving average list
       

    return grouped_df

# %%
player_ma_2015 = moving_average(yearly_dict['player_2015'],4)
player_ma_2016 = moving_average(yearly_dict['player_2016'],4)
player_ma_2017 = moving_average(yearly_dict['player_2017'],4)
player_ma_2018 = moving_average(yearly_dict['player_2018'],4)

# %%
player_yearly_ma = pd.concat([player_ma_2015, player_ma_2016])
player_yearly_ma = pd.concat([player_yearly_ma,player_ma_2017])
player_yearly_ma = pd.concat([player_yearly_ma,player_ma_2018])
player_yearly_ma[0:100]

# %%
player_ma_2015.loc['Aaron Rodgers']
# Out:
#                PlayerID  comp  att  comp%  yds  yds/att  td  int  \
# Week Opponent
# 1    CHI           2593    18   23   78.3  189      8.2   3    0
# 2    SEA           2593    25   33   75.8  249      7.5   2    0
# 3    KC            2593    24   35   68.6  333      9.5   5    0
# 4    SF            2593    22   32   68.8  224      7.0   1    0
# 5    LAR           5186    38   60  126.6  482     16.0   4    4
# 6    LAC           2593    16   29   55.2  255      8.8   2    0
# 8    DEN           2593    14   22   63.6   77      3.5   0    0
# 9    CAR           2593    25   48   52.1  369      7.7   4    1
# 10   DET           2593    35   61   57.4  333      5.5   2    0
# 11   MIN           2593    16   34   47.1  212      6.2   2    0
# 12   CHI           2593    22   43   51.2  202      4.7   1    1
# 13   DET           2593    24   36   66.7  273      7.6   2    1
# 14   DAL           2593    22   35   62.9  218      6.2   2    0
# ...

# %%
player_2015['year']=2015
player_2016['year']=2016
player_2017['year']=2017
player_2018['year']=2018

# %%
qb_recent = pd.concat([player_2015,player_2016])

# %%
qb_recent=pd.concat([qb_recent,player_2017])
qb_recent=pd.concat([qb_recent,player_2018])

# %%
qb_recent.head()
# Out:
#                            PlayerID  comp  PassingAttempts  comp%  yds  \
# Name        Week Opponent
# AJ McCarron 12   LAR          16116     1                1  100.0    3
#             13   CLE          16116     2                3   66.7   19
#             14   PIT          16116    22               32   68.8  280
#             15   SF           16116    15               21   71.4  192
#             16   DEN          16116    22               35   62.9  200
#
#                            yds/att  td  int  PassingRating  ru_att    ...      \
# Name        Week Opponent                                             ...
# AJ McCarron 12   LAR           3.0   0    0          79.17       0    ...
#             13   CLE           6.3   0    0          84.03       0    ...
#             14   PIT           8.8   2    2          90.62       3    ...
#             15   SF            9.1   1    0         115.58       2    ...
# ...

# %% [markdown]
# ## Moving Average

# %%
player_2015 = yearly_dict['player_2015']
player_2016 = yearly_dict['player_2016']
player_2017 = yearly_dict['player_2017']
player_2018 = yearly_dict['player_2018']

# %%
player_2015 =
# Out:
#                                  PlayerID  comp  att  comp%  yds  yds/att  td  \
# Name              Week Opponent
# AJ McCarron       12   LAR          16116     1    1  100.0    3      3.0   0
#                   13   CLE          16116     2    3   66.7   19      6.3   0
#                   14   PIT          16116    22   32   68.8  280      8.8   2
#                   15   SF           16116    15   21   71.4  192      9.1   1
#                   16   DEN          16116    22   35   62.9  200      5.7   1
#                   17   BAL          16116    17   27   63.0  160      5.9   2
# Aaron Rodgers     1    CHI           2593    18   23   78.3  189      8.2   3
#                   2    SEA           2593    25   33   75.8  249      7.5   2
#                   3    KC            2593    24   35   68.6  333      9.5   5
#                   4    SF            2593    22   32   68.8  224      7.0   1
#                   5    LAR           5186    38   60  126.6  482     16.0   4
# ...

# %%
player_2018
# Out:
#                                   PlayerID  comp  PassingAttempts  comp%  yds  \
# Name               Week Opponent
# Aaron Rodgers      1    CHI           2593    20               30   66.7  286
#                    2    MIN           2593    30               42   71.4  281
# Alex Smith         1    ARI           6739    21               30   70.0  255
#                    2    IND           6739    33               46   71.7  292
# Andrew Luck        1    CIN          14008    39               53   73.6  319
#                    2    WAS          14008    21               31   67.7  179
# Andy Dalton        1    IND          12841    21               28   75.0  243
#                    2    BAL          12841    24               42   57.1  265
# Ben Roethlisberger 1    CLE           3807    23               41   56.1  335
#                    2    KC            3807    39               60   65.0  452
# Blaine Gabbert     1    MIA          12982    11               22   50.0  117
# ...

# %%
keep =[] 
for col in qb_recent.columns:
    if 'ma' in col:
        keep.append(col)
        


qb_recent = qb_recent[keep]
qb_recent.`()

# %%
qb_stats = pd.concat([qb_car,qb_recent], axis=1)

qb_stats.to_csv('../input/qb/qb_stats.csv', index=False)

# %% [markdown]
# ## Current Stats
# Weekly moving average for every year from 2015 through 2018

# %%
# Read in dataframe of quarterback stats from 2015 through 2017

qb = pd.read_csv('../input/qb/dk_stats_loc.csv')
qb_2018 = pd.read_csv('../input/qb/dk_weekly_update.csv')
week1_def = pd.read_csv('../input/def/defense_2018_projections.csv')

qb.columns

# Rename columns for readability
qb.rename(columns={'PassingCompletions':'comp',
                  'PassongAttempts':'att',
                  'PassingCompletionPercentage':'comp%',
                  'PassingYards':'yds',
                  'PassingYardsPerAttempt':'yds/att',
                  'PassingTouchdowns':'td',
                  'PassingInterceptions':'int',
                  'PasserRatirng':'rat',
                  'RushingAttempts':'ru_att',
                  'RushingYards':'ru_yds',
                  'RushingYardsPerAttempt':'ru_yds/att',
                  'RushingTouchdowns':'ru_td',
                  'FantasyPointsDraftKings':'points'},inplace=True)

# CReate temporary dataframe to hold the year and surface attributes

temp = qb[['year','surface']]

# Drop columns and convert values to integers

qb.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1,inplace=True)
qb.replace('null',0,inplace=True)
qb['salary']=qb['salary'].apply(lambda x:int(x))

# %%
# Rename columns for readability
qb_2018.rename(columns={'PassingCompletions':'comp',
                  'PassongAttempts':'att',
                  'PassingCompletionPercentage':'comp%',
                  'PassingYards':'yds',
                  'PassingYardsPerAttempt':'yds/att',
                  'PassingTouchdowns':'td',
                  'PassingInterceptions':'int',
                  'PasserRatirng':'rat',
                  'RushingAttempts':'ru_att',
                  'RushingYards':'ru_yds',
                  'RushingYardsPerAttempt':'ru_yds/att',
                  'RushingTouchdowns':'ru_td',
                  'FantasyPointsDraftKings':'points'},inplace=True)

# %%
# Concatenate historical dataframe wiith the most recent week stats
qb=pd.concat([qb,qb_2018])
qb.head()

# Encode the all non_numeric attributes
encoder = LabelEncoder()
qb['h/a_encoded'] = encoder.fit_transform(qb['h/a'])
qb['surface_encoded']=encoder.fit_transform(qb['surface'])
qb['surface_encoded'].head()
qb['h/a_encoded'].head()


# Seperate dataframe by year
player_2015 = qb[qb['year']==2015]
player_2016 = qb[qb['year']==2016]
player_2017 = qb[qb['year']==2017]
player_2018= qb[qb['year']==2018]

# Drop year and surface 
player_2015.drop(['year','surface'],axis=1,inplace=True)
player_2016.drop(['year','surface'],axis=1,inplace=True)
player_2017.drop(['year','surface'],axis=1,inplace=True)
player_2018.drop(['year','surface'],axis=1,inplace=True)

#Group dataframes 
player_2015 = player_2015.groupby(['Name','Week','Opponent']).sum()
player_2016 = player_2016.groupby(['Name','Week','Opponent']).sum()
player_2017 = player_2017.groupby(['Name','Week','Opponent']).sum()
player_2018 = player_2018.groupby(['Name','Week','Opponent']).sum()
# Out:
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
player_2015.head()
# Out:
#                            PlayerID  comp  PassingAttempts  comp%  yds  \
# Name        Week Opponent
# AJ McCarron 12   LAR          16116     1                1  100.0    3
#             13   CLE          16116     2                3   66.7   19
#             14   PIT          16116    22               32   68.8  280
#             15   SF           16116    15               21   71.4  192
#             16   DEN          16116    22               35   62.9  200
#
#                            yds/att  td  int  PassingRating  ru_att  ru_yds  \
# Name        Week Opponent
# AJ McCarron 12   LAR           3.0   0    0          79.17       0       0
#             13   CLE           6.3   0    0          84.03       0       0
#             14   PIT           8.8   2    2          90.62       3       8
#             15   SF            9.1   1    0         115.58       2       2
#             16   DEN           5.7   1    0          87.80       4      21
#
# ...

# %%
# Week 1 stats are player's career average through 2014 season
# Populate current dataframe with current year averages of players

def insert_data (df):
    for col in df: # Iterate through every attribute in the team_stats dataframe
        points=[]  # Create an empty list to hold the season average of the current attribute

        for player in df.index.levels[0]:  # Iterate through every player in the team_stats df
            total =[]# create an empty list to hold the weekly attributes valu3

            for week in df.loc[player].index: # Iterate throough every week for the current player
                total.append(df.loc[player].loc[week][col]) # Add player's value for the current week's attribute to the total list
                points.append(round(np.mean(total),2))  # Add the average of the total list to the season average list

        df['{}_avg'.format(col.lower())] = points # Insert season average list for current attribute into the current stats dataframe
    return df

# %%
qb_weekly_2015 = insert_data(player_2015)
qb_weekly_2016 = insert_data(player_2016)
qb_weekly_2017 = insert_data(player_2017)
qb_weekly_2018 = insert_data(player_2018)

# %%
qb_weekly_2015.head()
# Out:
#                            PlayerID  comp  PassingAttempts  comp%  yds  \
# Name        Week Opponent
# AJ McCarron 12   LAR          16116     1                1  100.0    3
#             13   CLE          16116     2                3   66.7   19
#             14   PIT          16116    22               32   68.8  280
#             15   SF           16116    15               21   71.4  192
#             16   DEN          16116    22               35   62.9  200
#
#                            yds/att  td  int  PassingRating  ru_att  \
# Name        Week Opponent
# AJ McCarron 12   LAR           3.0   0    0          79.17       0
#             13   CLE           6.3   0    0          84.03       0
#             14   PIT           8.8   2    2          90.62       3
#             15   SF            9.1   1    0         115.58       2
#             16   DEN           5.7   1    0          87.80       4
#
#                                     ...             passingrating_car_avg  \
# ...

# %%
qb_weekly = pd.concat([qb_weekly_2015,qb_weekly_2016])
qb_weekly = pd.concat([qb_weekly, qb_weekly_2017])
qb_weekly = pd.concat([qb_weekly, qb_weekly_2018])

# %%
keep =[]
for col in qb_weekly.columns:
    if 'avg'in col:
        keep.append(col)

# %%
qb_weekly = qb_weekly[keep]
qb_weekly[0:50]
# Out:
#                              comp%_avg  comp%_car_avg  comp_avg  comp_car_avg  \
# Name          Week Opponent
# AJ McCarron   12   LAR          100.00         100.00      1.00          1.00
#               13   CLE           83.35          91.68      1.50          1.25
#               14   PIT           78.50          87.28      8.33          3.61
#               15   SF            76.72          84.64     10.00          5.21
#               16   DEN           73.96          82.51     12.40          6.65
#               17   BAL           72.13          80.78     13.17          7.73
# Aaron Rodgers 1    CHI           78.30          78.30     18.00         18.00
#               2    SEA           77.05          77.68     21.50         19.75
#               3    KC            74.23          76.53     22.33         20.61
#               4    SF            72.88          75.61     22.25         21.02
#               5    LAR           83.62          77.22     25.40         21.90
# ...

# %%
qb_stats = pd.concat([qb_stats,qb_weekly], axis=1)
qb_stats.shape
# Out:
# (1838, 89)

# %%
qb_stats.columns
# Out:
# Index(['PassingAttempts', 'PassingRating', 'PlayerID', 'comp', 'comp%',
#        'def_rk', 'int', 'points', 'ru_att', 'ru_td', 'ru_yds', 'ru_yds/att',
#        'salary', 'td', 'yds', 'yds/att', 'h/a_encoded', 'surface_encoded',
#        'passingattempts_car', 'passingrating_car', 'playerid_car', 'comp_car',
#        'comp%_car', 'def_rk_car', 'int_car', 'points_car', 'ru_att_car',
#        'ru_td_car', 'ru_yds_car', 'ru_yds/att_car', 'salary_car', 'td_car',
#        'yds_car', 'yds/att_car', 'h/a_encoded_car', 'surface_encoded_car',
#        'year', 'playerid_ma', 'comp_ma', 'passingattempts_ma', 'comp%_ma',
#        'yds_ma', 'yds/att_ma', 'td_ma', 'int_ma', 'passingrating_ma',
#        'ru_att_ma', 'ru_yds_ma', 'ru_yds/att_ma', 'ru_td_ma', 'points_ma',
#        'salary_ma', 'def_rk_ma', 'comp%_avg', 'comp%_car_avg', 'comp_avg',
#        'comp_car_avg', 'def_rk_avg', 'def_rk_car_avg', 'h/a_encoded_avg',
# ...

# %%
drop = []
for col in qb_stats.columns:
    if ('car_avg') in col:
        drop.append(col)

# %%
qb_stats = qb_stats.drop(drop, axis=1)
qb_stats[0:50]
# Out:
#                              PassingAttempts  PassingRating  PlayerID  comp  \
# Name          Week Opponent
# AJ McCarron   12   LAR                     1          79.17     16116     1
#               13   CLE                     3          84.03     16116     2
#               14   PIT                    32          90.62     16116    22
#               15   SF                     21         115.58     16116    15
#               16   DEN                    35          87.80     16116    22
#               17   BAL                    27         103.94     16116    17
# Aaron Rodgers 1    CHI                    23         140.49      2593    18
#               2    SEA                    33         116.86      2593    25
#               3    KC                     35         138.45      2593    24
#               4    SF                     32          98.96      2593    22
#               5    LAR                    60         165.56      5186    38
# ...

# %%
temp.columns
# Out:
# Index(['PassingAttempts', 'PassingRating', 'PlayerID', 'comp', 'comp%',
#        'def_rk', 'int', 'points', 'ru_att', 'ru_td', 'ru_yds', 'ru_yds/att',
#        'salary', 'td', 'yds', 'yds/att', 'h/a_encoded', 'surface_encoded',
#        'passingattempts_car', 'passingrating_car', 'playerid_car', 'comp_car',
#        'comp%_car', 'def_rk_car', 'int_car', 'points_car', 'ru_att_car',
#        'ru_td_car', 'ru_yds_car', 'ru_yds/att_car', 'salary_car', 'td_car',
#        'yds_car', 'yds/att_car', 'h/a_encoded_car', 'surface_encoded_car',
#        'year', 'playerid_ma', 'comp_ma', 'passingattempts_ma', 'comp%_ma',
#        'yds_ma', 'yds/att_ma', 'td_ma', 'int_ma', 'passingrating_ma',
#        'ru_att_ma', 'ru_yds_ma', 'ru_yds/att_ma', 'ru_td_ma', 'points_ma',
#        'salary_ma', 'def_rk_ma', 'comp%_avg', 'comp_avg', 'def_rk_avg',
#        'h/a_encoded_avg', 'int_avg', 'passingattempts_avg',
#        'passingrating_avg', 'playerid_avg', 'points_avg', 'ru_att_avg',
# ...

# %%
week1_def.head()
# Out:
#    Rank                  Name Team Position  Played  TacklesForLoss  Sacks  \
# 0     1  Jacksonville Jaguars  JAX      DST      16             103     49
# 1     2  Los Angeles Chargers  LAC      DST      16              93     44
# 2     3      Los Angeles Rams  LAR      DST      16              82     45
# 3     4   Philadelphia Eagles  PHI      DST      16              99     39
# 4     5     Minnesota Vikings  MIN      DST      16              82     42
#
#    QuarterbackHits  Interceptions  FumblesRecovered  Safeties  \
# 0              113             18                14         0
# 1               85             17                13         0
# 2              100             17                15         2
# 3              115             17                14         0
# 4               85             17                12         1
#
#    DefensiveTouchdowns  SpecialTeamsTouchdowns  PointsAllowed  \
# 0                    4                       1            268
# ...

# %%
week1['def_ru_rk'] = list(map(lambda x: week1_def.loc[x]['Rank'], week1['Opp']))
week1['def_pass_rk'] = list(map(lambda x: week1_def.loc[x]['Rank'], week1['Opp']))

week1['year'] =2018

# %%
for col in qb.columns:
    print(qb[col].describe(), '\n')
# Out:
# count           2729
# unique           108
# top       Drew Brees
# freq             102
# Name: Player, dtype: object
#
# count     2729
# unique      32
# top         NO
# freq       118
# Name: Team, dtype: object
#
# count    2729.000000
# mean        8.898864
# std         4.945676
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        13.000000
# max        17.000000
# Name: Week, dtype: float64
#
# count     2729
# unique      32
# top        ATL
# freq       106
# Name: Opp, dtype: object
#
# count    2729.000000
# mean       21.953096
# std         7.305794
# min         0.000000
# 25%        18.000000
# 50%        22.000000
# 75%        26.000000
# max        44.000000
# Name: Comp, dtype: float64
#
# count    2729.000000
# mean       34.285453
# std        11.020985
# min         0.000000
# 25%        29.000000
# 50%        35.000000
# 75%        41.000000
# max        66.000000
# Name: Att, dtype: float64
#
# count    2729.000000
# ...

# %%
qb.corr()
# Out:
#                  Week      Comp       Att       Pct       Yds   Yds/Att  \
# Week         1.000000 -0.073167 -0.056137 -0.045304 -0.067497 -0.030958
# Comp        -0.073167  1.000000  0.907936  0.493671  0.841669  0.209697
# Att         -0.056137  0.907936  1.000000  0.232028  0.781086  0.047118
# Pct         -0.045304  0.493671  0.232028  1.000000  0.445060  0.682635
# Yds         -0.067497  0.841669  0.781086  0.445060  1.000000  0.542607
# Yds/Att     -0.030958  0.209697  0.047118  0.682635  0.542607  1.000000
# TD          -0.021643  0.346127  0.251715  0.340857  0.467585  0.409962
# Int         -0.011587  0.246737  0.371266 -0.086776  0.206437 -0.101037
# ru_att       0.003627 -0.099053 -0.083553  0.065418 -0.086053  0.068499
# ru_yds       0.026820 -0.122100 -0.068672 -0.020230 -0.130288 -0.028087
# yds/ru_att   0.007510 -0.041320  0.018885 -0.021183 -0.045855 -0.027105
# ru_td        0.013918 -0.072680 -0.073527  0.039975 -0.067329  0.042007
# ...

# %%
corr = pd.DataFrame(index=qb.columns[4:])

# %%
np.corrcoef(qb.points, qb[col]))
# Out:
#   File "<ipython-input-113-a2a2e6077867>", line 1
#     np.corrcoef(qb.points, qb[col]))
#                                    ^
# SyntaxError: invalid syntax

# %%
corr
# Out:
# Empty DataFrame
# Columns: []
# Index: [Comp, Att, Pct, Yds, Yds/Att, TD, Int, ru_att, ru_yds, yds/ru_att, ru_td, points, year]

# %%
coef =[]
for col in qb.columns[4:]:
    #print(qb[col])
    coef.append(np.corrcoef(qb.points,qb[col])[0][1])

# %%
corr[1] = coef

# %%
corr
# Out:
#                    1
# Comp        0.571454
# Att         0.474329
# Pct         0.438055
# Yds         0.740128
# Yds/Att     0.541291
# TD          0.757600
# Int        -0.065047
# ru_att      0.190700
# ru_yds      0.207899
# yds/ru_att  0.157456
# ru_td       0.210013
# points      1.000000
# year        0.333488

# %%
qb['ru_yds2'] = qb['ru_yds'].apply(lambda x: x**2)

# %%
pd.scatter_matrix(qb[4:], figsize=(20,15))
plt.show()
# Out:
# C:\Users\bobal\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
#A function that will covert a time series database into a supervised learning database

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
            cols.append(df.shift(i))
            names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
train  = qb
test = week1

# %%
qb.columns
# Out:
# Index(['Player', 'Team', 'Week', 'Opp', 'Comp', 'Att', 'Pct', 'Yds', 'Yds/Att',
#        'TD', 'Int', 'ru_att', 'ru_yds', 'yds/ru_att', 'ru_td', 'points',
#        'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
week1.columns
# Out:
# Index(['Player', 'Team', 'Week', 'Opp', 'Comp', 'Att', 'Pct', 'Yds', 'Yds/Att',
#        'TD', 'Int', 'ru_att', 'ru_yds', 'yds/ru_att', 'ru_td', 'points',
#        'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
passing = ['Comp','Att','Pct','Yds','Yds/Att','TD','Int']

# %%
y_train = train['points']
y_test = test['points']
X_train = train.drop('points',axis=1)
X_test = test.drop('points', axis=1)

# %%
X_train = X_train[X_train.columns[4:]]
X_test = X_test[X_test.columns[4:]]

# %%
X_train = X_train[X_train.columns[4:11]]
X_test = X_test[X_test.columns[4:11]]

# %%
X_train.shape
# Out:
# (2729, 14)

# %%
X_test.shape
# Out:
# (57, 14)

# %%
X_train.columns
# Out:
# Index(['Comp', 'Att', 'Pct', 'Yds', 'Yds/Att', 'TD', 'Int', 'ru_att', 'ru_yds',
#        'yds/ru_att', 'ru_td', 'year', 'def_ru_rk', 'def_pass_rk'],
#       dtype='object')

# %%
reframed = series_to_supervised(X_train.values.astype('float32'),1,1)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff = pd.DataFrame(X_train.columns)
coeff['coefficients'] = lr.coef_
coeff
# Out:
#               0  coefficients
# 0          Comp      0.029938
# 1           Att     -0.076581
# 2           Pct     -0.013013
# 3           Yds      0.058688
# 4       Yds/Att     -0.179413
# 5            TD      4.002376
# 6           Int     -1.242807
# 7        ru_att     -0.086593
# 8        ru_yds      0.114284
# 9    yds/ru_att     -0.025317
# 10        ru_td      5.934202
# 11         year      0.257254
# 12    def_ru_rk      0.001679
# 13  def_pass_rk      0.001679

# %%
yhat = lr.predict(X_test)
yhat.shape
# Out:
# (57,)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y_test)
print("RMSE error is: " + str(rmse_val))
# Out:
# RMSE error is: 1.68578446369

# %%
results = pd.DataFrame()
results['Player'] = week1['Player']
#results['score'] = y_test
results['Predicted'] = yhat
#results['Week'] = qb[qb['year']==2017]['Week']
#results.groupby('Player').mean()[['score','Predicted']]
results
# Out:
#                 Player  Predicted
# 0        Aaron Rodgers  22.622505
# 1           Drew Brees  22.935390
# 2            Tom Brady  22.578469
# 3       Deshaun Watson  21.599166
# 4           Cam Newton  20.770403
# 5     Matthew Stafford  21.079952
# 6   Ben Roethlisberger  20.937474
# 7          Andrew Luck  20.630576
# 8        Philip Rivers  20.697301
# 9         Kirk Cousins  20.450940
# 10      Russell Wilson  19.891470
# 11          Jared Goff  20.281654
# 12         Andy Dalton  19.393590
# 13        Tyrod Taylor  18.422072
# 14      Marcus Mariota  18.840468
# 15          Alex Smith  18.706081
# 16        Dak Prescott  18.531013
# 17       Blake Bortles  17.825208
# 18      Mitch Trubisky  17.685679
# 19           Matt Ryan  17.719255
# 20          Nick Foles  17.689892
# 21         Case Keenum  17.309548
# 22    Ryan Fitzpatrick  17.335215
# 23      Ryan Tannehill  17.145849
# 24     Jimmy Garoppolo  16.642067
# 25        Sam Bradford  16.345740
# ...

# %%
results.shape
# Out:
# (300, 3)

# %%
results.to_csv('2018_week1_qb.csv', index= False)
