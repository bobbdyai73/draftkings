# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
rb = pd.read_csv('../input/rb/rb_stats.csv')

# %%
df = pd.read_csv('../input/rb/rb_loc_cleaned.csv')

# %%
df.sort_values(['Name','games'],inplace=True)

# %%
rb.dtypes
# Out:
# year             int64
# Name            object
# games            int64
# Opponent        object
# att_avg        float64
# yds_avg        float64
# td_avg         float64
# tar_avg        float64
# rec_yds_avg    float64
# att_ma         float64
# yds_ma         float64
# td_ma          float64
# tar_ma         float64
# rec_yds_ma     float64
# att_car        float64
# yds_car        float64
# td_car         float64
# tar_car        float64
# rec_yds_car    float64
# surface_0      float64
# h/a_1          float64
# def_rk           int64
# points         float64
# dtype: object

# %%
def conv_atts(df):
    df.rename(columns={'Unnamed: 0':'player'}, inplace=True)
    df.replace('null',0, inplace=True)
    df['h/a_1'] = df['h/a_1'].astype('category')
    df['surface_0'] = df['surface_0'].astype('category')
    

    return df

# %%
rb = conv_atts(rb)
rb.dtypes
# Out:
# year              int64
# Name             object
# games             int64
# Opponent         object
# att_avg         float64
# yds_avg         float64
# td_avg          float64
# tar_avg         float64
# rec_yds_avg     float64
# att_ma          float64
# yds_ma          float64
# td_ma           float64
# tar_ma          float64
# rec_yds_ma      float64
# att_car         float64
# yds_car         float64
# td_car          float64
# tar_car         float64
# rec_yds_car     float64
# surface_0      category
# h/a_1          category
# def_rk            int64
# points          float64
# dtype: object

# %%
rb['Week'] = df['Week']
rb.columns
# Out:
# Index(['year', 'Name', 'games', 'Opponent', 'att_avg', 'yds_avg', 'td_avg',
#        'tar_avg', 'rec_yds_avg', 'att_ma', 'yds_ma', 'td_ma', 'tar_ma',
#        'rec_yds_ma', 'att_car', 'yds_car', 'td_car', 'tar_car', 'rec_yds_car',
#        'surface_0', 'h/a_1', 'def_rk', 'points', 'Week'],
#       dtype='object')

# %%
rb.head()
# Out:
#    year         Name  games Opponent  att_avg  yds_avg  td_avg  tar_avg  \
# 0  2018  Aaron Jones      1      WAS      0.0      0.0    0.00     0.00
# 1  2018  Aaron Jones      2      BUF      6.0     42.0    0.00     1.00
# 2  2018  Aaron Jones      3      DET      8.5     53.5    0.50     1.00
# 3  2018  Aaron Jones      4       SF      8.0     49.0    0.33     1.67
# 4  2018  Aaron Jones      5      LAR      8.0     47.0    0.25     1.50
#
#    rec_yds_avg  att_ma  ...    rec_yds_ma  att_car  yds_car  td_car  tar_car  \
# 0         0.00     0.0  ...          0.00      0.0      0.0    0.00     0.00
# 1         5.00     0.0  ...          0.00      6.0     42.0    0.00     1.00
# 2        11.00     0.0  ...          0.00      8.5     53.5    0.50     1.00
# 3        13.67     0.0  ...          0.00      8.0     49.0    0.33     1.67
# 4        10.25     8.0  ...         10.25      8.0     47.0    0.25     1.50
#
#    rec_yds_car  surface_0  h/a_1  def_rk points
# 0         0.00        1.0    0.0      15    5.7
# 1         5.00        1.0    1.0      18   15.2
# 2        11.00        0.0    0.0      29    7.9
# 3        13.67        1.0    0.0      22    4.1
# 4        10.25        1.0    0.0      14   16.6
#
# [5 rows x 23 columns]

# %%
rb.isnull().sum()
# Out:
# year           0
# Name           0
# games          0
# Opponent       0
# att_avg        0
# yds_avg        0
# td_avg         0
# tar_avg        0
# rec_yds_avg    0
# att_ma         0
# yds_ma         0
# td_ma          0
# tar_ma         0
# rec_yds_ma     0
# att_car        0
# yds_car        0
# td_car         0
# tar_car        0
# rec_yds_car    0
# surface_0      0
# h/a_1          0
# def_rk         0
# points         0
# dtype: int64

# %%
rb = rb.sort_values(['year','Week']).reset_index(drop=True)
rb.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Week'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-845e5bbf1b3e> in <module>()
# ----> 1 rb = rb.sort_values(['year','Week']).reset_index(drop=True)
#       2 rb.head()
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3172             keys = []
#    3173             for x in by:
# -> 3174                 k = self.xs(x, axis=other_axis).values
#    3175                 if k.ndim == 2:
#    3176                     raise ValueError('Cannot sort by duplicate column %s' %
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Week'

# %%
rb_18 = rb[rb['year']==2018.0]
rb
# Out:
#                  Name  Week Opponent  att_avg  yds_avg  td_avg  tar_avg  \
# 0         Aaron Jones   4.0      WAS     0.00     0.00    0.00     0.00
# 1         Aaron Jones   5.0      CHI    13.00    49.00    1.00     0.00
# 2         Aaron Jones   6.0      BUF    16.00    87.00    1.00     0.50
# 3         Aaron Jones   7.0      DAL    15.00    71.67    0.67     1.67
# 4         Aaron Jones   9.0      MIN    15.50    86.50    0.75     2.50
# 5         Aaron Jones  10.0       NO    13.40    71.60    0.60     3.00
# 6         Aaron Jones  13.0      DET    11.67    61.67    0.50     2.67
# 7         Aaron Jones  14.0      CHI    10.14    55.71    0.57     2.29
# 8         Aaron Jones  15.0       TB     9.38    48.50    0.50     2.00
# 9         Aaron Jones  16.0      CLE     8.67    48.33    0.44     2.00
# 10        Aaron Jones   3.0      CAR     0.00     0.00    0.00     0.00
# 11        Aaron Jones   4.0      MIN     6.00    42.00    0.00     1.00
# 12    Aaron Ripkowski   5.0      CHI     0.00     0.00    0.00     0.00
# 13    Aaron Ripkowski   6.0      NYG     2.00    17.00    0.00     0.00
# 14    Aaron Ripkowski   7.0      DAL     1.50     8.50    0.00     0.50
# 15    Aaron Ripkowski   8.0      DAL     2.00     8.33    0.00     0.67
# 16    Aaron Ripkowski   9.0      CHI     3.00    14.75    0.00     0.75
# 17    Aaron Ripkowski  11.0      ATL     2.80    12.60    0.00     0.80
# 18    Aaron Ripkowski  12.0      IND     2.67    12.00    0.00     0.67
# 19    Aaron Ripkowski  13.0      CHI     2.71    10.43    0.14     0.86
# 20    Aaron Ripkowski  14.0      WAS     2.75    10.88    0.25     0.88
# 21    Aaron Ripkowski  17.0      PHI     2.78     9.89    0.22     0.89
# 22    Aaron Ripkowski   4.0      PIT     0.00     0.00    0.00     0.00
# 23    Aaron Ripkowski   5.0      HOU     1.00     4.00    0.00     2.00
# 24    Aaron Ripkowski  10.0      SEA     1.00     3.00    0.00     1.00
# 4844       20.75   14.0  2017.0    14.0    1.0        0.0     0.5  NaN
# 4845       22.40    2.0  2015.0     1.0    0.0        0.0     2.3  NaN
# 4846       23.33    4.0  2016.0     5.0    0.0        1.0     4.4  NaN
# 4847       17.00   15.0  2017.0     1.0    0.0        0.0     0.0  NaN
# 4848       17.00    3.0  2015.0     8.0    1.0        0.0     4.7  NaN
# 4849       16.00    5.0  2016.0    12.0    1.0        0.0     5.2  NaN
# 4850       16.67   16.0  2017.0     3.0    1.0        0.0     7.1  NaN
# 4851       17.00    6.0  2016.0    16.0    1.0        0.0     9.7  NaN
# 4852       15.25   17.0  2017.0    17.0    0.0        0.0     0.0  NaN
# 4853       16.78   19.0  2015.0    22.0    1.0        0.0     1.5  NaN
# 4854       16.70   20.0  2016.0    26.0    1.0        0.0     8.9  NaN
# 4855       15.55    7.0  2016.0    11.0    0.0        0.0     1.7  NaN
# 4856       15.58    8.0  2016.0     8.0    1.0        0.0     0.0  NaN
# 4857       16.85   21.0  2017.0     1.0    1.0        0.0     0.6  NaN
# 4858        5.00    9.0  2016.0    30.0    0.0        0.0     4.0  NaN
# 4859       10.67   18.0  2017.0    20.0    0.0        1.0     0.4  NaN
# 4860       10.25   10.0  2016.0     5.0    1.0        0.0     6.5  NaN
# 4861        8.80   22.0  2017.0    29.0    0.0        1.0     0.0  NaN
# 4862        9.50   11.0  2016.0     6.0    0.0        0.0     9.4  NaN
# 4863       11.14   12.0  2016.0     3.0    0.0        0.0    23.2  NaN
# 4864       13.25   13.0  2016.0    10.0    1.0        0.0    21.0  NaN
# 4865       21.57    1.0  2015.0     7.0    0.0        0.0     0.9  NaN
# 4866       22.38    2.0  2015.0     2.0    0.0        1.0     1.7  NaN
# 4867       22.44    3.0  2015.0    27.0    0.0        1.0     9.7  NaN
# 4868       23.20    4.0  2015.0     7.0    1.0        0.0     0.4  NaN
#
# [4869 rows x 28 columns]

# %%
# Design train and test datasets

train = rb[rb['year']!=2018]
train = train[train['Week']!=4]
train['year'].unique()
# Out:
# array([2017, 2016, 2015], dtype=int64)

# %%
train.shape
# Out:
# (3439, 39)

# %%
test = rb[rb['year']==2018]
test=test[test['Week']==4]
test.shape
# Out:
# (63, 39)

# %%
test.columns
# Out:
# Index(['player', 'Week', 'Opponent', 'year', 'var1(t-1)', 'var2(t-1)',
#        'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)',
#        'var8(t-1)', 'var9(t-1)', 'var10(t-1)', 'var11(t-1)', 'var12(t-1)',
#        'var13(t-1)', 'var14(t-1)', 'var15(t-1)', 'var1(t)', 'var2(t)',
#        'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)',
#        'var9(t)', 'var10(t)', 'var11(t)', 'var12(t)', 'var13(t)', 'var14(t)',
#        'var15(t)', 'def_rk', 'h/a_1', 'surface_0', 'salary', 'points'],
#       dtype='object')

# %%
# Target variables 

y_train = train['points']
y_test = test['points']

# Predictors, all numeric variables minus target variable
X_train = train.iloc[:,4:-2]
X_test = test.iloc[:,4:-2]

# %%
scaler = MinMaxScaler()
scaler.fit_transform(X_train)
# Out:
# array([[ 0.        ,  1.        ,  0.0070922 , ...,  0.        ,
#          0.51998093,  0.14457831],
#        [ 0.01960784,  0.8335    ,  0.02600473, ...,  0.19142857,
#          0.5486886 ,  0.39759036],
#        [ 0.21568627,  0.785     ,  0.23799054, ...,  0.21428571,
#          0.62250835,  0.5       ],
#        ...,
#        [ 0.46411765,  0.6547    ,  0.33174941, ...,  0.21428571,
#          0.48526466,  0.81325301],
#        [ 0.48039216,  0.6695    ,  0.39184397, ...,  0.22857143,
#          0.45808298,  0.85542169],
#        [ 0.58039216,  0.6414    ,  0.42411348, ...,  0.19142857,
#          0.36185026,  0.8253012 ]])

# %%
X_test.shape
# Out:
# (63, 33)

# %%
X_train.shape
# Out:
# (3439, 33)

# %%
y_train.reset_index(inplace=True,drop=True)
X_train.reset_index(inplace=True, drop=True)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff = pd.DataFrame(X_train.columns)
coeff['coefficients'] = lr.coef_
coeff
# Out:
#              0  coefficients
# 0    var1(t-1)      0.138881
# 1    var2(t-1)     -0.076445
# 2    var3(t-1)     -2.216490
# 3    var4(t-1)     -1.138667
# 4    var5(t-1)     -0.035783
# 5    var6(t-1)     -0.060778
# 6    var7(t-1)      0.017863
# 7    var8(t-1)      1.187123
# 8    var9(t-1)      0.168572
# 9   var10(t-1)     -0.006700
# 10  var11(t-1)      0.103015
# 11  var12(t-1)     -0.152682
# 12  var13(t-1)     -8.166758
# 13  var14(t-1)      0.355281
# 14  var15(t-1)     -0.249924
# 15     var1(t)     -0.191846
# 16     var2(t)      0.183973
# 17     var3(t)      3.646357
# 18     var4(t)      1.976133
# 19     var5(t)      0.043293
# 20     var6(t)      0.304513
# 21     var7(t)     -0.067347
# 22     var8(t)     -4.204805
# 23     var9(t)      0.064687
# 24    var10(t)     -0.028453
# 25    var11(t)     -0.232304
# 26    var12(t)      0.194420
# 27    var13(t)     14.009809
# 28    var14(t)     -0.587976
# 29    var15(t)      0.385734
# 30      def_rk      0.063934
# 31       h/a_1      0.385262
# 32   surface_0     -0.197825

# %%
X_train.shape
# Out:
# (3439, 33)

# %%
yhat = lr.predict(X_test)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y_test)
print("RMSE error is: " + str(rmse_val))
# Out:
# RMSE error is: 3.8973007000451947

# %%
results = pd.DataFrame()
results['Player'] = test['player']
#results['score'] = y_test
results['Predicted'] = yhat
results['points'] = test['points']
#results['Week'] = qb[qb['year']==2017]['Week']
#results.groupby('Player').mean()[['score','Predicted']]
results
# Out:
#                             Player  Predicted  points
# 10            Aaron Jones_reframed  19.034514    15.2
# 105          Alex Collins_reframed   8.311572    10.5
# 144           Alfred Blue_reframed   6.304185     3.1
# 189         Alfred Morris_reframed   6.260747     2.8
# 209          Alvin Kamara_reframed  41.834977    44.1
# 337         Austin Ekeler_reframed  12.196285    13.6
# 364   Benjamin Cunningham_reframed  -4.528588     0.0
# 410          Bilal Powell_reframed   9.930035     9.2
# 588           Carlos Hyde_reframed  18.368404    14.2
# 658         Chase Edmonds_reframed   1.655702     0.1
# 707           Chris Ivory_reframed   3.768668     1.5
# 852           Corey Grant_reframed   5.654936     3.7
# 871           Dalvin Cook_reframed   4.119933     2.0
# 1031        David Johnson_reframed  18.249695    19.2
# 1190        Derrick Henry_reframed   4.907325     5.1
# 1268      Devontae Booker_reframed   5.568824     2.4
# 1314           Dion Lewis_reframed  14.032705    15.6
# 1359          Doug Martin_reframed   3.025780     1.1
# 1418         Duke Johnson_reframed  11.011626    13.6
# 1596           Frank Gore_reframed   6.703391    13.7
# 1651      Giovani Bernard_reframed  21.340622    25.6
# 1702       Isaiah Crowell_reframed   6.889608     1.3
# 1706            Ito Smith_reframed  14.187899    13.8
# 1778        Jalen Richard_reframed   9.003633     6.6
# 1820      Jamaal Williams_reframed   5.518216     2.7
# 1835         James Conner_reframed  14.664359     9.4
# 1898          James White_reframed  22.689905    31.2
# 1961       Javorius Allen_reframed   8.679211     6.7
# 2001            Jay Ajayi_reframed  12.482467    11.1
# 2280        Jordan Howard_reframed   8.122661     2.5
# ...                            ...        ...     ...
# 2458         Kenyan Drake_reframed   6.025223     2.6
# 2461      Kerryon Johnson_reframed  13.348564    12.6
# 2564         Lamar Miller_reframed   7.483784     4.9
# 2622      Latavius Murray_reframed   5.148542     5.8
# 2701    LeGarrette Blount_reframed   2.289030     1.2
# 2746         LeSean McCoy_reframed   7.855329     6.7
# 2760    Leonard Fournette_reframed   3.560307     4.5
# 2879       Marshawn Lynch_reframed  20.734276    21.7
# 2924          Matt Breida_reframed  14.266006    10.1
# 3031        Melvin Gordon_reframed  25.832235    33.9
# 3055           Mike Davis_reframed  32.086037    31.4
# 3085       Mike Gillislee_reframed   3.569757     2.5
# 3130           Nick Chubb_reframed  19.701699    25.5
# 3133         Nyheim Hines_reframed  15.445659    28.3
# 3204        Peyton Barber_reframed   4.596568     4.0
# 3207      Phillip Lindsay_reframed  16.728406    15.9
# 3216        Rashaad Penny_reframed   6.120504     4.9
# 3340            Rod Smith_reframed   4.523028     3.2
# 3371        Royce Freeman_reframed  15.445913    12.7
# 3411       Saquon Barkley_reframed  25.025613    22.0
# 3466          Sony Michel_reframed  18.790724    20.2
# 3492         Spencer Ware_reframed   2.112744     0.6
# 3551            TJ Yeldon_reframed  17.535771    24.0
# 3577          Tarik Cohen_reframed  20.962505    33.4
# 3667        Tevin Coleman_reframed  12.420014    10.7
# 3706         Theo Riddick_reframed   6.844322     6.7
# 3809          Todd Gurley_reframed  26.347579    25.6
# 3869        Ty Montgomery_reframed  12.074420     9.4
# 3887        Wayne Gallman_reframed   3.754823     4.3
# 3909    Wendell Smallwood_reframed  10.566715     8.4
#
# [63 rows x 3 columns]

# %%
results.
# Out:
# (300, 3)

# %%
results.to_csv('../output/rb_test.csv', index= False)
