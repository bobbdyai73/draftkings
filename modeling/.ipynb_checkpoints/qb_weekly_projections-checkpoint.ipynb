# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
qb = pd.read_csv('../input/qb/qb_loc_cleaned.csv')

# %%
qb.sort_values(['year','games'], inplace=True)
qb.head()
# Out:
#      games  year                Name Team  Week Opponent  att  comp%  yds  td  \
# 1        1  2012       Aaron Rodgers   GB     1       SF   44   68.0  303   2
# 74       1  2012          Alex Smith   SF     1       GB   26   77.0  211   2
# 139      1  2012         Andrew Luck  IND     1      CHI   45   51.0  309   1
# 206      1  2012         Andy Dalton  CIN     1      BAL   37   60.0  221   0
# 282      1  2012  Ben Roethlisberger  PIT     1      DEN   40   55.0  245   2
#
#      def_rk h/a_1 surface_0  points
# 1         5   1.0       1.0   22.82
# 74       17   0.0       1.0   17.74
# 139      31   0.0       1.0    9.26
# 206      19   0.0       1.0    5.94
# 282      24   0.0       1.0   16.20

# %%
def conv_atts(df):
    df['h/a_1'] = df['h/a_1'].astype('category')
    df['surface_0'] = df['surface_0'].astype('category')

    return df

# %%
qb = conv_atts(qb)
qb.dtypes
# Out:
# games           int64
# year            int64
# Name           object
# Team           object
# Week            int64
# Opponent       object
# att             int64
# comp%         float64
# yds             int64
# td              int64
# def_rk          int64
# h/a_1        category
# surface_0    category
# points        float64
# dtype: object

# %%
qb.shape
# Out:
# (2428, 14)

# %%
train = qb[]
train.tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f8121dc8f4d3> in <module>()
# ----> 1 train = qb.drop(qb.iloc[test.index:])
#       2 train.tail()
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1722         if isinstance(key, slice):
#    1723             self._has_valid_type(key, axis)
# -> 1724             return self._get_slice_axis(key, axis=axis)
#    1725
#    1726         if isinstance(key, list):
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1693             return obj
#    1694
# -> 1695         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    1696         if isinstance(slice_obj, slice):
#    1697             return self._slice(slice_obj, axis=axis, kind='iloc')
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexing.py in _convert_slice_indexer(self, key, axis)
#     239         # if we are accessing via lowered dim, use the last dim
#     240         ax = self.obj._get_axis(min(axis, self.ndim - 1))
# --> 241         return ax._convert_slice_indexer(key, kind=self.name)
#     242
#     243     def _has_valid_setitem_indexer(self, indexer):
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    1359         # validate iloc
#    1360         if kind == 'iloc':
# -> 1361             return slice(self._validate_indexer('slice', key.start, kind),
#    1362                          self._validate_indexer('slice', key.stop, kind),
#    1363                          self._validate_indexer('slice', key.step, kind))
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    3386             pass
#    3387         elif kind in ['iloc', 'getitem']:
# -> 3388             self._invalid_indexer(form, key)
#    3389         return key
#    3390
#
# ~\Anaconda2\envs\py36\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    1517                         "indexers [{key}] of {kind}".format(
#    1518                             form=form, klass=type(self), key=key,
# -> 1519                             kind=type(key)))
#    1520
#    1521     def get_duplicates(self):
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.numeric.Int64Index'> with these indexers [Int64Index([2385, 2386, 2376, 2365, 2380, 2383, 2384, 2354, 2373, 2381, 2389,
#             2378, 2388, 2355, 2375, 2371, 2367, 2387, 2377, 2361, 2364, 2372,
#             2356, 2382, 2369, 2366, 2358, 2374, 2360, 2379, 2357, 2368, 2359,
#             2362, 2363, 2370],
#            dtype='int64')] of <class 'pandas.core.indexes.numeric.Int64Index'>

# %%
test.index
# Out:
# Int64Index([2385, 2386, 2376, 2365, 2380, 2383, 2384, 2354, 2373, 2381, 2389,
#             2378, 2388, 2355, 2375, 2371, 2367, 2387, 2377, 2361, 2364, 2372,
#             2356, 2382, 2369, 2366, 2358, 2374, 2360, 2379, 2357, 2368, 2359,
#             2362, 2363, 2370],
#            dtype='int64')

# %%
test = qb[qb['year']==2018]
test = test[test['Week']==7]
test.head()
# Out:
#       games  year            Name Team  Week Opponent  att  comp%  yds  td  \
# 2385      1  2018    Jeff Driskel  CIN     7       KC    4  100.0   39   0
# 2386      1  2018    Sean Mannion  LAR     7       SF    0    0.0    0   0
# 2376      2  2018    Cody Kessler  JAX     7      HOU   30   70.0  156   1
# 2365      5  2018  Baker Mayfield  CLE     7       TB   34   67.6  215   2
# 2380      5  2018      Josh Rosen  ARI     7      DEN   39   53.8  194   1
#
#       def_rk h/a_1 surface_0  points
# 2385       6   0.0       1.0    2.06
# 2386      11   0.0       1.0    0.10
# 2376       8   1.0       1.0   10.04
# 2365      16   0.0       1.0   20.90
# 2380       2   1.0       1.0    8.16

# %%
df_18 = qb[qb['year']==2018]
df_18.shape
# Out:
# (225, 26)

# %%
df_18
# Out:
#                     Name  Week Opponent  att_avg  comp%_avg  yds_avg  td_avg  \
# 6          Aaron Rodgers     2      CHI    37.00      56.80   333.00    3.00
# 13         Aaron Rodgers     1      MIN     0.00       0.00     0.00    0.00
# 18         Aaron Rodgers     2      WAS    34.00      58.80   199.00    2.00
# 23         Aaron Rodgers     3      BUF    46.00      66.35   327.00    1.50
# 30         Aaron Rodgers     6      DET    37.60      68.60   259.80    2.00
# 35         Aaron Rodgers    12       SF    35.40      66.90   261.90    2.70
# 79            Alex Smith     2      ARI    34.00      61.80   173.00    2.00
# 83            Alex Smith     4      IND    25.00      76.00   186.00    3.00
# 88            Alex Smith     4       GB    36.50      63.35   266.50    2.00
# 97            Alex Smith     4       NO    28.00      77.07   258.00    2.33
# 101           Alex Smith     5      CAR    32.00      67.23   255.67    1.33
# 144          Andrew Luck     2      CIN    23.00      78.30   178.00    2.00
# 148          Andrew Luck     2      WAS    53.00      66.00   370.00    2.00
# 154          Andrew Luck     7      PHI    43.00      57.70   271.67    2.33
# 158          Andrew Luck     5      HOU    42.00      65.07   316.67    2.33
# 163          Andrew Luck     6       NE    44.25      55.00   302.00    1.75
# 168          Andrew Luck    11      NYJ    40.22      58.33   292.33    1.11
# 211          Andy Dalton     2      IND    33.00      78.80   282.00    2.00
# 216          Andy Dalton     6      BAL    31.00      64.15   252.50    1.50
# 221          Andy Dalton     4      CAR    30.67      65.83   288.67    2.67
# 225          Andy Dalton     6      ATL    41.67      68.27   333.67    1.33
# 231          Andy Dalton     2      MIA    28.00      75.00   243.00    2.00
# 237          Andy Dalton     9      PIT    34.71      64.29   261.57    1.86
# 278       Baker Mayfield     3      NYJ     0.00       0.00     0.00    0.00
# 279       Baker Mayfield     4      OAK    23.00      73.90   201.00    0.00
# 280       Baker Mayfield     5      BAL    32.00      62.55   248.00    1.00
# 2153       20.00      2  2018      31    0.0        0.0    3.90
# 2154       23.67      3  2018      14    0.0        0.0    3.80
# 2155       21.25      1  2018      19    0.0        1.0    8.30
# 2159       24.33     13  2018      19    0.0        1.0   -0.30
# 2186       20.00     75  2018      15    1.0        0.0   22.28
# 2190       16.00     77  2018       4    0.0        1.0   17.36
# 2195       14.25     78  2018      12    0.0        0.0    8.52
# 2199       13.00     76  2018      11    1.0        0.0   20.96
# 2205       17.14     73  2018      23    1.0        0.0   32.54
# 2212       11.75     74  2018      29    0.0        1.0   25.80
# 2315        5.00     35  2018      28    1.0        1.0   24.58
# 2318        7.80     36  2018      30    0.0        0.0   15.44
# 2322       20.00     37  2018      22    1.0        1.0    2.96
#
# [225 rows x 26 columns]

# %%
df_18['Week'].unique()
# Out:
# array([ 2,  1,  3,  6, 12,  4,  5,  7, 11,  9,  8, 16, 14, 10, 13, 15, 17],
#       dtype=int64)

# %%
train.shape
# Out:
# (1632, 27)

# %%
test = qb[qb['year']==2018]
test=test[test['Week']==4]
test.shape
# Out:
# (23, 27)

# %%
test.columns
# Out:
# Index(['year', 'player', 'Week', 'Opponent', 'games_avg', 'att_avg',
#        'comp%_avg', 'yds_avg', 'td_avg', 'rat_avg', 'def_rk_avg', 'games_ma',
#        'att_ma', 'comp%_ma', 'yds_ma', 'td_ma', 'rat_ma', 'def_rk_ma',
#        'games_car', 'att_car', 'comp%_car', 'yds_car', 'td_car', 'rat_car',
#        'def_rk_car', 'def_rk', 'h/a_1', 'surface_0', 'salary', 'points'],
#       dtype='object')

# %%
# Target variables 

y_train = train['points']
y_test = test['points']

# Predictors, all numeric variables minus target variable
X_train = train.iloc[:,4:-2]
X_test = test.iloc[:,4:-2]

# %%
X_test.columns
# Out:
# Index(['games_avg', 'att_avg', 'comp%_avg', 'yds_avg', 'td_avg', 'rat_avg',
#        'def_rk_avg', 'games_ma', 'att_ma', 'comp%_ma', 'yds_ma', 'td_ma',
#        'rat_ma', 'def_rk_ma', 'games_car', 'att_car', 'comp%_car', 'yds_car',
#        'td_car', 'rat_car', 'def_rk_car', 'def_rk', 'h/a_1', 'surface_0'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
scaler.fit_transform(X_train)
# Out:
# array([[ 0.        ,  1.        ,  0.0070922 , ...,  0.        ,
#          0.51998093,  0.14457831],
#        [ 0.01960784,  0.8335    ,  0.02600473, ...,  0.19142857,
#          0.5486886 ,  0.39759036],
#        [ 0.21568627,  0.785     ,  0.23799054, ...,  0.21428571,
#          0.62250835,  0.5       ],
#        ...,
#        [ 0.46411765,  0.6547    ,  0.33174941, ...,  0.21428571,
#          0.48526466,  0.81325301],
#        [ 0.48039216,  0.6695    ,  0.39184397, ...,  0.22857143,
#          0.45808298,  0.85542169],
#        [ 0.58039216,  0.6414    ,  0.42411348, ...,  0.19142857,
#          0.36185026,  0.8253012 ]])

# %%
X_test.shape
# Out:
# (29, 24)

# %%
X_train.shape
# Out:
# (1554, 24)

# %%
y_train.reset_index(inplace=True,drop=True)
X_train.reset_index(inplace=True, drop=True)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
coeff = pd.DataFrame(X_train.columns)
coeff['coefficients'] = lr.coef_
coeff
# Out:
#              0  coefficients
# 0    games_avg     -1.557618
# 1      att_avg      0.069540
# 2    comp%_avg      0.094842
# 3      yds_avg      0.011553
# 4       td_avg      1.067263
# 5      rat_avg     -0.096874
# 6   def_rk_avg      0.040532
# 7     games_ma     -0.086614
# 8       att_ma     -0.216187
# 9     comp%_ma      0.118289
# 10      yds_ma      0.001655
# 11       td_ma      3.743741
# 12      rat_ma     -0.065478
# 13   def_rk_ma      0.104408
# 14   games_car      1.646770
# 15     att_car     -0.029742
# 16   comp%_car     -0.147506
# 17     yds_car      0.024927
# 18      td_car     -1.683899
# 19     rat_car      0.124073
# 20  def_rk_car     -0.179305
# 21      def_rk      0.225534
# 22       h/a_1      1.369738
# 23   surface_0     -0.707260

# %%
X_train.shape
# Out:
# (1554, 24)

# %%
yhat = lr.predict(X_test)

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

rmse_val = rmse(yhat, y_test)
print("RMSE error is: " + str(rmse_val))
# Out:
# RMSE error is: 11.886112724

# %%
results = pd.DataFrame()
results['Player'] = test['player']
#results['score'] = y_test
results['Predicted'] = yhat
results['points'] = test['points']
#results['Week'] = qb[qb['year']==2017]['Week']
#results.groupby('Player').mean()[['score','Predicted']]
results
# Out:
#                            Player  Predicted  points
# 49         Aaron Rodgers_reframed  20.573807   17.02
# 123          Andrew Luck_reframed  19.606521   39.66
# 171          Andy Dalton_reframed  24.064387   28.78
# 177       Baker Mayfield_reframed  14.830017   16.80
# 221   Ben Roethlisberger_reframed  20.109991   15.86
# 293        Blake Bortles_reframed  17.671645   28.32
# 497         Carson Wentz_reframed  18.251134   24.72
# 531          Case Keenum_reframed  22.272994    8.80
# 606         Dak Prescott_reframed  14.274891   18.40
# 666           Derek Carr_reframed  22.945548   36.58
# 677       Deshaun Watson_reframed  18.536891   35.10
# 743           Drew Brees_reframed  21.044687    8.58
# 814          Eli Manning_reframed  24.792723   15.70
# 910           Jared Goff_reframed  21.670753   42.30
# 1007          Joe Flacco_reframed  22.304024   25.22
# 1022          Josh Allen_reframed  12.100147    4.94
# 1050          Josh Rosen_reframed   5.372348   12.50
# 1112        Kirk Cousins_reframed  17.064334   35.68
# 1168      Marcus Mariota_reframed  18.549693   34.36
# 1265           Matt Ryan_reframed  24.913490   32.26
# 1320    Matthew Stafford_reframed  21.049755   23.78
# 1345      Mitch Trubisky_reframed  19.753895   46.46
# 1375     Patrick Mahomes_reframed  15.725732   25.86
# 1439       Philip Rivers_reframed  24.175494   22.70
# 1495      Russell Wilson_reframed  16.196133    8.98
# 1533    Ryan Fitzpatrick_reframed  19.723250    4.04
# 1577      Ryan Tannehill_reframed  18.185383    2.00
# 1614         Sam Darnold_reframed  12.919849   11.48
# 1698           Tom Brady_reframed  17.516351   20.96

# %%
results.
# Out:
#   File "<ipython-input-83-905f1e55433b>", line 1
#     results.
#             ^
# SyntaxError: invalid syntax

# %%
results.to_csv('../output/qb_test.csv', index= False)
